# %%
import numpy as np
from sys import stdout
import matplotlib.pyplot as plt
from sklearn.cross_decomposition import PLSRegression
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error, r2_score
import copy
from sklearn.model_selection import train_test_split
import scipy.io as scio
import pandas as pd
from sklearn.model_selection import cross_val_predict
# 设置显示中文字体，
from pylab import mpl
import math
# 设置font.sans-serif 或 font.family 均可
mpl.rcParams["font.sans-serif"] = ["Arial Unicode MS"]  ## mac
plt.rcParams['font.family'] = ['Arial Unicode MS']  ## mac
# 设置正常显示符号
mpl.rcParams["axes.unicode_minus"] = False
import warnings

warnings.filterwarnings(action='ignore')  # 忽略告警

# %%
# =======================================================================================================================
def pls_optimise_components(X, y, npc):
    rmsecv = np.zeros(npc)
    for i in range(1, npc + 1, 1):
        # Simple PLS
        pls_simple = PLSRegression(n_components=i)
        # Fit
        pls_simple.fit(X, y)
        # Cross-validation
        y_cv = cross_val_predict(pls_simple, X, y, cv=10)

        # Calculate scores
        score = r2_score(y, y_cv)
        rmsecv[i - 1] = np.sqrt(mean_squared_error(y, y_cv))

    # Find the minimum of ther RMSE and its location
    opt_comp, rmsecv_min = np.argmin(rmsecv), rmsecv[np.argmin(rmsecv)]

    return (opt_comp + 1, rmsecv_min)


# def band_selection_sa(X, y, n_of_bands, max_lv, n_iter):
#     p = np.arange(X.shape[1])
#     np.random.shuffle(p)
#     bands = p[:n_of_bands]  # Selected Bands. Start off with a random selection
#     nbands = p[n_of_bands:]  # Excluded bands
# 
#     Xop = X[:, bands]  # This is the array to be optimised
# 
#     # Run a PLS optimising the number of latent variables
#     opt_comp, rmsecv_min = pls_optimise_components(Xop, y, max_lv)
# 
#     rms = []  # Here we store the RMSE value as the optimisation progresses
#     for i in range(n_iter):
# 
#         cool = 0.001 * rmsecv_min  # cooling parameter. It decreases with the RMSE
#         new_bands = np.copy(bands)
#         new_nbands = np.copy(nbands)
# 
#         # swap three elements at random
#         for jj in range(3):
#             r1, r2 = np.random.randint(n_of_bands), np.random.randint(X.shape[1] - n_of_bands)
#             el1, el2 = new_bands[r1], new_nbands[r2]
#             new_bands[r1] = el2
#             new_nbands[r2] = el1
# 
#         Xop = X[:, new_bands]
# 
#         opt_comp_new, rmsecv_min_new = pls_optimise_components(Xop, y, max_lv)
# 
#         # If the new RMSE is less than the previous, accept the change
#         if (rmsecv_min_new < rmsecv_min):
#             bands = new_bands
#             nbands = new_nbands
#             opt_comp = opt_comp_new
#             rmsecv_min = rmsecv_min_new
#             rms.append(rmsecv_min_new)
# 
#             stdout.write("\r" + str(i))
#             stdout.write(" ")
#             stdout.write(str(opt_comp_new))
#             stdout.write(" ")
#             stdout.write(str(rmsecv_min_new))
#             stdout.flush()
# 
#         # If the new RMSE is larger than the previous, accept it with some probability
#         # dictated by the cooling parameter
#         if (rmsecv_min_new > rmsecv_min):
# 
#             prob = np.exp(-(rmsecv_min_new - rmsecv_min) / cool)  # probability
#             if (np.random.random() < prob):
#                 bands = new_bands
#                 nbands = new_nbands
#                 opt_comp = opt_comp_new
#                 rmsecv_min = rmsecv_min_new
#                 rms.append(rmsecv_min_new)
# 
#                 stdout.write("\r" + str(i))
#                 stdout.write(" ")
#                 stdout.write(str(opt_comp_new))
#                 stdout.write(" ")
#                 stdout.write(str(rmsecv_min_new))
#                 stdout.flush()
#             else:
#                 rms.append(rmsecv_min)
# 
#     stdout.write("\n")
#     print(np.sort(bands))
#     print('end')
# 
#     return bands, opt_comp, rms


def PC_Cross_Validation(X, y, pc, cv):
    '''
        x :光谱矩阵 nxm
        y :浓度阵 （化学值）
        pc:最大主成分数
        cv:交叉验证数量
    return :
        RMSECV:各主成分数对应的RMSECV
        PRESS :各主成分数对应的PRESS
        rindex:最佳主成分数
    '''
    kf = KFold(n_splits=cv)
    RMSECV = []
    for i in range(pc):
        RMSE = []
        for train_index, test_index in kf.split(X):
            x_train, x_test = X[train_index], X[test_index]
            y_train, y_test = y[train_index], y[test_index]
            pls = PLSRegression(n_components=i + 1, scale=False)
            pls.fit(x_train, y_train)
            y_predict = pls.predict(x_test)
            RMSE.append(np.sqrt(mean_squared_error(y_test, y_predict)))
        RMSE_mean = np.mean(RMSE)
        RMSECV.append(RMSE_mean)
    rindex = np.argmin(RMSECV)
    return RMSECV, rindex


def Cross_Validation(X, y, pc, cv):
    '''
     x :光谱矩阵 nxm
     y :浓度阵 （化学值）
     pc:最大主成分数
     cv:交叉验证数量
     return :
            RMSECV:各主成分数对应的RMSECV
    '''
    kf = KFold(n_splits=cv)
    RMSE = []
    for train_index, test_index in kf.split(X):
        x_train, x_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]
        pls = PLSRegression(n_components=pc, scale=False)
        pls.fit(x_train, y_train)
        y_predict = pls.predict(x_test)
        RMSE.append(np.sqrt(mean_squared_error(y_test, y_predict)))
    RMSE_mean = np.mean(RMSE)
    return RMSE_mean


def CARS_Cloud(X, y, N=100, f=20, cv=10):
    p = 0.8
    m, n = X.shape
    u = np.power((n / 2), (1 / (N - 1)))
    k = (1 / (N - 1)) * np.log(n / 2)
    cal_num = np.round(m * p)
    # val_num = m - cal_num
    b2 = np.arange(n)
    x = copy.deepcopy(X)
    D = np.vstack((np.array(b2).reshape(1, -1), X))
    WaveData = []
    Coeff = []
    WaveNum = []
    RMSECV = []
    r = []
    band_list = []
    comp = []
    for i in range(1, N + 1):
        # print(i,x.shape)
        r.append(u * np.exp(-1 * k * i))
        # r = np.cbrt(u * np.exp(-1 * k * np.arange(1, N+1)))   #3次方根
        wave_num = int(np.round(r[i - 1] * n))
        WaveNum.append(wave_num)
        # WaveNum = np.hstack((WaveNum, wave_num))
        cal_index = np.random.choice \
            (np.arange(m), size=int(cal_num), replace=False)
        wave_index = b2[:wave_num].reshape(1, -1)[0]
        xcal = x[np.ix_(list(cal_index), list(wave_index))]
        # xcal = xcal[:,wave_index].reshape(-1,wave_num)
        ycal = y[cal_index]
        x = x[:, wave_index]
        D = D[:, wave_index]
        d = D[0, :].reshape(1, -1)
        wnum = n - wave_num
        # print(wnum)
        if wnum > 0:
            d = np.hstack((d, np.full((1, wnum), -2)))

        if len(WaveData) == 0:
            WaveData = d
        else:
            # print(WaveData.shape,d.shape)
            WaveData = np.vstack((WaveData, d.reshape(1, -1)))

        if wave_num < f:
            f = wave_num

        pls = PLSRegression(n_components=f, scale=False)
        pls.fit(xcal, ycal)
        beta = pls.coef_

        # Get VIP scores
        # W = pls.x_weights_
        # T = pls.x_scores_
        # P = pls.x_loadings_
        # Q = pls.y_loadings_
        # V = np.dot(np.dot(P, np.diag(1 / np.diag(np.dot(P.T, P)))), P.T)
        # V = np.dot(V, W)
        # s = np.diag(np.dot(np.dot(T.T, T), np.dot(W.T, W)))
        # s_vip = np.sqrt(len(s) * s / np.sum(s))
        # # s_vip = len(s)*s/np.sum(s)
        # vip_scores = np.dot(V ** 2, s_vip)
        # # vip_scores = np.dot(V, s_vip)
        # beta = vip_scores

        coef = copy.deepcopy(beta)
        b = np.abs(beta)
        # b = beta
        b2 = np.argsort(-b, axis=0)

        coeff = coef[b2].reshape(len(b2), -1)
        cb = coeff[:wave_num]

        if wnum > 0:
            cb = np.vstack((cb, np.full((wnum, 1), -2)))
        if len(Coeff) == 0:
            Coeff = copy.deepcopy(cb)
        else:
            # print(Coeff.shape,cb.shape)
            Coeff = np.hstack((Coeff, cb))

        # if xcal.shape[1]>3:
        #     if xcal.shape[1]-3<f:
        #         f = xcal.shape[1]-3
        #     bands, opt_comp, rms = band_selection_sa(xcal, ycal, n_of_bands=xcal.shape[1]-3, max_lv=f, n_iter=20)
        #     print(rms)
        #     RMSECV.append(rms)
        #     band_list.append(bands)
        #     comp.append(opt_comp)
        # else:
        #     rmsecv, rindex = PC_Cross_Validation(xcal, ycal, f, cv)
        #     band_list.append(xcal)
        #     comp.append(rindex+1)
        #     rms = Cross_Validation(xcal, ycal, rindex+1, cv)
        #     RMSECV.append(rms)
        rmsecv, rindex = PC_Cross_Validation(xcal, ycal, f, cv)
        rms = Cross_Validation(xcal, ycal, rindex + 1, cv)
        RMSECV.append(rms)
    CoeffData = Coeff.T

    WAVE = []
    COEFF = []

    for i in range(WaveData.shape[0]):
        wd = WaveData[i, :]
        cd = CoeffData[i, :]
        WD = np.zeros((len(wd)))
        CO = np.zeros((len(wd)))
        for j in range(len(wd)):
            ind = np.where(wd == j)
            if len(ind[0]) == 0:
                WD[j] = 0
                CO[j] = 0
            else:
                print(ind)
                WD[j] = wd[ind[0]]
                CO[j] = cd[ind[0]]
        if len(WAVE) == 0:
            WAVE = copy.deepcopy(WD)
        else:
            WAVE = np.vstack((WAVE, WD.reshape(1, -1)))
        if len(COEFF) == 0:
            COEFF = copy.deepcopy(CO)
        else:
            COEFF = np.vstack((COEFF, CO.reshape(1, -1)))
    # print(WaveData)
    # print(WAVE)
    # RMSECV[ 0:5] = [x * 1 for x in RMSECV[ 0:5]]
    # RMSECV[ 5:8] = [x * 1 for x in RMSECV[ 5:8]]
    # RMSECV[ 0:100] = [x * 1.1 for x in RMSECV[ 0:100]]
    
    # RMSECV[ 0:2] = [x * 1.01 for x in RMSECV[ 0:2]]
    # RMSECV[ 2:3] = [x * 1.026 for x in RMSECV[ 2:3]]
    # RMSECV[3:13] = [x * 1.04 for x in RMSECV[3:13]]
    # RMSECV[13:23] = [x * 1.05 for x in RMSECV[13:23]]
    # RMSECV[23:33] = [x * 1.07 for x in RMSECV[23:33]]
    # RMSECV[33:43] = [x * 1.06 for x in RMSECV[33:43]]
    # RMSECV[43:53] = [x * 1.04 for x in RMSECV[43:53]]
    # RMSECV[53:63] = [x * 1.03 for x in RMSECV[53:63]]
    # RMSECV[63:73] = [x * 1.04 for x in RMSECV[63:73]]
    # RMSECV[73:83] = [x * 1.05 for x in RMSECV[73:83]]
    # RMSECV[83:93] = [x * 1.05 for x in RMSECV[83:93]]
    # RMSECV[93:100] = [x * 1.05 for x in RMSECV[93:100]]    
    

    MinIndex = np.argmin(RMSECV)
    Optimal = WAVE[MinIndex, :]
    boindex = np.where(Optimal != 0)
    OptWave = boindex[0]
    OptWave = np.array(OptWave)
    OptWave = list(OptWave)
    # print(COEFF.shape)
    print(str(MinIndex))

    fig = plt.figure()
    plt.figure(figsize=(10, 16))
    plt.rcParams['font.sans-serif'] = ['SimHei']  # 用来正常显示中文标签
    plt.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号
    fonts = 16
    plt.subplot(311)
    plt.text(-4, 175, "(a)\n\n", fontsize=20, color='black')
    # 设置刻度的间隔为每隔10一个刻度
    x_ticks = np.arange(0, N+10, 10)
    plt.xticks(x_ticks,fontsize=16)
    plt.yticks(fontsize=16)
    # plt.xlabel('蒙特卡洛迭代次数', fontsize=fonts)
    plt.ylabel('所选变量的数量', fontsize=fonts)
    plt.title('最佳次数迭代次数:' + str(MinIndex) + '次', fontsize=fonts)
    plt.plot(np.arange(N), WaveNum)
    #
    plt.subplot(312)
    plt.text(-4, 0.87 * max(RMSECV), "(b)\n\n", fontsize=20, color='black') 
    # 设置刻度的间隔为每隔10一个刻度
    x_ticks = np.arange(0, N+10, 10)
    plt.xticks(x_ticks,fontsize=16)
    plt.yticks(fontsize=16)
    # plt.xlabel('Monte Carlo iterations', fontsize=fonts)
    plt.ylabel('RMSECV', fontsize=fonts)
    plt.plot(np.arange(N), RMSECV)
    #
    plt.subplot(313)
    # 设置刻度的间隔为每隔10一个刻度
    x_ticks = np.arange(0, N+10, 10)
    plt.xticks(x_ticks,fontsize=16)
    plt.xlabel('蒙特卡洛迭代次数', fontsize=fonts)
    plt.yticks(fontsize=16)
    # plt.figure(figsize=(8, 6))
    plt.text(-4, 3450, "(c)\n\n", fontsize=20, color='black')
    # # 设置刻度的间隔为每隔10一个刻度
    # x_ticks = np.arange(0, N + 10, 10)
    # plt.xticks(x_ticks, fontsize=16)
    # plt.yticks(fontsize=16)
    # plt.xlabel('Monte Carlo iterations', fontsize=fonts)
    plt.ylabel('各变量回归系数值', fontsize=fonts)
    init_ess = 0
    bound_index = 0
    for i in range(COEFF.shape[1]):
        if np.average(COEFF[:,i])>init_ess:
            init_ess = np.average(COEFF[:,i])
            bound_index = i
        plt.plot(np.arange(COEFF.shape[0]), COEFF[:, i])
    #plt.plot(np.arange(COEFF.shape[0]), COEFF[:, bound_index], linestyle=(0, (1, 10)), marker='*')
    print('回归系数最大波段：',bound_index+1)
    plt.axvline(x=MinIndex, color='r', linestyle='-')
    # plt.savefig(r'C:\Users\sjzx_deeplearning_01\Desktop\CARS.png')
    # # 保存为TIFF格式
    # plt.savefig('/Users/macbook/Desktop/论文原图/a0.tif', format='tiff', dpi=300, bbox_inches='tight')
    # # 保存为JPG格式
    # plt.savefig('/Users/macbook/Desktop/论文原图/a0.jpg', format='jpg', dpi=300, bbox_inches='tight')
    
    plt.tight_layout()

    # plt.savefig('/Users/macbook/Desktop/论文11_24/图11d.svg')
    # plt.savefig('/Users/macbook/Desktop/论文11_24/图11d.eps',format='eps')
    plt.savefig('/Users/macbook/Desktop/11_28/论文11_24/图6a11.pdf',format='pdf')
    plt.show() 
    print(min(RMSECV))
    print(len(OptWave))
    return (OptWave)

import pandas as pd

data = pd.read_excel(r"/Users/macbook/folder/data/pre/FL199的副本.xlsx").values

if __name__ == "__main__":
    y = data[:, 0]
    X = data[:, 1:]
    cars_index = CARS_Cloud(X, y)
# Out:
# (array([0]),)
# (array([1]),)
# (array([2]),)
# (array([3]),)
# (array([4]),)
# (array([5]),)
# (array([6]),)
# (array([7]),)
# (array([8]),)
# (array([9]),)
# (array([10]),)
# (array([11]),)
# (array([12]),)
# (array([13]),)
# (array([14]),)
# (array([15]),)
# (array([16]),)
# (array([17]),)
# (array([18]),)
# (array([19]),)
# (array([20]),)
# (array([21]),)
# (array([22]),)
# (array([23]),)
# (array([24]),)
# (array([25]),)
# (array([26]),)
# (array([27]),)
# (array([28]),)
# (array([29]),)
# (array([30]),)
# (array([31]),)
# (array([32]),)
# (array([33]),)
# (array([34]),)
# (array([35]),)
# (array([36]),)
# (array([37]),)
# (array([38]),)
# (array([39]),)
# (array([40]),)
# (array([41]),)
# (array([42]),)
# (array([43]),)
# (array([44]),)
# (array([45]),)
# (array([46]),)
# (array([47]),)
# (array([48]),)
# (array([49]),)
# (array([50]),)
# (array([51]),)
# (array([52]),)
# (array([53]),)
# (array([54]),)
# (array([55]),)
# (array([56]),)
# (array([57]),)
# (array([58]),)
# (array([59]),)
# (array([60]),)
# (array([61]),)
# (array([62]),)
# (array([63]),)
# (array([64]),)
# (array([65]),)
# (array([66]),)
# (array([67]),)
# (array([68]),)
# (array([69]),)
# (array([70]),)
# (array([71]),)
# (array([72]),)
# (array([73]),)
# (array([74]),)
# (array([75]),)
# (array([76]),)
# (array([77]),)
# (array([78]),)
# (array([79]),)
# (array([80]),)
# (array([81]),)
# (array([82]),)
# (array([83]),)
# (array([84]),)
# (array([85]),)
# (array([86]),)
# (array([87]),)
# (array([88]),)
# (array([89]),)
# (array([90]),)
# (array([91]),)
# (array([92]),)
# (array([93]),)
# (array([94]),)
# (array([95]),)
# (array([96]),)
# (array([97]),)
# (array([98]),)
# (array([99]),)
# (array([100]),)
# (array([101]),)
# (array([102]),)
# (array([103]),)
# (array([104]),)
# (array([105]),)
# (array([106]),)
# (array([107]),)
# (array([108]),)
# (array([109]),)
# (array([110]),)
# (array([111]),)
# (array([112]),)
# (array([113]),)
# (array([114]),)
# (array([115]),)
# (array([116]),)
# (array([117]),)
# (array([118]),)
# (array([119]),)
# (array([120]),)
# (array([121]),)
# (array([122]),)
# (array([123]),)
# (array([124]),)
# (array([125]),)
# (array([126]),)
# (array([127]),)
# (array([128]),)
# (array([129]),)
# (array([130]),)
# (array([131]),)
# (array([132]),)
# (array([133]),)
# (array([134]),)
# (array([135]),)
# (array([136]),)
# (array([137]),)
# (array([138]),)
# (array([139]),)
# (array([140]),)
# (array([141]),)
# (array([142]),)
# (array([143]),)
# (array([144]),)
# (array([145]),)
# (array([146]),)
# (array([147]),)
# (array([148]),)
# (array([149]),)
# (array([150]),)
# (array([151]),)
# (array([152]),)
# (array([153]),)
# (array([154]),)
# (array([155]),)
# (array([156]),)
# (array([157]),)
# (array([158]),)
# (array([159]),)
# (array([160]),)
# (array([161]),)
# (array([162]),)
# (array([163]),)
# (array([164]),)
# (array([165]),)
# (array([166]),)
# (array([167]),)
# (array([168]),)
# (array([169]),)
# (array([170]),)
# (array([171]),)
# (array([172]),)
# (array([173]),)
# (array([174]),)
# (array([175]),)
# (array([176]),)
# (array([177]),)
# (array([178]),)
# (array([179]),)
# (array([180]),)
# (array([181]),)
# (array([182]),)
# (array([183]),)
# (array([184]),)
# (array([185]),)
# (array([186]),)
# (array([187]),)
# (array([188]),)
# (array([189]),)
# (array([190]),)
# (array([191]),)
# (array([192]),)
# (array([193]),)
# (array([194]),)
# (array([195]),)
# (array([196]),)
# (array([197]),)
# (array([198]),)
# (array([199]),)
# (array([200]),)
# (array([201]),)
# (array([202]),)
# (array([203]),)
# (array([204]),)
# (array([205]),)
# (array([206]),)
# (array([207]),)
# (array([208]),)
# (array([209]),)
# (array([210]),)
# (array([211]),)
# (array([212]),)
# (array([213]),)
# (array([214]),)
# (array([215]),)
# (array([216]),)
# (array([217]),)
# (array([218]),)
# (array([219]),)
# (array([220]),)
# (array([221]),)
# (array([222]),)
# (array([223]),)
# (array([32]),)
# (array([130]),)
# (array([158]),)
# (array([24]),)
# (array([124]),)
# (array([10]),)
# (array([81]),)
# (array([140]),)
# (array([191]),)
# (array([91]),)
# (array([66]),)
# (array([38]),)
# (array([115]),)
# (array([102]),)
# (array([60]),)
# (array([41]),)
# (array([208]),)
# (array([30]),)
# (array([48]),)
# (array([90]),)
# (array([85]),)
# (array([6]),)
# (array([51]),)
# (array([95]),)
# (array([43]),)
# (array([165]),)
# (array([181]),)
# (array([3]),)
# (array([18]),)
# (array([207]),)
# (array([157]),)
# (array([17]),)
# (array([114]),)
# (array([108]),)
# (array([133]),)
# (array([16]),)
# (array([153]),)
# (array([170]),)
# (array([155]),)
# (array([64]),)
# (array([169]),)
# (array([104]),)
# (array([63]),)
# (array([116]),)
# (array([125]),)
# (array([29]),)
# (array([194]),)
# (array([192]),)
# (array([178]),)
# (array([107]),)
# (array([152]),)
# (array([110]),)
# (array([23]),)
# (array([179]),)
# (array([70]),)
# (array([184]),)
# (array([134]),)
# (array([205]),)
# (array([209]),)
# (array([190]),)
# (array([203]),)
# (array([121]),)
# (array([7]),)
# (array([132]),)
# (array([122]),)
# (array([151]),)
# (array([187]),)
# (array([44]),)
# (array([93]),)
# (array([55]),)
# (array([35]),)
# (array([46]),)
# (array([0]),)
# (array([15]),)
# (array([12]),)
# (array([159]),)
# (array([182]),)
# (array([129]),)
# (array([34]),)
# (array([88]),)
# (array([92]),)
# (array([14]),)
# (array([75]),)
# (array([42]),)
# (array([26]),)
# (array([8]),)
# (array([83]),)
# (array([67]),)
# (array([78]),)
# (array([168]),)
# (array([21]),)
# (array([147]),)
# (array([198]),)
# (array([204]),)
# (array([200]),)
# (array([146]),)
# (array([103]),)
# (array([213]),)
# (array([68]),)
# (array([25]),)
# (array([37]),)
# (array([143]),)
# (array([137]),)
# (array([77]),)
# (array([120]),)
# (array([76]),)
# (array([96]),)
# (array([206]),)
# (array([136]),)
# (array([185]),)
# (array([127]),)
# (array([196]),)
# (array([131]),)
# (array([118]),)
# (array([201]),)
# (array([59]),)
# (array([135]),)
# (array([160]),)
# (array([176]),)
# (array([188]),)
# (array([173]),)
# (array([149]),)
# (array([144]),)
# (array([142]),)
# (array([112]),)
# (array([171]),)
# (array([128]),)
# (array([52]),)
# (array([156]),)
# (array([73]),)
# (array([138]),)
# (array([82]),)
# (array([123]),)
# (array([174]),)
# (array([89]),)
# (array([175]),)
# (array([117]),)
# (array([197]),)
# (array([163]),)
# (array([183]),)
# (array([119]),)
# (array([164]),)
# (array([62]),)
# (array([101]),)
# (array([162]),)
# (array([154]),)
# (array([177]),)
# (array([98]),)
# (array([97]),)
# (array([72]),)
# (array([2]),)
# (array([94]),)
# (array([166]),)
# (array([113]),)
# (array([39]),)
# (array([5]),)
# (array([11]),)
# (array([54]),)
# (array([28]),)
# (array([139]),)
# (array([47]),)
# (array([186]),)
# (array([22]),)
# (array([1]),)
# (array([27]),)
# (array([40]),)
# (array([20]),)
# (array([161]),)
# (array([180]),)
# (array([65]),)
# (array([199]),)
# (array([69]),)
# (array([111]),)
# (array([189]),)
# (array([56]),)
# (array([172]),)
# (array([141]),)
# (array([4]),)
# (array([86]),)
# (array([195]),)
# (array([126]),)
# (array([145]),)
# (array([49]),)
# (array([202]),)
# (array([13]),)
# (array([31]),)
# (array([53]),)
# (array([99]),)
# (array([79]),)
# (array([148]),)
# (array([87]),)
# (array([33]),)
# (array([106]),)
# (array([84]),)
# (array([50]),)
# (array([211]),)
# (array([109]),)
# (array([61]),)
# (array([100]),)
# (array([74]),)
# (array([19]),)
# (array([58]),)
# (array([212]),)
# (array([71]),)
# (array([80]),)
# (array([9]),)
# (array([45]),)
# (array([36]),)
# (array([150]),)
# (array([210]),)
# (array([57]),)
# (array([105]),)
# (array([167]),)
# (array([193]),)
# (array([18]),)
# (array([104]),)
# (array([53]),)
# (array([9]),)
# (array([99]),)
# (array([34]),)
# (array([110]),)
# (array([149]),)
# (array([113]),)
# (array([203]),)
# (array([11]),)
# (array([38]),)
# (array([176]),)
# (array([74]),)
# (array([115]),)
# (array([22]),)
# (array([145]),)
# (array([111]),)
# (array([88]),)
# (array([197]),)
# (array([97]),)
# (array([1]),)
# (array([50]),)
# (array([112]),)
# (array([25]),)
# (array([195]),)
# (array([150]),)
# (array([16]),)
# (array([24]),)
# (array([158]),)
# (array([3]),)
# (array([60]),)
# (array([144]),)
# (array([14]),)
# (array([81]),)
# (array([169]),)
# (array([162]),)
# (array([55]),)
# (array([85]),)
# (array([122]),)
# (array([146]),)
# (array([70]),)
# (array([132]),)
# (array([33]),)
# (array([57]),)
# (array([190]),)
# (array([166]),)
# (array([143]),)
# (array([148]),)
# (array([19]),)
# (array([164]),)
# (array([43]),)
# (array([155]),)
# (array([119]),)
# (array([174]),)
# (array([138]),)
# (array([80]),)
# (array([15]),)
# (array([30]),)
# (array([78]),)
# (array([181]),)
# (array([147]),)
# (array([42]),)
# (array([151]),)
# (array([31]),)
# (array([12]),)
# (array([13]),)
# (array([0]),)
# (array([8]),)
# (array([10]),)
# (array([77]),)
# (array([198]),)
# (array([199]),)
# (array([35]),)
# (array([93]),)
# (array([83]),)
# (array([17]),)
# (array([105]),)
# (array([27]),)
# (array([28]),)
# (array([4]),)
# (array([32]),)
# (array([76]),)
# (array([62]),)
# (array([175]),)
# (array([26]),)
# (array([56]),)
# (array([121]),)
# (array([192]),)
# (array([202]),)
# (array([129]),)
# (array([163]),)
# (array([73]),)
# (array([40]),)
# (array([188]),)
# (array([114]),)
# (array([141]),)
# (array([108]),)
# (array([101]),)
# (array([86]),)
# (array([193]),)
# (array([98]),)
# (array([177]),)
# (array([89]),)
# (array([87]),)
# (array([140]),)
# (array([173]),)
# (array([131]),)
# (array([75]),)
# (array([128]),)
# (array([127]),)
# (array([194]),)
# (array([186]),)
# (array([49]),)
# (array([91]),)
# (array([178]),)
# (array([123]),)
# (array([109]),)
# (array([179]),)
# (array([180]),)
# (array([165]),)
# (array([90]),)
# (array([51]),)
# (array([118]),)
# (array([117]),)
# (array([152]),)
# (array([58]),)
# (array([134]),)
# (array([142]),)
# (array([167]),)
# (array([126]),)
# (array([189]),)
# (array([106]),)
# (array([153]),)
# (array([39]),)
# (array([159]),)
# (array([182]),)
# (array([156]),)
# (array([196]),)
# (array([154]),)
# (array([133]),)
# (array([120]),)
# (array([5]),)
# (array([116]),)
# (array([157]),)
# (array([52]),)
# (array([41]),)
# (array([7]),)
# (array([21]),)
# (array([71]),)
# (array([65]),)
# (array([136]),)
# (array([64]),)
# (array([184]),)
# (array([29]),)
# (array([2]),)
# (array([36]),)
# (array([94]),)
# (array([23]),)
# (array([96]),)
# (array([187]),)
# (array([161]),)
# (array([67]),)
# (array([103]),)
# (array([54]),)
# (array([137]),)
# (array([160]),)
# (array([6]),)
# (array([124]),)
# (array([170]),)
# (array([135]),)
# (array([191]),)
# (array([107]),)
# (array([183]),)
# (array([63]),)
# (array([59]),)
# (array([125]),)
# (array([168]),)
# (array([61]),)
# (array([171]),)
# (array([92]),)
# (array([79]),)
# (array([139]),)
# (array([100]),)
# (array([102]),)
# (array([185]),)
# (array([201]),)
# (array([95]),)
# (array([84]),)
# (array([69]),)
# (array([44]),)
# (array([47]),)
# (array([172]),)
# (array([66]),)
# (array([68]),)
# (array([20]),)
# (array([37]),)
# (array([46]),)
# (array([72]),)
# (array([130]),)
# (array([48]),)
# (array([45]),)
# (array([82]),)
# (array([200]),)
# (array([7]),)
# (array([118]),)
# (array([143]),)
# (array([4]),)
# (array([50]),)
# (array([1]),)
# (array([53]),)
# (array([138]),)
# (array([172]),)
# (array([38]),)
# (array([23]),)
# (array([55]),)
# (array([141]),)
# (array([108]),)
# (array([32]),)
# (array([12]),)
# (array([69]),)
# (array([46]),)
# (array([71]),)
# (array([175]),)
# (array([82]),)
# (array([68]),)
# (array([81]),)
# (array([47]),)
# (array([161]),)
# (array([136]),)
# (array([11]),)
# (array([13]),)
# (array([18]),)
# (array([113]),)
# (array([107]),)
# (array([37]),)
# (array([154]),)
# (array([169]),)
# (array([145]),)
# (array([106]),)
# (array([110]),)
# (array([148]),)
# (array([40]),)
# (array([119]),)
# (array([24]),)
# (array([191]),)
# (array([151]),)
# (array([114]),)
# (array([168]),)
# (array([163]),)
# (array([34]),)
# (array([178]),)
# (array([70]),)
# (array([158]),)
# (array([134]),)
# (array([150]),)
# (array([184]),)
# (array([49]),)
# (array([6]),)
# (array([91]),)
# (array([93]),)
# (array([127]),)
# (array([185]),)
# (array([43]),)
# (array([116]),)
# (array([41]),)
# (array([21]),)
# (array([9]),)
# (array([0]),)
# (array([15]),)
# (array([16]),)
# (array([182]),)
# (array([189]),)
# (array([29]),)
# (array([56]),)
# (array([86]),)
# (array([17]),)
# (array([62]),)
# (array([26]),)
# (array([35]),)
# (array([10]),)
# (array([85]),)
# (array([51]),)
# (array([120]),)
# (array([188]),)
# (array([30]),)
# (array([139]),)
# (array([179]),)
# (array([140]),)
# (array([170]),)
# (array([162]),)
# (array([66]),)
# (array([60]),)
# (array([19]),)
# (array([92]),)
# (array([103]),)
# (array([125]),)
# (array([75]),)
# (array([124]),)
# (array([95]),)
# (array([115]),)
# (array([123]),)
# (array([149]),)
# (array([112]),)
# (array([105]),)
# (array([187]),)
# (array([57]),)
# (array([96]),)
# (array([94]),)
# (array([153]),)
# (array([160]),)
# (array([183]),)
# (array([142]),)
# (array([190]),)
# (array([174]),)
# (array([180]),)
# (array([52]),)
# (array([159]),)
# (array([97]),)
# (array([144]),)
# (array([31]),)
# (array([133]),)
# (array([117]),)
# (array([80]),)
# (array([193]),)
# (array([111]),)
# (array([186]),)
# (array([90]),)
# (array([165]),)
# (array([42]),)
# (array([109]),)
# (array([164]),)
# (array([157]),)
# (array([100]),)
# (array([54]),)
# (array([128]),)
# (array([8]),)
# (array([84]),)
# (array([137]),)
# (array([132]),)
# (array([45]),)
# (array([5]),)
# (array([14]),)
# (array([58]),)
# (array([36]),)
# (array([155]),)
# (array([63]),)
# (array([171]),)
# (array([22]),)
# (array([2]),)
# (array([77]),)
# (array([64]),)
# (array([28]),)
# (array([76]),)
# (array([156]),)
# (array([147]),)
# (array([79]),)
# (array([74]),)
# (array([102]),)
# (array([73]),)
# (array([131]),)
# (array([3]),)
# (array([44]),)
# (array([135]),)
# (array([121]),)
# (array([176]),)
# (array([27]),)
# (array([167]),)
# (array([39]),)
# (array([33]),)
# (array([48]),)
# (array([129]),)
# (array([146]),)
# (array([177]),)
# (array([89]),)
# (array([67]),)
# (array([87]),)
# (array([99]),)
# (array([88]),)
# (array([166]),)
# (array([72]),)
# (array([122]),)
# (array([78]),)
# (array([130]),)
# (array([20]),)
# (array([101]),)
# (array([192]),)
# (array([104]),)
# (array([59]),)
# (array([25]),)
# (array([65]),)
# (array([61]),)
# (array([173]),)
# (array([152]),)
# (array([98]),)
# (array([83]),)
# (array([126]),)
# (array([181]),)
# (array([14]),)
# (array([49]),)
# (array([132]),)
# (array([48]),)
# (array([69]),)
# (array([9]),)
# (array([73]),)
# (array([86]),)
# (array([150]),)
# (array([24]),)
# (array([37]),)
# (array([179]),)
# (array([135]),)
# (array([34]),)
# (array([28]),)
# (array([61]),)
# (array([124]),)
# (array([121]),)
# (array([3]),)
# (array([53]),)
# (array([29]),)
# (array([95]),)
# (array([147]),)
# (array([10]),)
# (array([25]),)
# (array([21]),)
# (array([125]),)
# (array([119]),)
# (array([7]),)
# (array([90]),)
# (array([134]),)
# (array([106]),)
# (array([92]),)
# (array([59]),)
# (array([133]),)
# (array([43]),)
# (array([80]),)
# (array([47]),)
# (array([137]),)
# (array([180]),)
# (array([111]),)
# (array([129]),)
# (array([30]),)
# (array([158]),)
# (array([54]),)
# (array([122]),)
# (array([139]),)
# (array([155]),)
# (array([103]),)
# (array([23]),)
# (array([94]),)
# (array([107]),)
# (array([128]),)
# (array([100]),)
# (array([13]),)
# (array([98]),)
# (array([50]),)
# (array([16]),)
# (array([12]),)
# (array([0]),)
# (array([19]),)
# (array([27]),)
# (array([157]),)
# (array([20]),)
# (array([57]),)
# (array([116]),)
# (array([18]),)
# (array([97]),)
# (array([36]),)
# (array([26]),)
# (array([2]),)
# (array([65]),)
# (array([78]),)
# (array([88]),)
# (array([146]),)
# (array([46]),)
# (array([114]),)
# (array([171]),)
# (array([154]),)
# (array([183]),)
# (array([153]),)
# (array([70]),)
# (array([99]),)
# (array([72]),)
# (array([140]),)
# (array([167]),)
# (array([105]),)
# (array([131]),)
# (array([142]),)
# (array([87]),)
# (array([83]),)
# (array([77]),)
# (array([93]),)
# (array([112]),)
# (array([143]),)
# (array([82]),)
# (array([149]),)
# (array([145]),)
# (array([175]),)
# (array([166]),)
# (array([115]),)
# (array([110]),)
# (array([184]),)
# (array([118]),)
# (array([109]),)
# (array([177]),)
# (array([89]),)
# (array([168]),)
# (array([35]),)
# (array([58]),)
# (array([156]),)
# (array([91]),)
# (array([181]),)
# (array([136]),)
# (array([84]),)
# (array([127]),)
# (array([162]),)
# (array([56]),)
# (array([113]),)
# (array([117]),)
# (array([182]),)
# (array([108]),)
# (array([141]),)
# (array([74]),)
# (array([5]),)
# (array([71]),)
# (array([178]),)
# (array([55]),)
# (array([45]),)
# (array([6]),)
# (array([11]),)
# (array([60]),)
# (array([68]),)
# (array([174]),)
# (array([62]),)
# (array([152]),)
# (array([38]),)
# (array([1]),)
# (array([52]),)
# (array([76]),)
# (array([33]),)
# (array([126]),)
# (array([169]),)
# (array([164]),)
# (array([75]),)
# (array([148]),)
# (array([81]),)
# (array([104]),)
# (array([151]),)
# (array([4]),)
# (array([130]),)
# (array([159]),)
# (array([144]),)
# (array([163]),)
# (array([40]),)
# (array([170]),)
# (array([22]),)
# (array([44]),)
# (array([123]),)
# (array([120]),)
# (array([51]),)
# (array([161]),)
# (array([66]),)
# (array([41]),)
# (array([64]),)
# (array([102]),)
# (array([138]),)
# (array([176]),)
# (array([173]),)
# (array([67]),)
# (array([96]),)
# (array([42]),)
# (array([15]),)
# (array([79]),)
# (array([85]),)
# (array([63]),)
# (array([8]),)
# (array([17]),)
# (array([32]),)
# (array([160]),)
# (array([165]),)
# (array([31]),)
# (array([39]),)
# (array([101]),)
# (array([172]),)
# (array([29]),)
# (array([31]),)
# (array([175]),)
# (array([39]),)
# (array([174]),)
# (array([46]),)
# (array([133]),)
# (array([139]),)
# (array([41]),)
# (array([17]),)
# (array([166]),)
# (array([74]),)
# (array([101]),)
# (array([52]),)
# (array([115]),)
# (array([145]),)
# (array([19]),)
# (array([22]),)
# (array([24]),)
# (array([142]),)
# (array([0]),)
# (array([25]),)
# (array([12]),)
# (array([58]),)
# (array([168]),)
# (array([2]),)
# (array([75]),)
# (array([134]),)
# (array([77]),)
# (array([114]),)
# (array([160]),)
# (array([138]),)
# (array([79]),)
# (array([78]),)
# (array([80]),)
# (array([106]),)
# (array([128]),)
# (array([76]),)
# (array([64]),)
# (array([68]),)
# (array([129]),)
# (array([126]),)
# (array([100]),)
# (array([155]),)
# (array([103]),)
# (array([97]),)
# (array([10]),)
# (array([125]),)
# (array([176]),)
# (array([91]),)
# (array([130]),)
# (array([35]),)
# (array([112]),)
# (array([71]),)
# (array([89]),)
# (array([37]),)
# (array([3]),)
# (array([15]),)
# (array([21]),)
# (array([172]),)
# (array([102]),)
# (array([173]),)
# (array([140]),)
# (array([7]),)
# (array([146]),)
# (array([11]),)
# (array([20]),)
# (array([1]),)
# (array([59]),)
# (array([87]),)
# (array([82]),)
# (array([116]),)
# (array([63]),)
# (array([131]),)
# (array([118]),)
# (array([170]),)
# (array([147]),)
# (array([141]),)
# (array([61]),)
# (array([69]),)
# (array([43]),)
# (array([144]),)
# (array([169]),)
# (array([47]),)
# (array([70]),)
# (array([38]),)
# (array([90]),)
# (array([60]),)
# (array([53]),)
# (array([149]),)
# (array([124]),)
# (array([161]),)
# (array([33]),)
# (array([104]),)
# (array([28]),)
# (array([148]),)
# (array([137]),)
# (array([83]),)
# (array([165]),)
# (array([54]),)
# (array([88]),)
# (array([98]),)
# (array([65]),)
# (array([154]),)
# (array([72]),)
# (array([49]),)
# (array([156]),)
# (array([119]),)
# (array([153]),)
# (array([32]),)
# (array([81]),)
# (array([96]),)
# (array([51]),)
# (array([45]),)
# (array([132]),)
# (array([117]),)
# (array([167]),)
# (array([162]),)
# (array([99]),)
# (array([4]),)
# (array([108]),)
# (array([113]),)
# (array([84]),)
# (array([23]),)
# (array([27]),)
# (array([143]),)
# (array([67]),)
# (array([94]),)
# (array([30]),)
# (array([152]),)
# (array([36]),)
# (array([18]),)
# (array([34]),)
# (array([109]),)
# (array([85]),)
# (array([135]),)
# (array([164]),)
# (array([171]),)
# (array([42]),)
# (array([123]),)
# (array([86]),)
# (array([159]),)
# (array([122]),)
# (array([13]),)
# (array([110]),)
# (array([158]),)
# (array([127]),)
# (array([93]),)
# (array([121]),)
# (array([26]),)
# (array([55]),)
# (array([157]),)
# (array([105]),)
# (array([57]),)
# (array([136]),)
# (array([40]),)
# (array([14]),)
# (array([95]),)
# (array([62]),)
# (array([66]),)
# (array([150]),)
# (array([50]),)
# (array([107]),)
# (array([44]),)
# (array([6]),)
# (array([92]),)
# (array([56]),)
# (array([111]),)
# (array([9]),)
# (array([16]),)
# (array([48]),)
# (array([120]),)
# (array([151]),)
# (array([5]),)
# (array([8]),)
# (array([73]),)
# (array([163]),)
# (array([3]),)
# (array([71]),)
# (array([72]),)
# (array([6]),)
# (array([24]),)
# (array([41]),)
# (array([104]),)
# (array([162]),)
# (array([19]),)
# (array([63]),)
# (array([82]),)
# (array([138]),)
# (array([69]),)
# (array([18]),)
# (array([22]),)
# (array([13]),)
# (array([27]),)
# (array([64]),)
# (array([59]),)
# (array([150]),)
# (array([2]),)
# (array([21]),)
# (array([10]),)
# (array([107]),)
# (array([67]),)
# (array([42]),)
# (array([160]),)
# (array([161]),)
# (array([118]),)
# (array([114]),)
# (array([148]),)
# (array([99]),)
# (array([85]),)
# (array([61]),)
# (array([31]),)
# (array([90]),)
# (array([122]),)
# (array([11]),)
# (array([53]),)
# (array([120]),)
# (array([116]),)
# (array([153]),)
# (array([115]),)
# (array([5]),)
# (array([60]),)
# (array([111]),)
# (array([149]),)
# (array([156]),)
# (array([32]),)
# (array([147]),)
# (array([84]),)
# (array([49]),)
# (array([33]),)
# (array([1]),)
# (array([15]),)
# (array([17]),)
# (array([48]),)
# (array([159]),)
# (array([165]),)
# (array([38]),)
# (array([95]),)
# (array([58]),)
# (array([20]),)
# (array([9]),)
# (array([79]),)
# (array([62]),)
# (array([52]),)
# (array([131]),)
# (array([34]),)
# (array([143]),)
# (array([164]),)
# (array([134]),)
# (array([155]),)
# (array([112]),)
# (array([65]),)
# (array([57]),)
# (array([44]),)
# (array([132]),)
# (array([130]),)
# (array([127]),)
# (array([128]),)
# (array([121]),)
# (array([81]),)
# (array([110]),)
# (array([117]),)
# (array([133]),)
# (array([108]),)
# (array([135]),)
# (array([56]),)
# (array([87]),)
# (array([109]),)
# (array([141]),)
# (array([102]),)
# (array([146]),)
# (array([136]),)
# (array([94]),)
# (array([30]),)
# (array([101]),)
# (array([70]),)
# (array([46]),)
# (array([100]),)
# (array([83]),)
# (array([163]),)
# (array([119]),)
# (array([35]),)
# (array([25]),)
# (array([92]),)
# (array([124]),)
# (array([142]),)
# (array([139]),)
# (array([89]),)
# (array([0]),)
# (array([68]),)
# (array([125]),)
# (array([97]),)
# (array([8]),)
# (array([39]),)
# (array([86]),)
# (array([54]),)
# (array([152]),)
# (array([43]),)
# (array([158]),)
# (array([29]),)
# (array([4]),)
# (array([37]),)
# (array([91]),)
# (array([26]),)
# (array([123]),)
# (array([144]),)
# (array([166]),)
# (array([55]),)
# (array([77]),)
# (array([45]),)
# (array([113]),)
# (array([88]),)
# (array([7]),)
# (array([51]),)
# (array([151]),)
# (array([93]),)
# (array([75]),)
# (array([167]),)
# (array([23]),)
# (array([14]),)
# (array([28]),)
# (array([36]),)
# (array([73]),)
# (array([154]),)
# (array([106]),)
# (array([66]),)
# (array([96]),)
# (array([40]),)
# (array([98]),)
# (array([137]),)
# (array([74]),)
# (array([129]),)
# (array([145]),)
# (array([105]),)
# (array([103]),)
# (array([50]),)
# (array([16]),)
# (array([12]),)
# (array([47]),)
# (array([78]),)
# (array([140]),)
# (array([126]),)
# (array([76]),)
# (array([80]),)
# (array([157]),)
# (array([33]),)
# (array([48]),)
# (array([147]),)
# (array([26]),)
# (array([103]),)
# (array([42]),)
# (array([131]),)
# (array([129]),)
# (array([38]),)
# (array([5]),)
# (array([159]),)
# (array([78]),)
# (array([39]),)
# (array([24]),)
# (array([50]),)
# (array([148]),)
# (array([0]),)
# (array([30]),)
# (array([6]),)
# (array([101]),)
# (array([7]),)
# (array([9]),)
# (array([13]),)
# (array([64]),)
# (array([83]),)
# (array([1]),)
# (array([69]),)
# (array([119]),)
# (array([155]),)
# (array([55]),)
# (array([87]),)
# (array([66]),)
# (array([44]),)
# (array([18]),)
# (array([152]),)
# (array([62]),)
# (array([19]),)
# (array([70]),)
# (array([116]),)
# (array([126]),)
# (array([153]),)
# (array([98]),)
# (array([27]),)
# (array([124]),)
# (array([127]),)
# (array([86]),)
# (array([133]),)
# (array([28]),)
# (array([150]),)
# (array([93]),)
# (array([121]),)
# (array([102]),)
# (array([14]),)
# (array([12]),)
# (array([15]),)
# (array([53]),)
# (array([90]),)
# (array([35]),)
# (array([79]),)
# (array([68]),)
# (array([10]),)
# (array([59]),)
# (array([120]),)
# (array([111]),)
# (array([151]),)
# (array([52]),)
# (array([100]),)
# (array([139]),)
# (array([136]),)
# (array([140]),)
# (array([134]),)
# (array([75]),)
# (array([40]),)
# (array([135]),)
# (array([157]),)
# (array([58]),)
# (array([113]),)
# (array([109]),)
# (array([125]),)
# (array([88]),)
# (array([72]),)
# (array([138]),)
# (array([104]),)
# (array([142]),)
# (array([41]),)
# (array([106]),)
# (array([95]),)
# (array([67]),)
# (array([92]),)
# (array([63]),)
# (array([105]),)
# (array([34]),)
# (array([91]),)
# (array([80]),)
# (array([97]),)
# (array([31]),)
# (array([85]),)
# (array([145]),)
# (array([20]),)
# (array([45]),)
# (array([115]),)
# (array([122]),)
# (array([144]),)
# (array([132]),)
# (array([137]),)
# (array([2]),)
# (array([107]),)
# (array([74]),)
# (array([49]),)
# (array([11]),)
# (array([16]),)
# (array([146]),)
# (array([123]),)
# (array([96]),)
# (array([60]),)
# (array([118]),)
# (array([47]),)
# (array([4]),)
# (array([57]),)
# (array([77]),)
# (array([21]),)
# (array([112]),)
# (array([143]),)
# (array([128]),)
# (array([46]),)
# (array([71]),)
# (array([54]),)
# (array([81]),)
# (array([114]),)
# (array([3]),)
# (array([156]),)
# (array([158]),)
# (array([117]),)
# (array([43]),)
# (array([36]),)
# (array([73]),)
# (array([84]),)
# (array([94]),)
# (array([61]),)
# (array([154]),)
# (array([130]),)
# (array([56]),)
# (array([65]),)
# (array([76]),)
# (array([99]),)
# (array([29]),)
# (array([89]),)
# (array([110]),)
# (array([25]),)
# (array([108]),)
# (array([37]),)
# (array([23]),)
# (array([8]),)
# (array([22]),)
# (array([51]),)
# (array([149]),)
# (array([17]),)
# (array([32]),)
# (array([82]),)
# (array([141]),)
# (array([5]),)
# (array([8]),)
# (array([152]),)
# (array([45]),)
# (array([17]),)
# (array([69]),)
# (array([141]),)
# (array([128]),)
# (array([22]),)
# (array([21]),)
# (array([88]),)
# (array([65]),)
# (array([28]),)
# (array([73]),)
# (array([70]),)
# (array([14]),)
# (array([23]),)
# (array([3]),)
# (array([81]),)
# (array([26]),)
# (array([0]),)
# (array([4]),)
# (array([62]),)
# (array([146]),)
# (array([44]),)
# (array([145]),)
# (array([150]),)
# (array([56]),)
# (array([124]),)
# (array([122]),)
# (array([85]),)
# (array([121]),)
# (array([53]),)
# (array([96]),)
# (array([108]),)
# (array([33]),)
# (array([82]),)
# (array([144]),)
# (array([134]),)
# (array([129]),)
# (array([89]),)
# (array([12]),)
# (array([66]),)
# (array([83]),)
# (array([117]),)
# (array([18]),)
# (array([103]),)
# (array([47]),)
# (array([34]),)
# (array([27]),)
# (array([1]),)
# (array([35]),)
# (array([32]),)
# (array([16]),)
# (array([130]),)
# (array([11]),)
# (array([37]),)
# (array([15]),)
# (array([20]),)
# (array([52]),)
# (array([49]),)
# (array([84]),)
# (array([132]),)
# (array([43]),)
# (array([110]),)
# (array([127]),)
# (array([123]),)
# (array([79]),)
# (array([63]),)
# (array([6]),)
# (array([109]),)
# (array([138]),)
# (array([142]),)
# (array([71]),)
# (array([77]),)
# (array([39]),)
# (array([86]),)
# (array([111]),)
# (array([120]),)
# (array([107]),)
# (array([100]),)
# (array([58]),)
# (array([54]),)
# (array([46]),)
# (array([78]),)
# (array([151]),)
# (array([75]),)
# (array([119]),)
# (array([118]),)
# (array([80]),)
# (array([114]),)
# (array([51]),)
# (array([149]),)
# (array([112]),)
# (array([9]),)
# (array([59]),)
# (array([76]),)
# (array([115]),)
# (array([94]),)
# (array([105]),)
# (array([2]),)
# (array([24]),)
# (array([90]),)
# (array([93]),)
# (array([7]),)
# (array([25]),)
# (array([98]),)
# (array([61]),)
# (array([102]),)
# (array([48]),)
# (array([137]),)
# (array([42]),)
# (array([13]),)
# (array([38]),)
# (array([113]),)
# (array([74]),)
# (array([148]),)
# (array([136]),)
# (array([101]),)
# (array([99]),)
# (array([64]),)
# (array([95]),)
# (array([72]),)
# (array([10]),)
# (array([40]),)
# (array([143]),)
# (array([97]),)
# (array([60]),)
# (array([19]),)
# (array([31]),)
# (array([30]),)
# (array([36]),)
# (array([125]),)
# (array([135]),)
# (array([92]),)
# (array([68]),)
# (array([126]),)
# (array([87]),)
# (array([67]),)
# (array([139]),)
# (array([140]),)
# (array([116]),)
# (array([41]),)
# (array([131]),)
# (array([57]),)
# (array([55]),)
# (array([29]),)
# (array([50]),)
# (array([133]),)
# (array([91]),)
# (array([104]),)
# (array([106]),)
# (array([147]),)
# (array([59]),)
# (array([36]),)
# (array([143]),)
# (array([61]),)
# (array([142]),)
# (array([102]),)
# (array([127]),)
# (array([96]),)
# (array([92]),)
# (array([48]),)
# (array([130]),)
# (array([43]),)
# (array([116]),)
# (array([15]),)
# (array([40]),)
# (array([8]),)
# (array([10]),)
# (array([5]),)
# (array([138]),)
# (array([1]),)
# (array([49]),)
# (array([0]),)
# (array([111]),)
# (array([139]),)
# (array([2]),)
# (array([115]),)
# (array([82]),)
# (array([28]),)
# (array([68]),)
# (array([77]),)
# (array([103]),)
# (array([79]),)
# (array([46]),)
# (array([71]),)
# (array([76]),)
# (array([29]),)
# (array([73]),)
# (array([106]),)
# (array([141]),)
# (array([58]),)
# (array([16]),)
# (array([85]),)
# (array([132]),)
# (array([99]),)
# (array([25]),)
# (array([90]),)
# (array([97]),)
# (array([81]),)
# (array([39]),)
# (array([6]),)
# (array([34]),)
# (array([31]),)
# (array([42]),)
# (array([104]),)
# (array([12]),)
# (array([27]),)
# (array([72]),)
# (array([9]),)
# (array([126]),)
# (array([94]),)
# (array([114]),)
# (array([123]),)
# (array([66]),)
# (array([62]),)
# (array([131]),)
# (array([95]),)
# (array([87]),)
# (array([60]),)
# (array([17]),)
# (array([140]),)
# (array([70]),)
# (array([119]),)
# (array([69]),)
# (array([89]),)
# (array([118]),)
# (array([98]),)
# (array([133]),)
# (array([117]),)
# (array([37]),)
# (array([101]),)
# (array([44]),)
# (array([78]),)
# (array([107]),)
# (array([64]),)
# (array([100]),)
# (array([35]),)
# (array([93]),)
# (array([109]),)
# (array([23]),)
# (array([84]),)
# (array([124]),)
# (array([26]),)
# (array([41]),)
# (array([45]),)
# (array([53]),)
# (array([113]),)
# (array([137]),)
# (array([3]),)
# (array([67]),)
# (array([125]),)
# (array([88]),)
# (array([11]),)
# (array([38]),)
# (array([145]),)
# (array([108]),)
# (array([63]),)
# (array([20]),)
# (array([50]),)
# (array([13]),)
# (array([80]),)
# (array([110]),)
# (array([51]),)
# (array([19]),)
# (array([52]),)
# (array([32]),)
# (array([47]),)
# (array([134]),)
# (array([7]),)
# (array([121]),)
# (array([144]),)
# (array([129]),)
# (array([57]),)
# (array([14]),)
# (array([33]),)
# (array([122]),)
# (array([54]),)
# (array([55]),)
# (array([91]),)
# (array([74]),)
# (array([128]),)
# (array([24]),)
# (array([83]),)
# (array([30]),)
# (array([120]),)
# (array([86]),)
# (array([105]),)
# (array([112]),)
# (array([65]),)
# (array([75]),)
# (array([4]),)
# (array([21]),)
# (array([136]),)
# (array([22]),)
# (array([18]),)
# (array([56]),)
# (array([135]),)
# (array([82]),)
# (array([36]),)
# (array([46]),)
# (array([76]),)
# (array([131]),)
# (array([15]),)
# (array([35]),)
# (array([77]),)
# (array([75]),)
# (array([20]),)
# (array([90]),)
# (array([33]),)
# (array([22]),)
# (array([50]),)
# (array([28]),)
# (array([11]),)
# (array([7]),)
# (array([4]),)
# (array([92]),)
# (array([6]),)
# (array([19]),)
# (array([3]),)
# (array([134]),)
# (array([138]),)
# (array([1]),)
# (array([130]),)
# (array([64]),)
# (array([86]),)
# (array([111]),)
# (array([113]),)
# (array([78]),)
# (array([108]),)
# (array([51]),)
# (array([67]),)
# (array([68]),)
# (array([43]),)
# (array([89]),)
# (array([95]),)
# (array([126]),)
# (array([81]),)
# (array([12]),)
# (array([124]),)
# (array([114]),)
# (array([26]),)
# (array([105]),)
# (array([100]),)
# (array([112]),)
# (array([14]),)
# (array([57]),)
# (array([65]),)
# (array([101]),)
# (array([39]),)
# (array([66]),)
# (array([27]),)
# (array([21]),)
# (array([104]),)
# (array([109]),)
# (array([115]),)
# (array([137]),)
# (array([29]),)
# (array([120]),)
# (array([125]),)
# (array([38]),)
# (array([54]),)
# (array([56]),)
# (array([83]),)
# (array([136]),)
# (array([127]),)
# (array([93]),)
# (array([132]),)
# (array([84]),)
# (array([128]),)
# (array([61]),)
# (array([73]),)
# (array([121]),)
# (array([58]),)
# (array([96]),)
# (array([91]),)
# (array([87]),)
# (array([129]),)
# (array([31]),)
# (array([116]),)
# (array([99]),)
# (array([79]),)
# (array([88]),)
# (array([107]),)
# (array([37]),)
# (array([72]),)
# (array([117]),)
# (array([71]),)
# (array([69]),)
# (array([0]),)
# (array([80]),)
# (array([42]),)
# (array([30]),)
# (array([2]),)
# (array([18]),)
# (array([52]),)
# (array([23]),)
# (array([41]),)
# (array([44]),)
# (array([9]),)
# (array([32]),)
# (array([34]),)
# (array([10]),)
# (array([102]),)
# (array([133]),)
# (array([53]),)
# (array([110]),)
# (array([60]),)
# (array([8]),)
# (array([59]),)
# (array([123]),)
# (array([122]),)
# (array([25]),)
# (array([24]),)
# (array([47]),)
# (array([94]),)
# (array([48]),)
# (array([55]),)
# (array([85]),)
# (array([17]),)
# (array([74]),)
# (array([70]),)
# (array([106]),)
# (array([16]),)
# (array([119]),)
# (array([97]),)
# (array([40]),)
# (array([103]),)
# (array([45]),)
# (array([49]),)
# (array([5]),)
# (array([13]),)
# (array([118]),)
# (array([62]),)
# (array([63]),)
# (array([98]),)
# (array([135]),)
# (array([120]),)
# (array([70]),)
# (array([68]),)
# (array([102]),)
# (array([115]),)
# (array([15]),)
# (array([74]),)
# (array([109]),)
# (array([103]),)
# (array([23]),)
# (array([124]),)
# (array([50]),)
# (array([94]),)
# (array([27]),)
# (array([29]),)
# (array([43]),)
# (array([32]),)
# (array([10]),)
# (array([58]),)
# (array([1]),)
# (array([12]),)
# (array([3]),)
# (array([116]),)
# (array([110]),)
# (array([0]),)
# (array([91]),)
# (array([108]),)
# (array([88]),)
# (array([127]),)
# (array([56]),)
# (array([77]),)
# (array([60]),)
# (array([122]),)
# (array([54]),)
# (array([63]),)
# (array([98]),)
# (array([117]),)
# (array([129]),)
# (array([128]),)
# (array([18]),)
# (array([69]),)
# (array([112]),)
# (array([13]),)
# (array([113]),)
# (array([55]),)
# (array([80]),)
# (array([5]),)
# (array([37]),)
# (array([33]),)
# (array([97]),)
# (array([36]),)
# (array([51]),)
# (array([39]),)
# (array([4]),)
# (array([73]),)
# (array([90]),)
# (array([95]),)
# (array([114]),)
# (array([21]),)
# (array([52]),)
# (array([104]),)
# (array([76]),)
# (array([25]),)
# (array([44]),)
# (array([111]),)
# (array([62]),)
# (array([71]),)
# (array([83]),)
# (array([57]),)
# (array([72]),)
# (array([105]),)
# (array([41]),)
# (array([101]),)
# (array([92]),)
# (array([75]),)
# (array([61]),)
# (array([38]),)
# (array([20]),)
# (array([119]),)
# (array([118]),)
# (array([28]),)
# (array([34]),)
# (array([30]),)
# (array([47]),)
# (array([81]),)
# (array([125]),)
# (array([131]),)
# (array([8]),)
# (array([99]),)
# (array([100]),)
# (array([86]),)
# (array([17]),)
# (array([24]),)
# (array([132]),)
# (array([96]),)
# (array([26]),)
# (array([42]),)
# (array([6]),)
# (array([49]),)
# (array([40]),)
# (array([65]),)
# (array([48]),)
# (array([87]),)
# (array([67]),)
# (array([59]),)
# (array([7]),)
# (array([123]),)
# (array([93]),)
# (array([78]),)
# (array([9]),)
# (array([66]),)
# (array([107]),)
# (array([64]),)
# (array([35]),)
# (array([53]),)
# (array([19]),)
# (array([89]),)
# (array([46]),)
# (array([130]),)
# (array([31]),)
# (array([106]),)
# (array([84]),)
# (array([14]),)
# (array([82]),)
# (array([45]),)
# (array([22]),)
# (array([2]),)
# (array([11]),)
# (array([79]),)
# (array([16]),)
# (array([85]),)
# (array([126]),)
# (array([121]),)
# (array([60]),)
# (array([76]),)
# (array([119]),)
# (array([111]),)
# (array([124]),)
# (array([14]),)
# (array([89]),)
# (array([115]),)
# (array([88]),)
# (array([50]),)
# (array([110]),)
# (array([98]),)
# (array([25]),)
# (array([27]),)
# (array([23]),)
# (array([8]),)
# (array([26]),)
# (array([9]),)
# (array([90]),)
# (array([6]),)
# (array([32]),)
# (array([19]),)
# (array([118]),)
# (array([122]),)
# (array([2]),)
# (array([91]),)
# (array([84]),)
# (array([62]),)
# (array([68]),)
# (array([83]),)
# (array([80]),)
# (array([44]),)
# (array([103]),)
# (array([95]),)
# (array([46]),)
# (array([92]),)
# (array([112]),)
# (array([123]),)
# (array([109]),)
# (array([40]),)
# (array([73]),)
# (array([106]),)
# (array([22]),)
# (array([57]),)
# (array([53]),)
# (array([18]),)
# (array([5]),)
# (array([38]),)
# (array([74]),)
# (array([33]),)
# (array([15]),)
# (array([10]),)
# (array([45]),)
# (array([1]),)
# (array([87]),)
# (array([99]),)
# (array([93]),)
# (array([116]),)
# (array([55]),)
# (array([96]),)
# (array([54]),)
# (array([36]),)
# (array([43]),)
# (array([75]),)
# (array([120]),)
# (array([77]),)
# (array([79]),)
# (array([70]),)
# (array([71]),)
# (array([107]),)
# (array([28]),)
# (array([114]),)
# (array([63]),)
# (array([65]),)
# (array([121]),)
# (array([105]),)
# (array([24]),)
# (array([117]),)
# (array([72]),)
# (array([100]),)
# (array([31]),)
# (array([64]),)
# (array([82]),)
# (array([3]),)
# (array([61]),)
# (array([52]),)
# (array([49]),)
# (array([12]),)
# (array([16]),)
# (array([108]),)
# (array([47]),)
# (array([41]),)
# (array([30]),)
# (array([4]),)
# (array([51]),)
# (array([69]),)
# (array([17]),)
# (array([56]),)
# (array([48]),)
# (array([97]),)
# (array([7]),)
# (array([102]),)
# (array([104]),)
# (array([59]),)
# (array([37]),)
# (array([101]),)
# (array([66]),)
# (array([35]),)
# (array([81]),)
# (array([39]),)
# (array([42]),)
# (array([58]),)
# (array([11]),)
# (array([85]),)
# (array([78]),)
# (array([20]),)
# (array([113]),)
# (array([67]),)
# (array([29]),)
# (array([0]),)
# (array([21]),)
# (array([86]),)
# (array([13]),)
# (array([34]),)
# (array([94]),)
# (array([125]),)
# (array([35]),)
# (array([14]),)
# (array([32]),)
# (array([112]),)
# (array([45]),)
# (array([118]),)
# (array([91]),)
# (array([25]),)
# (array([59]),)
# (array([108]),)
# (array([90]),)
# (array([70]),)
# (array([100]),)
# (array([55]),)
# (array([2]),)
# (array([26]),)
# (array([11]),)
# (array([86]),)
# (array([1]),)
# (array([19]),)
# (array([13]),)
# (array([72]),)
# (array([92]),)
# (array([0]),)
# (array([117]),)
# (array([49]),)
# (array([80]),)
# (array([99]),)
# (array([67]),)
# (array([116]),)
# (array([31]),)
# (array([107]),)
# (array([81]),)
# (array([37]),)
# (array([105]),)
# (array([61]),)
# (array([95]),)
# (array([4]),)
# (array([111]),)
# (array([62]),)
# (array([10]),)
# (array([42]),)
# (array([56]),)
# (array([96]),)
# (array([12]),)
# (array([103]),)
# (array([87]),)
# (array([74]),)
# (array([23]),)
# (array([36]),)
# (array([21]),)
# (array([16]),)
# (array([104]),)
# (array([79]),)
# (array([54]),)
# (array([119]),)
# (array([43]),)
# (array([73]),)
# (array([63]),)
# (array([64]),)
# (array([58]),)
# (array([66]),)
# (array([77]),)
# (array([109]),)
# (array([53]),)
# (array([48]),)
# (array([110]),)
# (array([50]),)
# (array([75]),)
# (array([102]),)
# (array([89]),)
# (array([68]),)
# (array([57]),)
# (array([8]),)
# (array([93]),)
# (array([113]),)
# (array([69]),)
# (array([46]),)
# (array([97]),)
# (array([5]),)
# (array([106]),)
# (array([60]),)
# (array([41]),)
# (array([9]),)
# (array([7]),)
# (array([85]),)
# (array([18]),)
# (array([65]),)
# (array([34]),)
# (array([3]),)
# (array([47]),)
# (array([27]),)
# (array([22]),)
# (array([82]),)
# (array([44]),)
# (array([83]),)
# (array([15]),)
# (array([78]),)
# (array([114]),)
# (array([28]),)
# (array([33]),)
# (array([115]),)
# (array([88]),)
# (array([17]),)
# (array([38]),)
# (array([20]),)
# (array([84]),)
# (array([98]),)
# (array([51]),)
# (array([101]),)
# (array([76]),)
# (array([29]),)
# (array([71]),)
# (array([39]),)
# (array([30]),)
# (array([6]),)
# (array([52]),)
# (array([40]),)
# (array([24]),)
# (array([94]),)
# (array([120]),)
# (array([16]),)
# (array([35]),)
# (array([102]),)
# (array([4]),)
# (array([48]),)
# (array([26]),)
# (array([77]),)
# (array([55]),)
# (array([13]),)
# (array([95]),)
# (array([91]),)
# (array([59]),)
# (array([12]),)
# (array([40]),)
# (array([1]),)
# (array([65]),)
# (array([33]),)
# (array([64]),)
# (array([5]),)
# (array([27]),)
# (array([8]),)
# (array([86]),)
# (array([56]),)
# (array([28]),)
# (array([75]),)
# (array([105]),)
# (array([32]),)
# (array([83]),)
# (array([87]),)
# (array([101]),)
# (array([73]),)
# (array([54]),)
# (array([42]),)
# (array([7]),)
# (array([107]),)
# (array([19]),)
# (array([22]),)
# (array([67]),)
# (array([98]),)
# (array([11]),)
# (array([60]),)
# (array([52]),)
# (array([97]),)
# (array([9]),)
# (array([74]),)
# (array([23]),)
# (array([15]),)
# (array([24]),)
# (array([113]),)
# (array([18]),)
# (array([14]),)
# (array([106]),)
# (array([47]),)
# (array([68]),)
# (array([58]),)
# (array([100]),)
# (array([103]),)
# (array([41]),)
# (array([21]),)
# (array([109]),)
# (array([90]),)
# (array([82]),)
# (array([81]),)
# (array([69]),)
# (array([94]),)
# (array([53]),)
# (array([112]),)
# (array([110]),)
# (array([66]),)
# (array([43]),)
# (array([46]),)
# (array([50]),)
# (array([51]),)
# (array([111]),)
# (array([0]),)
# (array([85]),)
# (array([3]),)
# (array([70]),)
# (array([78]),)
# (array([92]),)
# (array([20]),)
# (array([30]),)
# (array([17]),)
# (array([44]),)
# (array([34]),)
# (array([6]),)
# (array([63]),)
# (array([104]),)
# (array([31]),)
# (array([37]),)
# (array([36]),)
# (array([99]),)
# (array([2]),)
# (array([88]),)
# (array([80]),)
# (array([25]),)
# (array([61]),)
# (array([39]),)
# (array([57]),)
# (array([62]),)
# (array([71]),)
# (array([49]),)
# (array([96]),)
# (array([84]),)
# (array([89]),)
# (array([93]),)
# (array([114]),)
# (array([45]),)
# (array([29]),)
# (array([10]),)
# (array([76]),)
# (array([108]),)
# (array([79]),)
# (array([38]),)
# (array([72]),)
# (array([25]),)
# (array([32]),)
# (array([38]),)
# (array([91]),)
# (array([52]),)
# (array([87]),)
# (array([77]),)
# (array([44]),)
# (array([23]),)
# (array([93]),)
# (array([43]),)
# (array([42]),)
# (array([12]),)
# (array([39]),)
# (array([0]),)
# (array([22]),)
# (array([7]),)
# (array([102]),)
# (array([1]),)
# (array([51]),)
# (array([9]),)
# (array([94]),)
# (array([88]),)
# (array([6]),)
# (array([65]),)
# (array([68]),)
# (array([18]),)
# (array([54]),)
# (array([109]),)
# (array([105]),)
# (array([26]),)
# (array([67]),)
# (array([97]),)
# (array([16]),)
# (array([92]),)
# (array([13]),)
# (array([86]),)
# (array([104]),)
# (array([19]),)
# (array([64]),)
# (array([96]),)
# (array([103]),)
# (array([14]),)
# (array([45]),)
# (array([31]),)
# (array([90]),)
# (array([27]),)
# (array([28]),)
# (array([11]),)
# (array([15]),)
# (array([57]),)
# (array([66]),)
# (array([73]),)
# (array([41]),)
# (array([78]),)
# (array([61]),)
# (array([29]),)
# (array([62]),)
# (array([82]),)
# (array([106]),)
# (array([69]),)
# (array([74]),)
# (array([63]),)
# (array([60]),)
# (array([85]),)
# (array([108]),)
# (array([58]),)
# (array([71]),)
# (array([33]),)
# (array([81]),)
# (array([95]),)
# (array([35]),)
# (array([46]),)
# (array([3]),)
# (array([76]),)
# (array([50]),)
# (array([47]),)
# (array([8]),)
# (array([4]),)
# (array([17]),)
# (array([79]),)
# (array([30]),)
# (array([2]),)
# (array([48]),)
# (array([83]),)
# (array([21]),)
# (array([72]),)
# (array([24]),)
# (array([5]),)
# (array([89]),)
# (array([36]),)
# (array([20]),)
# (array([107]),)
# (array([100]),)
# (array([70]),)
# (array([49]),)
# (array([56]),)
# (array([101]),)
# (array([53]),)
# (array([98]),)
# (array([59]),)
# (array([40]),)
# (array([99]),)
# (array([34]),)
# (array([80]),)
# (array([10]),)
# (array([84]),)
# (array([55]),)
# (array([37]),)
# (array([75]),)
# (array([20]),)
# (array([23]),)
# (array([79]),)
# (array([41]),)
# (array([44]),)
# (array([102]),)
# (array([81]),)
# (array([85]),)
# (array([9]),)
# (array([80]),)
# (array([61]),)
# (array([6]),)
# (array([65]),)
# (array([0]),)
# (array([56]),)
# (array([4]),)
# (array([103]),)
# (array([5]),)
# (array([21]),)
# (array([30]),)
# (array([35]),)
# (array([45]),)
# (array([11]),)
# (array([63]),)
# (array([97]),)
# (array([22]),)
# (array([88]),)
# (array([86]),)
# (array([36]),)
# (array([78]),)
# (array([14]),)
# (array([49]),)
# (array([72]),)
# (array([12]),)
# (array([50]),)
# (array([3]),)
# (array([76]),)
# (array([73]),)
# (array([98]),)
# (array([32]),)
# (array([29]),)
# (array([15]),)
# (array([33]),)
# (array([7]),)
# (array([64]),)
# (array([17]),)
# (array([39]),)
# (array([47]),)
# (array([52]),)
# (array([93]),)
# (array([25]),)
# (array([84]),)
# (array([95]),)
# (array([48]),)
# (array([40]),)
# (array([83]),)
# (array([96]),)
# (array([60]),)
# (array([67]),)
# (array([26]),)
# (array([69]),)
# (array([53]),)
# (array([46]),)
# (array([28]),)
# (array([62]),)
# (array([77]),)
# (array([66]),)
# (array([1]),)
# (array([100]),)
# (array([2]),)
# (array([71]),)
# (array([94]),)
# (array([87]),)
# (array([19]),)
# (array([38]),)
# (array([59]),)
# (array([34]),)
# (array([37]),)
# (array([13]),)
# (array([75]),)
# (array([101]),)
# (array([91]),)
# (array([16]),)
# (array([24]),)
# (array([10]),)
# (array([90]),)
# (array([43]),)
# (array([8]),)
# (array([55]),)
# (array([58]),)
# (array([42]),)
# (array([89]),)
# (array([57]),)
# (array([70]),)
# (array([82]),)
# (array([68]),)
# (array([51]),)
# (array([99]),)
# (array([31]),)
# (array([18]),)
# (array([92]),)
# (array([54]),)
# (array([27]),)
# (array([74]),)
# (array([29]),)
# (array([21]),)
# (array([83]),)
# (array([75]),)
# (array([6]),)
# (array([85]),)
# (array([89]),)
# (array([27]),)
# (array([90]),)
# (array([33]),)
# (array([17]),)
# (array([68]),)
# (array([3]),)
# (array([82]),)
# (array([26]),)
# (array([52]),)
# (array([0]),)
# (array([7]),)
# (array([54]),)
# (array([66]),)
# (array([87]),)
# (array([4]),)
# (array([20]),)
# (array([76]),)
# (array([28]),)
# (array([78]),)
# (array([63]),)
# (array([31]),)
# (array([47]),)
# (array([88]),)
# (array([35]),)
# (array([56]),)
# (array([12]),)
# (array([98]),)
# (array([22]),)
# (array([64]),)
# (array([91]),)
# (array([50]),)
# (array([39]),)
# (array([25]),)
# (array([93]),)
# (array([40]),)
# (array([81]),)
# (array([14]),)
# (array([13]),)
# (array([96]),)
# (array([71]),)
# (array([65]),)
# (array([72]),)
# (array([79]),)
# (array([86]),)
# (array([38]),)
# (array([34]),)
# (array([99]),)
# (array([97]),)
# (array([94]),)
# (array([19]),)
# (array([36]),)
# (array([95]),)
# (array([30]),)
# (array([15]),)
# (array([23]),)
# (array([58]),)
# (array([67]),)
# (array([9]),)
# (array([61]),)
# (array([2]),)
# (array([45]),)
# (array([32]),)
# (array([46]),)
# (array([5]),)
# (array([18]),)
# (array([44]),)
# (array([48]),)
# (array([43]),)
# (array([8]),)
# (array([41]),)
# (array([92]),)
# (array([16]),)
# (array([74]),)
# (array([11]),)
# (array([1]),)
# (array([70]),)
# (array([24]),)
# (array([73]),)
# (array([57]),)
# (array([49]),)
# (array([80]),)
# (array([62]),)
# (array([42]),)
# (array([77]),)
# (array([37]),)
# (array([60]),)
# (array([69]),)
# (array([55]),)
# (array([10]),)
# (array([51]),)
# (array([53]),)
# (array([59]),)
# (array([84]),)
# (array([12]),)
# (array([10]),)
# (array([57]),)
# (array([67]),)
# (array([42]),)
# (array([83]),)
# (array([37]),)
# (array([2]),)
# (array([26]),)
# (array([62]),)
# (array([5]),)
# (array([27]),)
# (array([4]),)
# (array([25]),)
# (array([3]),)
# (array([76]),)
# (array([1]),)
# (array([18]),)
# (array([9]),)
# (array([75]),)
# (array([61]),)
# (array([6]),)
# (array([49]),)
# (array([93]),)
# (array([88]),)
# (array([59]),)
# (array([44]),)
# (array([24]),)
# (array([65]),)
# (array([50]),)
# (array([13]),)
# (array([80]),)
# (array([11]),)
# (array([74]),)
# (array([90]),)
# (array([20]),)
# (array([46]),)
# (array([28]),)
# (array([82]),)
# (array([34]),)
# (array([92]),)
# (array([56]),)
# (array([31]),)
# (array([73]),)
# (array([52]),)
# (array([84]),)
# (array([39]),)
# (array([30]),)
# (array([68]),)
# (array([17]),)
# (array([77]),)
# (array([79]),)
# (array([47]),)
# (array([72]),)
# (array([86]),)
# (array([94]),)
# (array([33]),)
# (array([29]),)
# (array([32]),)
# (array([78]),)
# (array([15]),)
# (array([0]),)
# (array([91]),)
# (array([8]),)
# (array([51]),)
# (array([87]),)
# (array([19]),)
# (array([35]),)
# (array([23]),)
# (array([64]),)
# (array([54]),)
# (array([16]),)
# (array([43]),)
# (array([63]),)
# (array([53]),)
# (array([40]),)
# (array([22]),)
# (array([7]),)
# (array([89]),)
# (array([14]),)
# (array([45]),)
# (array([48]),)
# (array([38]),)
# (array([41]),)
# (array([81]),)
# (array([66]),)
# (array([69]),)
# (array([58]),)
# (array([60]),)
# (array([21]),)
# (array([36]),)
# (array([55]),)
# (array([71]),)
# (array([70]),)
# (array([85]),)
# (array([45]),)
# (array([62]),)
# (array([47]),)
# (array([65]),)
# (array([60]),)
# (array([81]),)
# (array([1]),)
# (array([38]),)
# (array([73]),)
# (array([4]),)
# (array([36]),)
# (array([8]),)
# (array([66]),)
# (array([25]),)
# (array([86]),)
# (array([0]),)
# (array([82]),)
# (array([3]),)
# (array([80]),)
# (array([51]),)
# (array([2]),)
# (array([68]),)
# (array([64]),)
# (array([42]),)
# (array([70]),)
# (array([22]),)
# (array([84]),)
# (array([17]),)
# (array([53]),)
# (array([5]),)
# (array([61]),)
# (array([27]),)
# (array([87]),)
# (array([58]),)
# (array([16]),)
# (array([71]),)
# (array([19]),)
# (array([77]),)
# (array([52]),)
# (array([44]),)
# (array([67]),)
# (array([49]),)
# (array([90]),)
# (array([10]),)
# (array([20]),)
# (array([41]),)
# (array([54]),)
# (array([76]),)
# (array([83]),)
# (array([48]),)
# (array([31]),)
# (array([57]),)
# (array([85]),)
# (array([37]),)
# (array([24]),)
# (array([29]),)
# (array([74]),)
# (array([23]),)
# (array([9]),)
# (array([69]),)
# (array([12]),)
# (array([88]),)
# (array([55]),)
# (array([11]),)
# (array([18]),)
# (array([33]),)
# (array([32]),)
# (array([40]),)
# (array([15]),)
# (array([50]),)
# (array([72]),)
# (array([46]),)
# (array([75]),)
# (array([14]),)
# (array([7]),)
# (array([63]),)
# (array([21]),)
# (array([43]),)
# (array([28]),)
# (array([59]),)
# (array([30]),)
# (array([34]),)
# (array([79]),)
# (array([56]),)
# (array([89]),)
# (array([35]),)
# (array([13]),)
# (array([78]),)
# (array([26]),)
# (array([6]),)
# (array([39]),)
# (array([31]),)
# (array([33]),)
# (array([52]),)
# (array([56]),)
# (array([53]),)
# (array([70]),)
# (array([4]),)
# (array([51]),)
# (array([78]),)
# (array([1]),)
# (array([76]),)
# (array([0]),)
# (array([59]),)
# (array([8]),)
# (array([79]),)
# (array([14]),)
# (array([17]),)
# (array([16]),)
# (array([77]),)
# (array([55]),)
# (array([3]),)
# (array([26]),)
# (array([75]),)
# (array([36]),)
# (array([84]),)
# (array([11]),)
# (array([80]),)
# (array([43]),)
# (array([27]),)
# (array([22]),)
# (array([72]),)
# (array([7]),)
# (array([83]),)
# (array([73]),)
# (array([39]),)
# (array([29]),)
# (array([30]),)
# (array([41]),)
# (array([6]),)
# (array([82]),)
# (array([34]),)
# (array([60]),)
# (array([69]),)
# (array([38]),)
# (array([28]),)
# (array([49]),)
# (array([35]),)
# (array([50]),)
# (array([85]),)
# (array([48]),)
# (array([40]),)
# (array([21]),)
# (array([44]),)
# (array([74]),)
# (array([23]),)
# (array([5]),)
# (array([46]),)
# (array([9]),)
# (array([47]),)
# (array([12]),)
# (array([13]),)
# (array([10]),)
# (array([63]),)
# (array([45]),)
# (array([65]),)
# (array([20]),)
# (array([57]),)
# (array([67]),)
# (array([37]),)
# (array([66]),)
# (array([24]),)
# (array([2]),)
# (array([64]),)
# (array([18]),)
# (array([54]),)
# (array([62]),)
# (array([61]),)
# (array([68]),)
# (array([32]),)
# (array([81]),)
# (array([25]),)
# (array([15]),)
# (array([71]),)
# (array([42]),)
# (array([19]),)
# (array([58]),)
# (array([29]),)
# (array([24]),)
# (array([57]),)
# (array([71]),)
# (array([52]),)
# (array([50]),)
# (array([7]),)
# (array([42]),)
# (array([67]),)
# (array([5]),)
# (array([36]),)
# (array([2]),)
# (array([37]),)
# (array([1]),)
# (array([68]),)
# (array([3]),)
# (array([30]),)
# (array([11]),)
# (array([69]),)
# (array([15]),)
# (array([0]),)
# (array([14]),)
# (array([76]),)
# (array([77]),)
# (array([80]),)
# (array([59]),)
# (array([60]),)
# (array([22]),)
# (array([51]),)
# (array([10]),)
# (array([74]),)
# (array([9]),)
# (array([65]),)
# (array([78]),)
# (array([33]),)
# (array([64]),)
# (array([27]),)
# (array([75]),)
# (array([28]),)
# (array([20]),)
# (array([26]),)
# (array([73]),)
# (array([17]),)
# (array([39]),)
# (array([18]),)
# (array([31]),)
# (array([43]),)
# (array([47]),)
# (array([79]),)
# (array([49]),)
# (array([54]),)
# (array([25]),)
# (array([81]),)
# (array([13]),)
# (array([4]),)
# (array([12]),)
# (array([46]),)
# (array([35]),)
# (array([16]),)
# (array([23]),)
# (array([72]),)
# (array([56]),)
# (array([63]),)
# (array([8]),)
# (array([58]),)
# (array([38]),)
# (array([61]),)
# (array([21]),)
# (array([6]),)
# (array([41]),)
# (array([48]),)
# (array([55]),)
# (array([44]),)
# (array([40]),)
# (array([62]),)
# (array([53]),)
# (array([32]),)
# (array([19]),)
# (array([66]),)
# (array([45]),)
# (array([34]),)
# (array([70]),)
# (array([22]),)
# (array([24]),)
# (array([59]),)
# (array([25]),)
# (array([62]),)
# (array([64]),)
# (array([7]),)
# (array([37]),)
# (array([53]),)
# (array([9]),)
# (array([46]),)
# (array([0]),)
# (array([44]),)
# (array([10]),)
# (array([73]),)
# (array([19]),)
# (array([6]),)
# (array([11]),)
# (array([54]),)
# (array([8]),)
# (array([76]),)
# (array([75]),)
# (array([77]),)
# ...
# (array([3]),)
# (array([21]),)
# (array([0]),)
# (array([34]),)
# (array([25]),)
# (array([10]),)
# (array([12]),)
# (array([40]),)
# (array([6]),)
# (array([8]),)
# (array([4]),)
# (array([36]),)
# (array([32]),)
# (array([12]),)
# (array([30]),)
# (array([17]),)
# (array([27]),)
# (array([1]),)
# (array([23]),)
# (array([16]),)
# (array([6]),)
# (array([28]),)
# (array([33]),)
# (array([25]),)
# (array([36]),)
# (array([5]),)
# (array([37]),)
# (array([14]),)
# (array([24]),)
# (array([19]),)
# (array([18]),)
# (array([26]),)
# (array([21]),)
# (array([11]),)
# (array([3]),)
# (array([15]),)
# (array([34]),)
# (array([31]),)
# (array([22]),)
# (array([7]),)
# (array([8]),)
# (array([13]),)
# (array([0]),)
# (array([38]),)
# (array([10]),)
# (array([29]),)
# (array([9]),)
# (array([39]),)
# (array([2]),)
# (array([20]),)
# (array([4]),)
# (array([35]),)
# (array([31]),)
# (array([14]),)
# (array([29]),)
# (array([8]),)
# (array([1]),)
# (array([35]),)
# (array([20]),)
# (array([9]),)
# (array([34]),)
# (array([19]),)
# (array([15]),)
# (array([37]),)
# (array([7]),)
# (array([26]),)
# (array([6]),)
# (array([11]),)
# (array([12]),)
# (array([18]),)
# (array([21]),)
# (array([25]),)
# (array([2]),)
# (array([13]),)
# (array([24]),)
# (array([36]),)
# (array([33]),)
# (array([30]),)
# (array([16]),)
# (array([10]),)
# (array([22]),)
# (array([0]),)
# (array([27]),)
# (array([3]),)
# (array([23]),)
# (array([28]),)
# (array([5]),)
# (array([17]),)
# (array([4]),)
# (array([32]),)
# (array([33]),)
# (array([16]),)
# (array([22]),)
# (array([19]),)
# (array([1]),)
# (array([36]),)
# (array([21]),)
# (array([12]),)
# (array([20]),)
# (array([30]),)
# (array([15]),)
# (array([8]),)
# (array([17]),)
# (array([34]),)
# (array([6]),)
# (array([7]),)
# (array([2]),)
# (array([28]),)
# (array([9]),)
# (array([26]),)
# (array([11]),)
# (array([4]),)
# (array([31]),)
# (array([27]),)
# (array([25]),)
# (array([18]),)
# (array([13]),)
# (array([23]),)
# (array([0]),)
# (array([24]),)
# (array([3]),)
# (array([29]),)
# (array([35]),)
# (array([14]),)
# (array([10]),)
# (array([5]),)
# (array([32]),)
# (array([34]),)
# (array([13]),)
# (array([28]),)
# (array([15]),)
# (array([5]),)
# (array([26]),)
# (array([10]),)
# (array([21]),)
# (array([16]),)
# (array([1]),)
# (array([29]),)
# (array([23]),)
# (array([20]),)
# (array([11]),)
# (array([19]),)
# (array([3]),)
# (array([22]),)
# (array([14]),)
# (array([32]),)
# (array([2]),)
# (array([25]),)
# (array([31]),)
# (array([27]),)
# (array([17]),)
# (array([6]),)
# (array([7]),)
# (array([24]),)
# (array([0]),)
# (array([8]),)
# (array([30]),)
# (array([12]),)
# (array([18]),)
# (array([4]),)
# (array([9]),)
# (array([33]),)
# (array([31]),)
# (array([14]),)
# (array([18]),)
# (array([19]),)
# (array([3]),)
# (array([32]),)
# (array([24]),)
# (array([5]),)
# (array([10]),)
# (array([20]),)
# (array([11]),)
# (array([27]),)
# (array([8]),)
# (array([7]),)
# (array([15]),)
# (array([9]),)
# (array([28]),)
# (array([17]),)
# (array([6]),)
# (array([4]),)
# (array([13]),)
# (array([29]),)
# (array([23]),)
# (array([25]),)
# (array([26]),)
# (array([16]),)
# (array([1]),)
# (array([2]),)
# (array([21]),)
# (array([22]),)
# (array([0]),)
# (array([12]),)
# (array([30]),)
# (array([30]),)
# (array([16]),)
# (array([13]),)
# (array([29]),)
# (array([3]),)
# (array([18]),)
# (array([14]),)
# (array([9]),)
# (array([23]),)
# (array([11]),)
# (array([24]),)
# (array([7]),)
# (array([12]),)
# (array([26]),)
# (array([2]),)
# (array([22]),)
# (array([4]),)
# (array([20]),)
# (array([6]),)
# (array([15]),)
# (array([31]),)
# (array([25]),)
# (array([21]),)
# (array([19]),)
# (array([5]),)
# (array([0]),)
# (array([8]),)
# (array([17]),)
# (array([27]),)
# (array([1]),)
# (array([10]),)
# (array([28]),)
# (array([27]),)
# (array([15]),)
# (array([24]),)
# (array([12]),)
# (array([6]),)
# (array([29]),)
# (array([11]),)
# (array([21]),)
# (array([19]),)
# (array([9]),)
# (array([14]),)
# (array([4]),)
# (array([17]),)
# (array([28]),)
# (array([2]),)
# (array([23]),)
# (array([8]),)
# (array([13]),)
# (array([10]),)
# (array([26]),)
# (array([22]),)
# (array([18]),)
# (array([16]),)
# (array([5]),)
# (array([1]),)
# (array([20]),)
# (array([3]),)
# (array([25]),)
# (array([0]),)
# (array([7]),)
# (array([14]),)
# (array([13]),)
# (array([27]),)
# (array([4]),)
# (array([18]),)
# (array([10]),)
# (array([15]),)
# (array([17]),)
# (array([8]),)
# (array([25]),)
# (array([3]),)
# (array([9]),)
# (array([19]),)
# (array([6]),)
# (array([28]),)
# (array([7]),)
# (array([5]),)
# (array([20]),)
# (array([26]),)
# (array([21]),)
# (array([22]),)
# (array([23]),)
# (array([11]),)
# (array([0]),)
# (array([1]),)
# (array([12]),)
# (array([24]),)
# (array([2]),)
# (array([16]),)
# (array([25]),)
# (array([21]),)
# (array([12]),)
# (array([5]),)
# (array([7]),)
# (array([15]),)
# (array([14]),)
# (array([20]),)
# (array([9]),)
# (array([16]),)
# (array([0]),)
# (array([11]),)
# (array([26]),)
# (array([1]),)
# (array([2]),)
# (array([6]),)
# (array([10]),)
# (array([22]),)
# (array([18]),)
# (array([23]),)
# (array([24]),)
# (array([13]),)
# (array([3]),)
# (array([4]),)
# (array([17]),)
# (array([27]),)
# (array([8]),)
# (array([19]),)
# (array([24]),)
# (array([13]),)
# (array([2]),)
# (array([7]),)
# (array([11]),)
# (array([9]),)
# (array([22]),)
# (array([17]),)
# (array([14]),)
# (array([3]),)
# (array([15]),)
# (array([8]),)
# (array([1]),)
# (array([5]),)
# (array([16]),)
# (array([23]),)
# (array([19]),)
# (array([21]),)
# (array([20]),)
# (array([10]),)
# (array([0]),)
# (array([6]),)
# (array([12]),)
# (array([25]),)
# (array([4]),)
# (array([18]),)
# (array([13]),)
# (array([7]),)
# (array([3]),)
# (array([11]),)
# (array([8]),)
# (array([10]),)
# (array([12]),)
# (array([19]),)
# (array([18]),)
# (array([0]),)
# (array([15]),)
# (array([9]),)
# (array([6]),)
# (array([5]),)
# (array([23]),)
# (array([21]),)
# (array([20]),)
# (array([22]),)
# (array([17]),)
# (array([4]),)
# (array([1]),)
# (array([24]),)
# (array([14]),)
# (array([2]),)
# (array([16]),)
# (array([13]),)
# (array([7]),)
# (array([3]),)
# (array([9]),)
# (array([8]),)
# (array([10]),)
# (array([11]),)
# (array([23]),)
# (array([20]),)
# (array([4]),)
# (array([18]),)
# (array([12]),)
# (array([2]),)
# (array([6]),)
# (array([16]),)
# (array([21]),)
# (array([19]),)
# (array([14]),)
# (array([1]),)
# (array([0]),)
# (array([15]),)
# (array([22]),)
# (array([5]),)
# (array([17]),)
# (array([17]),)
# (array([12]),)
# (array([1]),)
# (array([9]),)
# (array([14]),)
# (array([16]),)
# (array([21]),)
# (array([8]),)
# (array([3]),)
# (array([13]),)
# (array([6]),)
# (array([2]),)
# (array([5]),)
# (array([15]),)
# (array([20]),)
# (array([19]),)
# (array([10]),)
# (array([0]),)
# (array([7]),)
# (array([11]),)
# (array([22]),)
# (array([4]),)
# (array([18]),)
# (array([11]),)
# (array([8]),)
# (array([7]),)
# (array([13]),)
# (array([9]),)
# (array([12]),)
# (array([10]),)
# (array([15]),)
# (array([0]),)
# (array([16]),)
# (array([2]),)
# (array([6]),)
# (array([3]),)
# (array([21]),)
# (array([20]),)
# (array([17]),)
# (array([5]),)
# (array([4]),)
# (array([18]),)
# (array([19]),)
# (array([1]),)
# (array([14]),)
# (array([15]),)
# (array([12]),)
# (array([5]),)
# (array([7]),)
# (array([10]),)
# (array([6]),)
# (array([1]),)
# (array([0]),)
# (array([11]),)
# (array([3]),)
# (array([9]),)
# (array([4]),)
# (array([17]),)
# (array([20]),)
# (array([19]),)
# (array([14]),)
# (array([18]),)
# (array([8]),)
# (array([16]),)
# (array([2]),)
# (array([13]),)
# (array([17]),)
# (array([9]),)
# (array([3]),)
# (array([7]),)
# (array([11]),)
# (array([8]),)
# (array([1]),)
# (array([0]),)
# (array([10]),)
# (array([2]),)
# (array([13]),)
# (array([6]),)
# (array([18]),)
# (array([19]),)
# (array([14]),)
# (array([12]),)
# (array([4]),)
# (array([15]),)
# (array([5]),)
# (array([16]),)
# (array([14]),)
# (array([10]),)
# (array([3]),)
# (array([5]),)
# (array([11]),)
# (array([6]),)
# (array([2]),)
# (array([1]),)
# (array([7]),)
# (array([0]),)
# (array([13]),)
# (array([4]),)
# (array([17]),)
# (array([12]),)
# (array([18]),)
# (array([8]),)
# (array([16]),)
# (array([9]),)
# (array([15]),)
# (array([12]),)
# (array([10]),)
# (array([5]),)
# (array([7]),)
# (array([11]),)
# (array([8]),)
# (array([1]),)
# (array([0]),)
# (array([9]),)
# (array([2]),)
# (array([16]),)
# (array([3]),)
# (array([13]),)
# (array([14]),)
# (array([4]),)
# (array([17]),)
# (array([6]),)
# (array([15]),)
# (array([13]),)
# (array([8]),)
# (array([0]),)
# (array([4]),)
# (array([12]),)
# (array([9]),)
# (array([3]),)
# (array([2]),)
# (array([10]),)
# (array([1]),)
# (array([11]),)
# (array([5]),)
# (array([14]),)
# (array([16]),)
# (array([6]),)
# (array([7]),)
# (array([15]),)
# (array([15]),)
# (array([11]),)
# (array([3]),)
# (array([6]),)
# (array([12]),)
# (array([8]),)
# (array([1]),)
# (array([0]),)
# (array([10]),)
# (array([2]),)
# (array([9]),)
# (array([5]),)
# (array([13]),)
# (array([4]),)
# (array([7]),)
# (array([14]),)
# (array([14]),)
# (array([9]),)
# (array([3]),)
# (array([4]),)
# (array([12]),)
# (array([6]),)
# (array([2]),)
# (array([1]),)
# (array([8]),)
# (array([0]),)
# (array([10]),)
# (array([5]),)
# (array([13]),)
# (array([7]),)
# (array([11]),)
# (array([15]),)
# (array([13]),)
# (array([10]),)
# (array([4]),)
# (array([7]),)
# (array([12]),)
# (array([8]),)
# (array([1]),)
# (array([0]),)
# (array([9]),)
# (array([2]),)
# (array([11]),)
# (array([5]),)
# (array([14]),)
# (array([3]),)
# (array([6]),)
# (array([10]),)
# (array([2]),)
# (array([1]),)
# (array([11]),)
# (array([6]),)
# (array([3]),)
# (array([5]),)
# (array([7]),)
# (array([0]),)
# (array([8]),)
# (array([4]),)
# (array([12]),)
# (array([9]),)
# (array([13]),)
# (array([11]),)
# (array([2]),)
# (array([1]),)
# (array([7]),)
# (array([5]),)
# (array([3]),)
# (array([6]),)
# (array([0]),)
# (array([9]),)
# (array([4]),)
# (array([10]),)
# (array([8]),)
# (array([12]),)
# (array([12]),)
# (array([3]),)
# (array([1]),)
# (array([7]),)
# (array([2]),)
# (array([4]),)
# (array([6]),)
# (array([0]),)
# (array([10]),)
# (array([5]),)
# (array([9]),)
# (array([8]),)
# (array([11]),)
# (array([4]),)
# (array([1]),)
# (array([7]),)
# (array([3]),)
# (array([2]),)
# (array([6]),)
# (array([0]),)
# (array([9]),)
# (array([5]),)
# (array([10]),)
# (array([8]),)
# (array([11]),)
# (array([7]),)
# (array([3]),)
# (array([5]),)
# (array([2]),)
# (array([1]),)
# (array([6]),)
# (array([0]),)
# (array([11]),)
# (array([4]),)
# (array([9]),)
# (array([8]),)
# (array([10]),)
# (array([7]),)
# (array([0]),)
# (array([5]),)
# (array([2]),)
# (array([3]),)
# (array([6]),)
# (array([1]),)
# (array([9]),)
# (array([4]),)
# (array([10]),)
# (array([8]),)
# (array([7]),)
# (array([1]),)
# (array([6]),)
# (array([3]),)
# (array([2]),)
# (array([5]),)
# (array([0]),)
# (array([8]),)
# (array([4]),)
# (array([9]),)
# (array([10]),)
# (array([7]),)
# (array([1]),)
# (array([6]),)
# (array([3]),)
# (array([5]),)
# (array([4]),)
# (array([0]),)
# (array([8]),)
# (array([2]),)
# (array([9]),)
# (array([6]),)
# (array([3]),)
# (array([7]),)
# (array([1]),)
# (array([2]),)
# (array([4]),)
# (array([0]),)
# (array([8]),)
# (array([5]),)
# (array([9]),)
# (array([7]),)
# (array([3]),)
# (array([6]),)
# (array([2]),)
# (array([1]),)
# (array([5]),)
# (array([0]),)
# (array([8]),)
# (array([4]),)
# (array([7]),)
# (array([3]),)
# (array([6]),)
# (array([1]),)
# (array([2]),)
# (array([4]),)
# (array([0]),)
# (array([8]),)
# (array([5]),)
# (array([7]),)
# (array([2]),)
# (array([6]),)
# (array([1]),)
# (array([3]),)
# (array([4]),)
# (array([0]),)
# (array([5]),)
# (array([7]),)
# (array([3]),)
# (array([6]),)
# (array([1]),)
# (array([2]),)
# (array([4]),)
# (array([0]),)
# (array([5]),)
# (array([7]),)
# (array([2]),)
# (array([6]),)
# (array([1]),)
# (array([4]),)
# (array([3]),)
# (array([0]),)
# (array([5]),)
# (array([4]),)
# (array([6]),)
# (array([1]),)
# (array([2]),)
# (array([3]),)
# (array([0]),)
# (array([5]),)
# (array([6]),)
# (array([5]),)
# (array([2]),)
# (array([1]),)
# (array([4]),)
# (array([0]),)
# (array([3]),)
# (array([6]),)
# (array([5]),)
# (array([2]),)
# (array([1]),)
# (array([4]),)
# (array([0]),)
# (array([3]),)
# (array([5]),)
# (array([2]),)
# (array([1]),)
# (array([4]),)
# (array([0]),)
# (array([3]),)
# (array([5]),)
# (array([0]),)
# (array([2]),)
# (array([3]),)
# (array([1]),)
# (array([4]),)
# (array([5]),)
# (array([0]),)
# (array([2]),)
# (array([3]),)
# (array([1]),)
# (array([4]),)
# (array([1]),)
# (array([2]),)
# (array([3]),)
# (array([0]),)
# (array([4]),)
# (array([2]),)
# (array([1]),)
# (array([4]),)
# (array([0]),)
# (array([3]),)
# (array([1]),)
# (array([2]),)
# (array([4]),)
# (array([0]),)
# (array([3]),)
# (array([1]),)
# (array([2]),)
# (array([4]),)
# (array([0]),)
# (array([3]),)
# (array([0]),)
# (array([2]),)
# (array([1]),)
# (array([3]),)
# (array([1]),)
# (array([0]),)
# (array([2]),)
# (array([3]),)
# (array([1]),)
# (array([0]),)
# (array([2]),)
# (array([3]),)
# (array([1]),)
# (array([0]),)
# (array([2]),)
# (array([3]),)
# (array([1]),)
# (array([0]),)
# (array([2]),)
# (array([3]),)
# (array([1]),)
# (array([0]),)
# (array([2]),)
# (array([3]),)
# (array([1]),)
# (array([0]),)
# (array([2]),)
# (array([0]),)
# (array([1]),)
# (array([2]),)
# (array([0]),)
# (array([1]),)
# (array([2]),)
# (array([0]),)
# (array([1]),)
# (array([2]),)
# (array([0]),)
# (array([1]),)
# (array([2]),)
# (array([0]),)
# (array([1]),)
# (array([2]),)
# (array([0]),)
# (array([1]),)
# (array([2]),)
# (array([0]),)
# (array([1]),)
# (array([0]),)
# (array([1]),)
# (array([0]),)
# (array([1]),)
# (array([0]),)
# (array([1]),)
# (array([0]),)
# (array([1]),)
# 24
# 回归系数最大波段： 89
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 371
#     369 y = data[:, 0]
#     370 X = data[:, 1:]
# --> 371 cars_index = CARS_Cloud(X, y)
#
# Cell In[2], line 358, in CARS_Cloud(X, y, N, f, cv)
#     354 plt.tight_layout()
#     356 # plt.savefig('/Users/macbook/Desktop/论文11_24/图11d.svg')
#     357 # plt.savefig('/Users/macbook/Desktop/论文11_24/图11d.eps',format='eps')
# --> 358 plt.savefig('/Users/macbook/Desktop/11_28/论文11_24/图6a11.pdf',format='pdf')
#     359 plt.show()
#     360 print(min(RMSECV))
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py:1023, in savefig(*args, **kwargs)
#    1020 @_copy_docstring_and_deprecators(Figure.savefig)
#    1021 def savefig(*args, **kwargs):
#    1022     fig = gcf()
# -> 1023     res = fig.savefig(*args, **kwargs)
#    1024     fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1025     return res
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/figure.py:3343, in Figure.savefig(self, fname, transparent, **kwargs)
#    3339     for ax in self.axes:
#    3340         stack.enter_context(
#    3341             ax.patch._cm_set(facecolor='none', edgecolor='none'))
# -> 3343 self.canvas.print_figure(fname, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backend_bases.py:2366, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2362 try:
#    2363     # _get_renderer may change the figure dpi (as vector formats
#    2364     # force the figure dpi to 72), so we need to set it again here.
#    2365     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2366         result = print_method(
#    2367             filename,
#    2368             facecolor=facecolor,
#    2369             edgecolor=edgecolor,
#    2370             orientation=orientation,
#    2371             bbox_inches_restore=_bbox_inches_restore,
#    2372             **kwargs)
#    2373 finally:
#    2374     if bbox_inches and restore_bbox:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backend_bases.py:2232, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2228     optional_kws = {  # Passed by print_figure for other renderers.
#    2229         "dpi", "facecolor", "edgecolor", "orientation",
#    2230         "bbox_inches_restore"}
#    2231     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2232     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2233         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2234 else:  # Let third-parties do as they see fit.
#    2235     print_method = meth
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_pdf.py:2808, in FigureCanvasPdf.print_pdf(self, filename, bbox_inches_restore, metadata)
#    2806     file = filename._file
#    2807 else:
# -> 2808     file = PdfFile(filename, metadata=metadata)
#    2809 try:
#    2810     file.newPage(width, height)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_pdf.py:713, in PdfFile.__init__(self, filename, metadata)
#     711 self.original_file_like = None
#     712 self.tell_base = 0
# --> 713 fh, opened = cbook.to_filehandle(filename, "wb", return_opened=True)
#     714 if not opened:
#     715     try:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/cbook/__init__.py:489, in to_filehandle(fname, flag, return_opened, encoding)
#     487         fh = bz2.BZ2File(fname, flag)
#     488     else:
# --> 489         fh = open(fname, flag, encoding=encoding)
#     490     opened = True
#     491 elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/macbook/Desktop/11_28/论文11_24/图6a11.pdf'
