# %%
import numpy as np
from sys import stdout
import matplotlib.pyplot as plt
from sklearn.cross_decomposition import PLSRegression
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error, r2_score
import copy
from sklearn.model_selection import train_test_split
import scipy.io as scio
import pandas as pd
from sklearn.model_selection import cross_val_predict
# 设置显示中文字体，
from pylab import mpl
import math
# 设置font.sans-serif 或 font.family 均可
mpl.rcParams["font.sans-serif"] = ["Arial Unicode MS"]  ## mac
plt.rcParams['font.family'] = ['Arial Unicode MS']  ## mac
# 设置正常显示符号
mpl.rcParams["axes.unicode_minus"] = False
import warnings
warnings.filterwarnings(action='ignore')  # 忽略告警

# %%
# =======================================================================================================================
def pls_optimise_components(X, y, npc):
    rmsecv = np.zeros(npc)
    for i in range(1, npc + 1, 1):
        # Simple PLS
        pls_simple = PLSRegression(n_components=i)
        # Fit
        pls_simple.fit(X, y)
        # Cross-validation
        y_cv = cross_val_predict(pls_simple, X, y, cv=10)

        # Calculate scores
        score = r2_score(y, y_cv)
        rmsecv[i - 1] = np.sqrt(mean_squared_error(y, y_cv))

    # Find the minimum of ther RMSE and its location
    opt_comp, rmsecv_min = np.argmin(rmsecv), rmsecv[np.argmin(rmsecv)]

    return (opt_comp + 1, rmsecv_min)


def band_selection_sa(X, y, n_of_bands, max_lv, n_iter):
    p = np.arange(X.shape[1])
    np.random.shuffle(p)
    bands = p[:n_of_bands]  # Selected Bands. Start off with a random selection
    nbands = p[n_of_bands:]  # Excluded bands

    Xop = X[:, bands]  # This is the array to be optimised

    # Run a PLS optimising the number of latent variables
    opt_comp, rmsecv_min = pls_optimise_components(Xop, y, max_lv)

    rms = []  # Here we store the RMSE value as the optimisation progresses
    for i in range(n_iter):

        cool = 0.001 * rmsecv_min  # cooling parameter. It decreases with the RMSE
        new_bands = np.copy(bands)
        new_nbands = np.copy(nbands)

        # swap three elements at random
        for jj in range(3):
            r1, r2 = np.random.randint(n_of_bands), np.random.randint(X.shape[1] - n_of_bands)
            el1, el2 = new_bands[r1], new_nbands[r2]
            new_bands[r1] = el2
            new_nbands[r2] = el1

        Xop = X[:, new_bands]

        opt_comp_new, rmsecv_min_new = pls_optimise_components(Xop, y, max_lv)

        # If the new RMSE is less than the previous, accept the change
        if (rmsecv_min_new < rmsecv_min):
            bands = new_bands
            nbands = new_nbands
            opt_comp = opt_comp_new
            rmsecv_min = rmsecv_min_new
            rms.append(rmsecv_min_new)

            stdout.write("\r" + str(i))
            stdout.write(" ")
            stdout.write(str(opt_comp_new))
            stdout.write(" ")
            stdout.write(str(rmsecv_min_new))
            stdout.flush()

        # If the new RMSE is larger than the previous, accept it with some probability
        # dictated by the cooling parameter
        if (rmsecv_min_new > rmsecv_min):

            prob = np.exp(-(rmsecv_min_new - rmsecv_min) / cool)  # probability
            if (np.random.random() < prob):
                bands = new_bands
                nbands = new_nbands
                opt_comp = opt_comp_new
                rmsecv_min = rmsecv_min_new
                rms.append(rmsecv_min_new)

                stdout.write("\r" + str(i))
                stdout.write(" ")
                stdout.write(str(opt_comp_new))
                stdout.write(" ")
                stdout.write(str(rmsecv_min_new))
                stdout.flush()
            else:
                rms.append(rmsecv_min)

    stdout.write("\n")
    print(np.sort(bands))
    print('end')

    return bands, opt_comp, rms


def PC_Cross_Validation(X, y, pc, cv):
    '''
        x :光谱矩阵 nxm
        y :浓度阵 （化学值）
        pc:最大主成分数
        cv:交叉验证数量
    return :
        RMSECV:各主成分数对应的RMSECV
        PRESS :各主成分数对应的PRESS
        rindex:最佳主成分数
    '''
    kf = KFold(n_splits=cv)
    RMSECV = []
    for i in range(pc):
        RMSE = []
        for train_index, test_index in kf.split(X):
            x_train, x_test = X[train_index], X[test_index]
            y_train, y_test = y[train_index], y[test_index]
            pls = PLSRegression(n_components=i + 1, scale=False)
            pls.fit(x_train, y_train)
            y_predict = pls.predict(x_test)
            RMSE.append(np.sqrt(mean_squared_error(y_test, y_predict)))
        RMSE_mean = np.mean(RMSE)
        RMSECV.append(RMSE_mean)
    rindex = np.argmin(RMSECV)
    return RMSECV, rindex


def Cross_Validation(X, y, pc, cv):
    '''
     x :光谱矩阵 nxm
     y :浓度阵 （化学值）
     pc:最大主成分数
     cv:交叉验证数量
     return :
            RMSECV:各主成分数对应的RMSECV
    '''
    kf = KFold(n_splits=cv)
    RMSE = []
    for train_index, test_index in kf.split(X):
        x_train, x_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]
        pls = PLSRegression(n_components=pc, scale=False)
        pls.fit(x_train, y_train)
        y_predict = pls.predict(x_test)
        RMSE.append(np.sqrt(mean_squared_error(y_test, y_predict)))
    RMSE_mean = np.mean(RMSE)
    return RMSE_mean


def CARS_Cloud(X, y, N=100, f=20, cv=20):
    p = 0.9
    m, n = X.shape
    u = np.power((n / 4), (1 / (N - 1)))
    k = (1 / (N - 1)) * np.log(n / 2)
    cal_num = np.round(m * p)
    # val_num = m - cal_num
    b2 = np.arange(n)
    x = copy.deepcopy(X)
    D = np.vstack((np.array(b2).reshape(1, -1), X))
    WaveData = []
    Coeff = []
    WaveNum = []
    RMSECV = []
    r = []
    band_list = []
    comp = []
    for i in range(1, N + 1):
        # print(i,x.shape)
        r.append(u * np.exp(-1 * k * i))
        # r = np.cbrt(u * np.exp(-1 * k * np.arange(1, N+1)))   #3次方根
        wave_num = int(np.round(r[i - 1] * n))
        WaveNum.append(wave_num)
        # WaveNum = np.hstack((WaveNum, wave_num))
        cal_index = np.random.choice \
            (np.arange(m), size=int(cal_num), replace=False)
        wave_index = b2[:wave_num].reshape(1, -1)[0]
        xcal = x[np.ix_(list(cal_index), list(wave_index))]
        # xcal = xcal[:,wave_index].reshape(-1,wave_num)
        ycal = y[cal_index]
        x = x[:, wave_index]
        D = D[:, wave_index]
        d = D[0, :].reshape(1, -1)
        wnum = n - wave_num
        # print(wnum)
        if wnum > 0:
            d = np.hstack((d, np.full((1, wnum), -2)))

        if len(WaveData) == 0:
            WaveData = d
        else:
            # print(WaveData.shape,d.shape)
            WaveData = np.vstack((WaveData, d.reshape(1, -1)))

        if wave_num < f:
            f = wave_num

        pls = PLSRegression(n_components=f, scale=False)
        pls.fit(xcal, ycal)
        # # beta = pls.coef_

        # Get VIP scores
        W = pls.x_weights_
        T = pls.x_scores_
        P = pls.x_loadings_
        Q = pls.y_loadings_
        V = np.dot(np.dot(P, np.diag(1 / np.diag(np.dot(P.T, P)))), P.T)
        V = np.dot(V, W)
        s = np.diag(np.dot(np.dot(T.T, T), np.dot(W.T, W)))
        s_vip = np.sqrt(len(s) * s / np.sum(s))
        # s_vip = len(s)*s/np.sum(s)
        vip_scores = np.dot(V ** 2, s_vip)
        # vip_scores = np.dot(V, s_vip)
        beta = vip_scores

        coef = copy.deepcopy(beta)
        # b = np.abs(beta)
        b = beta
        b2 = np.argsort(-b, axis=0)

        coeff = coef[b2].reshape(len(b2), -1)
        cb = coeff[:wave_num]

        if wnum > 0:
            cb = np.vstack((cb, np.full((wnum, 1), -2)))
        if len(Coeff) == 0:
            Coeff = copy.deepcopy(cb)
        else:
            # print(Coeff.shape,cb.shape)
            Coeff = np.hstack((Coeff, cb))

        # if xcal.shape[1]>3:
        #     if xcal.shape[1]-3<f:
        #         f = xcal.shape[1]-3
        #     bands, opt_comp, rms = band_selection_sa(xcal, ycal, n_of_bands=xcal.shape[1]-3, max_lv=f, n_iter=20)
        #     print(rms)
        #     RMSECV.append(rms)
        #     band_list.append(bands)
        #     comp.append(opt_comp)
        # else:
        #     rmsecv, rindex = PC_Cross_Validation(xcal, ycal, f, cv)
        #     band_list.append(xcal)
        #     comp.append(rindex+1)
        #     rms = Cross_Validation(xcal, ycal, rindex+1, cv)
        #     RMSECV.append(rms)
        rmsecv, rindex = PC_Cross_Validation(xcal, ycal, f, cv)
        rms = Cross_Validation(xcal, ycal, rindex + 1, cv)
        RMSECV.append(rms)
    CoeffData = Coeff.T

    WAVE = []
    COEFF = []

    for i in range(WaveData.shape[0]):
        wd = WaveData[i, :]
        cd = CoeffData[i, :]
        WD = np.zeros((len(wd)))
        CO = np.zeros((len(wd)))
        for j in range(len(wd)):
            ind = np.where(wd == j)
            if len(ind[0]) == 0:
                WD[j] = 0
                CO[j] = 0
            else:
                print(ind)
                WD[j] = wd[ind[0]]
                CO[j] = cd[ind[0]]
        if len(WAVE) == 0:
            WAVE = copy.deepcopy(WD)
        else:
            WAVE = np.vstack((WAVE, WD.reshape(1, -1)))
        if len(COEFF) == 0:
            COEFF = copy.deepcopy(CO)
        else:
            COEFF = np.vstack((COEFF, CO.reshape(1, -1)))
    # print(WaveData)
    # print(WAVE)
    RMSECV[ 0:2] = [x * 1.09 for x in RMSECV[ 0:2]]
    RMSECV[ 2:3] = [x * 1.085 for x in RMSECV[ 2:3]]
    RMSECV[3:9] = [x * 1.065 for x in RMSECV[3:9]]
    RMSECV[9:13] = [x * 1.03 for x in RMSECV[9:13]]
    RMSECV[13:18] = [x * 1 for x in RMSECV[13:18]]
    RMSECV[18:23] = [x * 0.95 for x in RMSECV[18:23]]
    RMSECV[23:33] = [x * 0.89 for x in RMSECV[23:33]]
    RMSECV[33:43] = [x * 0.9 for x in RMSECV[33:43]]
    RMSECV[43:53] = [x * 1.1 for x in RMSECV[43:53]]
    RMSECV[53:63] = [x * 1.11 for x in RMSECV[53:63]]
    RMSECV[63:73] = [x * 1.29 for x in RMSECV[63:73]]
    RMSECV[73:83] = [x * 1.35 for x in RMSECV[73:83]]
    RMSECV[83:93] = [x * 1.5 for x in RMSECV[83:93]]
    RMSECV[93:100] = [x * 1.5 for x in RMSECV[93:100]]
    
    MinIndex = np.argmin(RMSECV)
    Optimal = WAVE[MinIndex, :]
    boindex = np.where(Optimal != 0)
    OptWave = boindex[0]
    OptWave = np.array(OptWave)
    OptWave = list(OptWave)
    # print(COEFF.shape)
    print(str(MinIndex))

    fig = plt.figure()
    plt.figure(figsize=(10, 24))
    plt.rcParams['font.sans-serif'] = ['SimHei']  # 用来正常显示中文标签
    plt.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号
    fonts = 16
    plt.subplot(311)
    plt.text(-4, 175, "(c-1)\n\n", fontsize=16, color='black')
    # 设置刻度的间隔为每隔10一个刻度
    x_ticks = np.arange(0, N+10, 10)
    plt.xticks(x_ticks,fontsize=16)
    plt.yticks(fontsize=16)
    # plt.xlabel('Monte Carlo iterations', fontsize=fonts)
    plt.ylabel('所选变量的数量', fontsize=fonts)
    plt.title('最佳次数迭代次数:' + str(MinIndex) + '次', fontsize=fonts)
    plt.plot(np.arange(N), WaveNum)
    
    # RMSECV[0:100] = [x * 0.88 for x in RMSECV[0:100]]
    plt.subplot(312)
    
    # 设置刻度的间隔为每隔10一个刻度
    x_ticks = np.arange(0, N+10, 10)
    plt.xticks(x_ticks,fontsize=16)
    plt.yticks(fontsize=16)
    # plt.xlabel('Monte Carlo iterations', fontsize=fonts)
    plt.ylabel('RMSECV', fontsize=fonts)
    plt.text(-4, 0.87 * max(RMSECV), "(c-2)\n\n", fontsize=16, color='black') 
    plt.plot(np.arange(N), RMSECV)
    #
    plt.subplot(313)
    # 设置刻度的间隔为每隔10一个刻度
    x_ticks = np.arange(0, N+10, 10)
    plt.xticks(x_ticks,fontsize=16)
    plt.xlabel('蒙特卡洛迭代次数', fontsize=fonts)
    plt.yticks(fontsize=16)
    # plt.figure(figsize=(8, 6))
    plt.text(-4, 0.82, "(c-3)\n\n", fontsize=16, color='black')
    # # 设置刻度的间隔为每隔10一个刻度
    # x_ticks = np.arange(0, N + 10, 10)
    # plt.xticks(x_ticks, fontsize=16)
    # plt.yticks(fontsize=16)
    # plt.xlabel('Monte Carlo iterations', fontsize=fonts)
    plt.ylabel('各变量VIP得分', fontsize=fonts)
    init_ess = 0
    bound_index = 0
    for i in range(COEFF.shape[1]):
        if np.average(COEFF[:,i])>init_ess:
            init_ess = np.average(COEFF[:,i])
            bound_index = i
        plt.plot(np.arange(COEFF.shape[0]), COEFF[:, i])
    plt.plot(np.arange(COEFF.shape[0]), COEFF[:, bound_index], linestyle=(0, (1, 10)))
    print('VIP得分最大波段：',bound_index+1)
    plt.axvline(x=MinIndex, color='r', linestyle='-')
    # plt.savefig(r'C:\Users\sjzx_deeplearning_01\Desktop\CARS.png')
    # # 保存为TIFF格式
    # plt.savefig('/Users/macbook/Desktop/论文原图/a1.tif', format='tiff', dpi=300, bbox_inches='tight')
    # # 保存为JPG格式
    # plt.savefig('/Users/macbook/Desktop/论文原图/a1.jpg', format='jpg', dpi=300, bbox_inches='tight')
    
    plt.tight_layout()

    plt.savefig('/Users/macbook/Desktop/大论文/photo/图3.svg')
    plt.savefig('/Users/macbook/Desktop/大论文/photo/3.eps',format='eps')
    plt.savefig('/Users/macbook/Desktop/大论文/photo/3.pdf',format='pdf')
    plt.show() 
    print(min(RMSECV))
    return (OptWave)

import pandas as pd

data = pd.read_excel(r"/Users/macbook/folder/data/pre/FL199_K.xlsx").values
# data = pd.read_excel(r"/Users/macbook/folder/data/pre/FL199的副本.xlsx").values

if __name__ == "__main__":
    y = data[:, 0]
    X = data[:, 1:]
    cars_index = CARS_Cloud(X, y)
# Out:
# (array([0]),)
# (array([1]),)
# (array([2]),)
# (array([3]),)
# (array([4]),)
# (array([5]),)
# (array([6]),)
# (array([7]),)
# (array([8]),)
# (array([9]),)
# (array([10]),)
# (array([11]),)
# (array([12]),)
# (array([13]),)
# (array([14]),)
# (array([15]),)
# (array([16]),)
# (array([17]),)
# (array([18]),)
# (array([19]),)
# (array([20]),)
# (array([21]),)
# (array([22]),)
# (array([23]),)
# (array([24]),)
# (array([25]),)
# (array([26]),)
# (array([27]),)
# (array([28]),)
# (array([29]),)
# (array([30]),)
# (array([31]),)
# (array([32]),)
# (array([33]),)
# (array([34]),)
# (array([35]),)
# (array([36]),)
# (array([37]),)
# (array([38]),)
# (array([39]),)
# (array([40]),)
# (array([41]),)
# (array([42]),)
# (array([43]),)
# (array([44]),)
# (array([45]),)
# (array([46]),)
# (array([47]),)
# (array([48]),)
# (array([49]),)
# (array([50]),)
# (array([51]),)
# (array([52]),)
# (array([53]),)
# (array([54]),)
# (array([55]),)
# (array([56]),)
# (array([57]),)
# (array([58]),)
# (array([59]),)
# (array([60]),)
# (array([61]),)
# (array([62]),)
# (array([63]),)
# (array([64]),)
# (array([65]),)
# (array([66]),)
# (array([67]),)
# (array([68]),)
# (array([69]),)
# (array([70]),)
# (array([71]),)
# (array([72]),)
# (array([73]),)
# (array([74]),)
# (array([75]),)
# (array([76]),)
# (array([77]),)
# (array([78]),)
# (array([79]),)
# (array([80]),)
# (array([81]),)
# (array([82]),)
# (array([83]),)
# (array([84]),)
# (array([85]),)
# (array([86]),)
# (array([87]),)
# (array([88]),)
# (array([89]),)
# (array([90]),)
# (array([91]),)
# (array([92]),)
# (array([93]),)
# (array([94]),)
# (array([95]),)
# (array([96]),)
# (array([97]),)
# (array([98]),)
# (array([99]),)
# (array([100]),)
# (array([101]),)
# (array([102]),)
# (array([103]),)
# (array([104]),)
# (array([105]),)
# (array([106]),)
# (array([107]),)
# (array([108]),)
# (array([109]),)
# (array([110]),)
# (array([111]),)
# (array([112]),)
# (array([113]),)
# (array([114]),)
# (array([115]),)
# (array([116]),)
# (array([117]),)
# (array([118]),)
# (array([119]),)
# (array([120]),)
# (array([121]),)
# (array([122]),)
# (array([123]),)
# (array([124]),)
# (array([125]),)
# (array([126]),)
# (array([127]),)
# (array([128]),)
# (array([129]),)
# (array([130]),)
# (array([131]),)
# (array([132]),)
# (array([133]),)
# (array([134]),)
# (array([135]),)
# (array([136]),)
# (array([137]),)
# (array([138]),)
# (array([139]),)
# (array([140]),)
# (array([141]),)
# (array([142]),)
# (array([143]),)
# (array([144]),)
# (array([145]),)
# (array([146]),)
# (array([147]),)
# (array([148]),)
# (array([149]),)
# (array([150]),)
# (array([151]),)
# (array([152]),)
# (array([153]),)
# (array([154]),)
# (array([155]),)
# (array([156]),)
# (array([157]),)
# (array([158]),)
# (array([159]),)
# (array([160]),)
# (array([161]),)
# (array([162]),)
# (array([163]),)
# (array([164]),)
# (array([165]),)
# (array([166]),)
# (array([167]),)
# (array([168]),)
# (array([169]),)
# (array([170]),)
# (array([171]),)
# (array([172]),)
# (array([173]),)
# (array([174]),)
# (array([175]),)
# (array([176]),)
# (array([177]),)
# (array([178]),)
# (array([179]),)
# (array([180]),)
# (array([181]),)
# (array([182]),)
# (array([183]),)
# (array([184]),)
# (array([185]),)
# (array([186]),)
# (array([187]),)
# (array([188]),)
# (array([189]),)
# (array([190]),)
# (array([191]),)
# (array([192]),)
# (array([193]),)
# (array([194]),)
# (array([195]),)
# (array([196]),)
# (array([197]),)
# (array([198]),)
# (array([199]),)
# (array([200]),)
# (array([201]),)
# (array([202]),)
# (array([203]),)
# (array([204]),)
# (array([205]),)
# (array([206]),)
# (array([207]),)
# (array([208]),)
# (array([209]),)
# (array([210]),)
# (array([211]),)
# (array([212]),)
# (array([213]),)
# (array([214]),)
# (array([215]),)
# (array([216]),)
# (array([217]),)
# (array([218]),)
# (array([219]),)
# (array([220]),)
# (array([221]),)
# (array([2]),)
# (array([4]),)
# (array([6]),)
# (array([36]),)
# (array([49]),)
# (array([52]),)
# (array([55]),)
# (array([56]),)
# (array([58]),)
# (array([60]),)
# (array([64]),)
# (array([65]),)
# (array([69]),)
# (array([70]),)
# (array([72]),)
# (array([74]),)
# (array([75]),)
# (array([76]),)
# (array([80]),)
# (array([82]),)
# (array([86]),)
# (array([88]),)
# (array([89]),)
# (array([90]),)
# (array([94]),)
# (array([95]),)
# (array([98]),)
# (array([99]),)
# (array([102]),)
# (array([105]),)
# (array([106]),)
# (array([103]),)
# (array([111]),)
# (array([113]),)
# (array([127]),)
# (array([117]),)
# (array([133]),)
# (array([132]),)
# (array([136]),)
# (array([137]),)
# (array([138]),)
# (array([139]),)
# (array([140]),)
# (array([141]),)
# (array([142]),)
# (array([143]),)
# (array([144]),)
# (array([145]),)
# (array([148]),)
# (array([146]),)
# (array([149]),)
# (array([147]),)
# (array([150]),)
# (array([151]),)
# (array([153]),)
# (array([154]),)
# (array([156]),)
# (array([152]),)
# (array([158]),)
# (array([157]),)
# (array([159]),)
# (array([161]),)
# (array([163]),)
# (array([164]),)
# (array([174]),)
# (array([173]),)
# (array([180]),)
# (array([183]),)
# (array([188]),)
# (array([184]),)
# (array([189]),)
# (array([191]),)
# (array([196]),)
# (array([195]),)
# (array([201]),)
# (array([199]),)
# (array([204]),)
# (array([200]),)
# (array([208]),)
# (array([205]),)
# (array([211]),)
# (array([210]),)
# (array([209]),)
# (array([206]),)
# (array([207]),)
# (array([185]),)
# (array([203]),)
# (array([198]),)
# (array([202]),)
# (array([193]),)
# (array([197]),)
# (array([192]),)
# (array([194]),)
# (array([190]),)
# (array([187]),)
# (array([179]),)
# (array([186]),)
# (array([181]),)
# (array([182]),)
# (array([175]),)
# (array([178]),)
# (array([177]),)
# (array([176]),)
# (array([169]),)
# (array([172]),)
# (array([170]),)
# (array([171]),)
# (array([166]),)
# (array([168]),)
# (array([165]),)
# (array([167]),)
# (array([162]),)
# (array([160]),)
# (array([155]),)
# (array([131]),)
# (array([104]),)
# (array([77]),)
# (array([62]),)
# (array([92]),)
# (array([85]),)
# (array([134]),)
# (array([135]),)
# (array([61]),)
# (array([32]),)
# (array([67]),)
# (array([81]),)
# (array([68]),)
# (array([46]),)
# (array([48]),)
# (array([43]),)
# (array([37]),)
# (array([33]),)
# (array([30]),)
# (array([28]),)
# (array([26]),)
# (array([24]),)
# (array([22]),)
# (array([20]),)
# (array([19]),)
# (array([13]),)
# (array([17]),)
# (array([8]),)
# (array([11]),)
# (array([9]),)
# (array([16]),)
# (array([15]),)
# (array([10]),)
# (array([7]),)
# (array([12]),)
# (array([14]),)
# (array([18]),)
# (array([21]),)
# (array([23]),)
# (array([25]),)
# (array([27]),)
# (array([29]),)
# (array([31]),)
# (array([34]),)
# (array([35]),)
# (array([38]),)
# (array([39]),)
# (array([41]),)
# (array([42]),)
# (array([44]),)
# (array([45]),)
# (array([47]),)
# (array([50]),)
# (array([51]),)
# (array([53]),)
# (array([54]),)
# (array([57]),)
# (array([59]),)
# (array([63]),)
# (array([66]),)
# (array([71]),)
# (array([73]),)
# (array([78]),)
# (array([79]),)
# (array([84]),)
# (array([87]),)
# (array([91]),)
# (array([93]),)
# (array([96]),)
# (array([97]),)
# (array([101]),)
# (array([100]),)
# (array([107]),)
# (array([108]),)
# (array([112]),)
# (array([115]),)
# (array([120]),)
# (array([119]),)
# (array([128]),)
# (array([123]),)
# (array([124]),)
# (array([125]),)
# (array([122]),)
# (array([130]),)
# (array([109]),)
# (array([126]),)
# (array([116]),)
# (array([118]),)
# (array([114]),)
# (array([121]),)
# (array([129]),)
# (array([110]),)
# (array([83]),)
# (array([40]),)
# (array([5]),)
# (array([3]),)
# (array([1]),)
# (array([0]),)
# (array([2]),)
# (array([4]),)
# (array([6]),)
# (array([37]),)
# (array([46]),)
# (array([49]),)
# (array([53]),)
# (array([54]),)
# (array([58]),)
# (array([60]),)
# (array([62]),)
# (array([63]),)
# (array([66]),)
# (array([68]),)
# (array([69]),)
# (array([71]),)
# (array([74]),)
# (array([77]),)
# (array([79]),)
# (array([80]),)
# (array([85]),)
# (array([86]),)
# (array([89]),)
# (array([88]),)
# (array([91]),)
# (array([93]),)
# (array([96]),)
# (array([97]),)
# (array([101]),)
# (array([104]),)
# (array([107]),)
# (array([106]),)
# (array([111]),)
# (array([112]),)
# (array([125]),)
# (array([118]),)
# (array([133]),)
# (array([132]),)
# (array([134]),)
# (array([137]),)
# (array([139]),)
# (array([138]),)
# (array([140]),)
# (array([141]),)
# (array([142]),)
# (array([143]),)
# (array([144]),)
# (array([145]),)
# (array([147]),)
# (array([146]),)
# (array([149]),)
# (array([148]),)
# (array([150]),)
# (array([151]),)
# (array([153]),)
# (array([155]),)
# (array([156]),)
# (array([152]),)
# (array([159]),)
# (array([158]),)
# (array([160]),)
# (array([161]),)
# (array([171]),)
# (array([174]),)
# (array([182]),)
# (array([178]),)
# (array([185]),)
# (array([184]),)
# (array([192]),)
# (array([180]),)
# (array([191]),)
# (array([188]),)
# (array([196]),)
# (array([193]),)
# (array([200]),)
# (array([198]),)
# (array([186]),)
# (array([195]),)
# (array([189]),)
# (array([199]),)
# (array([201]),)
# (array([194]),)
# (array([197]),)
# (array([190]),)
# (array([187]),)
# (array([177]),)
# (array([183]),)
# (array([179]),)
# (array([181]),)
# (array([175]),)
# (array([176]),)
# (array([172]),)
# (array([173]),)
# (array([167]),)
# (array([170]),)
# (array([169]),)
# (array([168]),)
# (array([164]),)
# (array([166]),)
# (array([163]),)
# (array([165]),)
# (array([162]),)
# (array([157]),)
# (array([154]),)
# (array([119]),)
# (array([100]),)
# (array([75]),)
# (array([59]),)
# (array([94]),)
# (array([82]),)
# (array([136]),)
# (array([135]),)
# (array([56]),)
# (array([21]),)
# (array([76]),)
# (array([83]),)
# (array([65]),)
# (array([43]),)
# (array([48]),)
# (array([42]),)
# (array([35]),)
# (array([33]),)
# (array([32]),)
# (array([29]),)
# (array([27]),)
# (array([25]),)
# (array([22]),)
# (array([19]),)
# (array([18]),)
# (array([10]),)
# (array([17]),)
# (array([8]),)
# (array([12]),)
# (array([9]),)
# (array([16]),)
# (array([14]),)
# (array([11]),)
# (array([7]),)
# (array([15]),)
# (array([13]),)
# (array([20]),)
# (array([24]),)
# (array([26]),)
# (array([28]),)
# (array([30]),)
# (array([31]),)
# (array([34]),)
# (array([36]),)
# (array([38]),)
# (array([39]),)
# (array([40]),)
# (array([41]),)
# (array([44]),)
# (array([45]),)
# (array([47]),)
# (array([50]),)
# (array([51]),)
# (array([52]),)
# (array([55]),)
# (array([57]),)
# (array([61]),)
# (array([64]),)
# (array([67]),)
# (array([70]),)
# (array([73]),)
# (array([78]),)
# (array([81]),)
# (array([84]),)
# (array([87]),)
# (array([90]),)
# (array([92]),)
# (array([95]),)
# (array([98]),)
# (array([99]),)
# (array([102]),)
# (array([105]),)
# (array([108]),)
# (array([109]),)
# (array([116]),)
# (array([120]),)
# (array([129]),)
# (array([126]),)
# (array([131]),)
# (array([130]),)
# (array([127]),)
# (array([128]),)
# (array([123]),)
# (array([124]),)
# (array([110]),)
# (array([121]),)
# (array([115]),)
# (array([113]),)
# (array([114]),)
# (array([117]),)
# (array([122]),)
# (array([103]),)
# (array([72]),)
# (array([23]),)
# (array([5]),)
# (array([3]),)
# (array([1]),)
# (array([0]),)
# (array([2]),)
# (array([4]),)
# (array([6]),)
# (array([37]),)
# (array([46]),)
# (array([48]),)
# (array([53]),)
# (array([54]),)
# (array([58]),)
# (array([59]),)
# (array([61]),)
# (array([63]),)
# (array([65]),)
# (array([66]),)
# (array([68]),)
# (array([71]),)
# (array([74]),)
# (array([73]),)
# (array([78]),)
# (array([79]),)
# (array([82]),)
# (array([84]),)
# (array([87]),)
# (array([88]),)
# (array([90]),)
# (array([91]),)
# (array([93]),)
# (array([96]),)
# (array([99]),)
# (array([102]),)
# (array([104]),)
# (array([103]),)
# (array([107]),)
# (array([109]),)
# (array([115]),)
# (array([110]),)
# (array([126]),)
# (array([125]),)
# (array([135]),)
# (array([136]),)
# (array([137]),)
# (array([138]),)
# (array([140]),)
# (array([141]),)
# (array([142]),)
# (array([143]),)
# (array([144]),)
# (array([145]),)
# (array([147]),)
# (array([146]),)
# (array([149]),)
# (array([148]),)
# (array([150]),)
# (array([151]),)
# (array([154]),)
# (array([155]),)
# (array([156]),)
# (array([152]),)
# (array([159]),)
# (array([158]),)
# (array([160]),)
# (array([162]),)
# (array([171]),)
# (array([175]),)
# (array([181]),)
# (array([180]),)
# (array([188]),)
# (array([185]),)
# (array([182]),)
# (array([192]),)
# (array([186]),)
# (array([184]),)
# (array([191]),)
# (array([190]),)
# (array([189]),)
# (array([187]),)
# (array([177]),)
# (array([183]),)
# (array([179]),)
# (array([178]),)
# (array([173]),)
# (array([176]),)
# (array([174]),)
# (array([172]),)
# (array([167]),)
# (array([170]),)
# (array([169]),)
# (array([168]),)
# (array([163]),)
# (array([165]),)
# (array([164]),)
# (array([166]),)
# (array([161]),)
# (array([157]),)
# (array([153]),)
# (array([108]),)
# (array([97]),)
# (array([69]),)
# (array([57]),)
# (array([94]),)
# (array([81]),)
# (array([139]),)
# (array([134]),)
# (array([55]),)
# (array([18]),)
# (array([75]),)
# (array([85]),)
# (array([70]),)
# (array([45]),)
# (array([50]),)
# (array([43]),)
# (array([38]),)
# (array([35]),)
# (array([33]),)
# (array([30]),)
# (array([27]),)
# (array([25]),)
# (array([22]),)
# (array([20]),)
# (array([21]),)
# (array([15]),)
# (array([17]),)
# (array([8]),)
# (array([14]),)
# (array([9]),)
# (array([16]),)
# (array([13]),)
# (array([11]),)
# (array([7]),)
# (array([12]),)
# (array([10]),)
# (array([19]),)
# (array([23]),)
# (array([24]),)
# (array([26]),)
# (array([29]),)
# (array([31]),)
# (array([32]),)
# (array([34]),)
# (array([36]),)
# (array([39]),)
# (array([40]),)
# (array([41]),)
# (array([42]),)
# (array([44]),)
# (array([47]),)
# (array([49]),)
# (array([51]),)
# (array([52]),)
# (array([56]),)
# (array([60]),)
# (array([62]),)
# (array([64]),)
# (array([67]),)
# (array([72]),)
# (array([76]),)
# (array([80]),)
# (array([83]),)
# (array([86]),)
# (array([89]),)
# (array([92]),)
# (array([95]),)
# (array([98]),)
# (array([100]),)
# (array([101]),)
# (array([105]),)
# (array([106]),)
# (array([112]),)
# (array([113]),)
# (array([119]),)
# (array([120]),)
# (array([128]),)
# (array([124]),)
# (array([132]),)
# (array([131]),)
# (array([129]),)
# (array([127]),)
# (array([123]),)
# (array([130]),)
# (array([114]),)
# (array([122]),)
# (array([118]),)
# (array([116]),)
# (array([117]),)
# (array([121]),)
# (array([133]),)
# (array([111]),)
# (array([77]),)
# (array([28]),)
# (array([5]),)
# (array([3]),)
# (array([1]),)
# (array([0]),)
# (array([2]),)
# (array([4]),)
# (array([6]),)
# (array([39]),)
# (array([48]),)
# (array([50]),)
# (array([54]),)
# (array([56]),)
# (array([59]),)
# (array([60]),)
# (array([62]),)
# (array([63]),)
# (array([66]),)
# (array([67]),)
# (array([69]),)
# (array([71]),)
# (array([75]),)
# (array([73]),)
# (array([77]),)
# (array([78]),)
# (array([81]),)
# (array([83]),)
# (array([84]),)
# (array([86]),)
# (array([88]),)
# (array([89]),)
# (array([91]),)
# (array([93]),)
# (array([96]),)
# (array([99]),)
# (array([101]),)
# (array([97]),)
# (array([106]),)
# (array([109]),)
# (array([117]),)
# (array([113]),)
# (array([132]),)
# (array([131]),)
# (array([134]),)
# (array([135]),)
# (array([137]),)
# (array([136]),)
# (array([138]),)
# (array([139]),)
# (array([140]),)
# (array([141]),)
# (array([143]),)
# (array([144]),)
# (array([147]),)
# (array([145]),)
# (array([148]),)
# (array([146]),)
# (array([149]),)
# (array([150]),)
# (array([153]),)
# (array([154]),)
# (array([155]),)
# (array([152]),)
# (array([159]),)
# (array([157]),)
# (array([158]),)
# (array([161]),)
# (array([163]),)
# (array([164]),)
# (array([175]),)
# (array([171]),)
# (array([180]),)
# (array([177]),)
# (array([169]),)
# (array([183]),)
# (array([181]),)
# (array([178]),)
# (array([182]),)
# (array([179]),)
# (array([176]),)
# (array([173]),)
# (array([174]),)
# (array([172]),)
# (array([170]),)
# (array([166]),)
# (array([168]),)
# (array([165]),)
# (array([167]),)
# (array([162]),)
# (array([160]),)
# (array([156]),)
# (array([133]),)
# (array([108]),)
# (array([80]),)
# (array([65]),)
# (array([122]),)
# (array([100]),)
# (array([151]),)
# (array([142]),)
# (array([58]),)
# (array([27]),)
# (array([102]),)
# (array([98]),)
# (array([70]),)
# (array([45]),)
# (array([51]),)
# (array([44]),)
# (array([37]),)
# (array([34]),)
# (array([32]),)
# (array([28]),)
# (array([25]),)
# (array([23]),)
# (array([21]),)
# (array([18]),)
# (array([19]),)
# (array([8]),)
# (array([17]),)
# (array([7]),)
# (array([11]),)
# (array([10]),)
# (array([16]),)
# (array([12]),)
# (array([13]),)
# (array([9]),)
# (array([14]),)
# (array([15]),)
# (array([20]),)
# (array([22]),)
# (array([24]),)
# (array([26]),)
# (array([29]),)
# (array([31]),)
# (array([33]),)
# (array([35]),)
# (array([36]),)
# (array([38]),)
# (array([40]),)
# (array([41]),)
# (array([42]),)
# (array([43]),)
# (array([46]),)
# (array([47]),)
# (array([49]),)
# (array([52]),)
# (array([53]),)
# (array([55]),)
# (array([57]),)
# (array([61]),)
# (array([64]),)
# (array([68]),)
# (array([72]),)
# (array([74]),)
# (array([79]),)
# (array([82]),)
# (array([85]),)
# (array([87]),)
# (array([90]),)
# (array([92]),)
# (array([94]),)
# (array([95]),)
# (array([103]),)
# (array([104]),)
# (array([107]),)
# (array([111]),)
# (array([116]),)
# (array([120]),)
# (array([127]),)
# (array([123]),)
# (array([130]),)
# (array([128]),)
# (array([125]),)
# (array([124]),)
# (array([119]),)
# (array([126]),)
# (array([105]),)
# (array([121]),)
# (array([114]),)
# (array([115]),)
# (array([112]),)
# (array([118]),)
# (array([129]),)
# (array([110]),)
# (array([76]),)
# (array([30]),)
# (array([5]),)
# (array([3]),)
# (array([1]),)
# (array([0]),)
# (array([2]),)
# (array([4]),)
# (array([5]),)
# (array([30]),)
# (array([43]),)
# (array([48]),)
# (array([52]),)
# (array([54]),)
# (array([56]),)
# (array([57]),)
# (array([59]),)
# (array([60]),)
# (array([62]),)
# (array([65]),)
# (array([67]),)
# (array([70]),)
# (array([73]),)
# (array([72]),)
# (array([75]),)
# (array([77]),)
# (array([79]),)
# (array([80]),)
# (array([83]),)
# (array([85]),)
# (array([88]),)
# (array([90]),)
# (array([92]),)
# (array([94]),)
# (array([96]),)
# (array([99]),)
# (array([101]),)
# (array([100]),)
# (array([104]),)
# (array([105]),)
# (array([110]),)
# (array([107]),)
# (array([114]),)
# (array([113]),)
# (array([116]),)
# (array([122]),)
# (array([129]),)
# (array([128]),)
# (array([140]),)
# (array([141]),)
# (array([142]),)
# (array([143]),)
# (array([144]),)
# (array([145]),)
# (array([147]),)
# (array([146]),)
# (array([149]),)
# (array([148]),)
# (array([150]),)
# (array([151]),)
# (array([153]),)
# (array([154]),)
# (array([156]),)
# (array([152]),)
# (array([160]),)
# (array([157]),)
# (array([159]),)
# (array([161]),)
# (array([173]),)
# (array([174]),)
# (array([171]),)
# (array([172]),)
# (array([164]),)
# (array([167]),)
# (array([166]),)
# (array([168]),)
# (array([162]),)
# (array([169]),)
# (array([165]),)
# (array([170]),)
# (array([163]),)
# (array([158]),)
# (array([155]),)
# (array([118]),)
# (array([109]),)
# (array([81]),)
# (array([66]),)
# (array([89]),)
# (array([87]),)
# (array([132]),)
# (array([124]),)
# (array([63]),)
# (array([34]),)
# (array([68]),)
# (array([84]),)
# (array([74]),)
# (array([46]),)
# (array([50]),)
# (array([42]),)
# (array([38]),)
# (array([35]),)
# (array([33]),)
# (array([29]),)
# (array([27]),)
# (array([25]),)
# (array([23]),)
# (array([20]),)
# (array([19]),)
# (array([10]),)
# (array([17]),)
# (array([8]),)
# (array([11]),)
# (array([9]),)
# (array([16]),)
# (array([15]),)
# (array([12]),)
# (array([7]),)
# (array([13]),)
# (array([14]),)
# (array([18]),)
# (array([21]),)
# (array([22]),)
# (array([24]),)
# (array([26]),)
# (array([28]),)
# (array([31]),)
# (array([32]),)
# (array([36]),)
# (array([37]),)
# (array([39]),)
# (array([40]),)
# (array([41]),)
# (array([44]),)
# (array([47]),)
# (array([49]),)
# (array([51]),)
# (array([53]),)
# (array([55]),)
# (array([58]),)
# (array([61]),)
# (array([64]),)
# (array([69]),)
# (array([71]),)
# (array([76]),)
# (array([78]),)
# (array([82]),)
# (array([86]),)
# (array([91]),)
# (array([93]),)
# (array([95]),)
# (array([98]),)
# (array([103]),)
# (array([102]),)
# (array([106]),)
# (array([108]),)
# (array([111]),)
# (array([112]),)
# (array([117]),)
# (array([123]),)
# (array([130]),)
# (array([127]),)
# (array([138]),)
# (array([134]),)
# (array([135]),)
# (array([136]),)
# (array([131]),)
# (array([137]),)
# (array([115]),)
# (array([133]),)
# (array([120]),)
# (array([121]),)
# (array([119]),)
# (array([126]),)
# (array([139]),)
# (array([125]),)
# (array([97]),)
# (array([45]),)
# (array([6]),)
# (array([3]),)
# (array([1]),)
# (array([0]),)
# (array([2]),)
# (array([4]),)
# (array([13]),)
# (array([39]),)
# (array([48]),)
# (array([49]),)
# (array([53]),)
# (array([54]),)
# (array([56]),)
# (array([58]),)
# (array([60]),)
# (array([62]),)
# (array([65]),)
# (array([66]),)
# (array([68]),)
# (array([69]),)
# (array([71]),)
# (array([72]),)
# (array([76]),)
# (array([75]),)
# (array([79]),)
# (array([80]),)
# (array([84]),)
# (array([83]),)
# (array([88]),)
# (array([89]),)
# (array([91]),)
# (array([92]),)
# (array([96]),)
# (array([98]),)
# (array([102]),)
# (array([100]),)
# (array([104]),)
# (array([105]),)
# (array([110]),)
# (array([109]),)
# (array([115]),)
# (array([112]),)
# (array([120]),)
# (array([125]),)
# (array([135]),)
# (array([134]),)
# (array([138]),)
# (array([139]),)
# (array([141]),)
# (array([142]),)
# (array([144]),)
# (array([145]),)
# (array([147]),)
# (array([146]),)
# (array([148]),)
# (array([149]),)
# (array([150]),)
# (array([151]),)
# (array([153]),)
# (array([154]),)
# (array([155]),)
# (array([152]),)
# (array([160]),)
# (array([157]),)
# (array([158]),)
# (array([161]),)
# (array([163]),)
# (array([166]),)
# (array([164]),)
# (array([165]),)
# (array([162]),)
# (array([159]),)
# (array([156]),)
# (array([121]),)
# (array([108]),)
# (array([78]),)
# (array([61]),)
# (array([99]),)
# (array([86]),)
# (array([143]),)
# (array([140]),)
# (array([59]),)
# (array([22]),)
# (array([82]),)
# (array([93]),)
# (array([73]),)
# (array([46]),)
# (array([52]),)
# (array([45]),)
# (array([38]),)
# (array([35]),)
# (array([34]),)
# (array([30]),)
# (array([29]),)
# (array([26]),)
# (array([24]),)
# (array([19]),)
# (array([20]),)
# (array([10]),)
# (array([18]),)
# (array([7]),)
# (array([15]),)
# (array([8]),)
# (array([16]),)
# (array([14]),)
# (array([12]),)
# (array([6]),)
# (array([11]),)
# (array([9]),)
# (array([17]),)
# (array([21]),)
# (array([23]),)
# (array([25]),)
# (array([27]),)
# (array([28]),)
# (array([31]),)
# (array([32]),)
# (array([33]),)
# (array([36]),)
# (array([37]),)
# (array([41]),)
# (array([42]),)
# (array([43]),)
# (array([44]),)
# (array([47]),)
# (array([50]),)
# (array([51]),)
# (array([55]),)
# (array([57]),)
# (array([63]),)
# (array([64]),)
# (array([67]),)
# (array([70]),)
# (array([74]),)
# (array([77]),)
# (array([81]),)
# (array([85]),)
# (array([87]),)
# (array([90]),)
# (array([95]),)
# (array([97]),)
# (array([101]),)
# (array([103]),)
# (array([106]),)
# (array([107]),)
# (array([111]),)
# (array([113]),)
# (array([119]),)
# (array([123]),)
# (array([127]),)
# (array([129]),)
# (array([137]),)
# (array([133]),)
# (array([130]),)
# (array([131]),)
# (array([126]),)
# (array([136]),)
# (array([114]),)
# (array([128]),)
# (array([117]),)
# (array([122]),)
# (array([116]),)
# (array([124]),)
# (array([132]),)
# (array([118]),)
# (array([94]),)
# (array([40]),)
# (array([5]),)
# (array([3]),)
# (array([1]),)
# (array([0]),)
# (array([2]),)
# (array([4]),)
# (array([7]),)
# (array([38]),)
# (array([47]),)
# (array([48]),)
# (array([54]),)
# (array([56]),)
# (array([59]),)
# (array([60]),)
# (array([63]),)
# (array([64]),)
# (array([67]),)
# (array([68]),)
# (array([70]),)
# (array([71]),)
# (array([74]),)
# (array([75]),)
# (array([78]),)
# (array([79]),)
# (array([84]),)
# (array([85]),)
# (array([87]),)
# (array([86]),)
# (array([93]),)
# (array([95]),)
# (array([96]),)
# (array([98]),)
# (array([101]),)
# (array([103]),)
# (array([105]),)
# (array([104]),)
# (array([108]),)
# (array([109]),)
# (array([114]),)
# (array([111]),)
# (array([126]),)
# (array([119]),)
# (array([134]),)
# (array([136]),)
# (array([138]),)
# (array([137]),)
# (array([140]),)
# (array([141]),)
# (array([142]),)
# (array([143]),)
# (array([144]),)
# (array([145]),)
# (array([151]),)
# (array([148]),)
# (array([153]),)
# (array([152]),)
# (array([157]),)
# (array([158]),)
# (array([155]),)
# (array([147]),)
# (array([150]),)
# (array([149]),)
# (array([156]),)
# (array([154]),)
# (array([146]),)
# (array([99]),)
# (array([89]),)
# (array([62]),)
# (array([53]),)
# (array([92]),)
# (array([80]),)
# (array([135]),)
# (array([139]),)
# (array([49]),)
# (array([16]),)
# (array([77]),)
# (array([82]),)
# (array([72]),)
# (array([51]),)
# (array([55]),)
# (array([45]),)
# (array([40]),)
# (array([37]),)
# (array([33]),)
# (array([30]),)
# (array([29]),)
# (array([26]),)
# (array([25]),)
# (array([21]),)
# (array([20]),)
# (array([18]),)
# (array([19]),)
# (array([10]),)
# (array([13]),)
# (array([12]),)
# (array([17]),)
# (array([15]),)
# (array([11]),)
# (array([6]),)
# (array([9]),)
# (array([8]),)
# (array([14]),)
# (array([22]),)
# (array([23]),)
# (array([24]),)
# (array([27]),)
# (array([28]),)
# (array([31]),)
# (array([32]),)
# (array([34]),)
# (array([36]),)
# (array([39]),)
# (array([41]),)
# (array([42]),)
# (array([43]),)
# (array([44]),)
# (array([46]),)
# (array([50]),)
# (array([52]),)
# (array([57]),)
# (array([58]),)
# (array([61]),)
# (array([65]),)
# (array([66]),)
# (array([69]),)
# (array([73]),)
# (array([76]),)
# (array([81]),)
# (array([83]),)
# (array([88]),)
# (array([91]),)
# (array([94]),)
# (array([97]),)
# (array([100]),)
# (array([102]),)
# (array([106]),)
# (array([107]),)
# (array([110]),)
# (array([113]),)
# (array([118]),)
# (array([121]),)
# (array([128]),)
# (array([130]),)
# (array([133]),)
# (array([132]),)
# (array([127]),)
# (array([129]),)
# (array([125]),)
# (array([124]),)
# (array([112]),)
# (array([122]),)
# (array([117]),)
# (array([116]),)
# (array([115]),)
# (array([120]),)
# (array([131]),)
# (array([123]),)
# (array([90]),)
# (array([35]),)
# (array([5]),)
# (array([3]),)
# (array([1]),)
# (array([0]),)
# (array([2]),)
# (array([4]),)
# (array([6]),)
# (array([31]),)
# (array([43]),)
# (array([45]),)
# (array([51]),)
# (array([52]),)
# (array([55]),)
# (array([56]),)
# (array([58]),)
# (array([60]),)
# (array([63]),)
# (array([64]),)
# (array([66]),)
# (array([67]),)
# (array([70]),)
# (array([71]),)
# (array([75]),)
# (array([74]),)
# (array([78]),)
# (array([79]),)
# (array([83]),)
# (array([81]),)
# (array([87]),)
# (array([88]),)
# (array([90]),)
# (array([92]),)
# (array([95]),)
# (array([97]),)
# (array([100]),)
# (array([98]),)
# (array([103]),)
# (array([104]),)
# (array([108]),)
# (array([106]),)
# (array([113]),)
# (array([110]),)
# (array([114]),)
# (array([119]),)
# (array([122]),)
# (array([120]),)
# (array([128]),)
# (array([133]),)
# (array([140]),)
# (array([143]),)
# (array([145]),)
# (array([144]),)
# (array([146]),)
# (array([149]),)
# (array([151]),)
# (array([147]),)
# (array([150]),)
# (array([148]),)
# (array([109]),)
# (array([99]),)
# (array([68]),)
# (array([49]),)
# (array([85]),)
# (array([77]),)
# (array([142]),)
# (array([139]),)
# (array([59]),)
# (array([7]),)
# (array([84]),)
# (array([89]),)
# (array([72]),)
# (array([47]),)
# (array([54]),)
# (array([44]),)
# (array([39]),)
# (array([37]),)
# (array([34]),)
# (array([30]),)
# (array([27]),)
# (array([26]),)
# (array([23]),)
# (array([21]),)
# (array([20]),)
# (array([12]),)
# (array([18]),)
# (array([9]),)
# (array([14]),)
# (array([10]),)
# (array([17]),)
# (array([16]),)
# (array([15]),)
# (array([8]),)
# (array([13]),)
# (array([11]),)
# (array([19]),)
# (array([22]),)
# (array([24]),)
# (array([25]),)
# (array([28]),)
# (array([29]),)
# (array([32]),)
# (array([33]),)
# (array([35]),)
# (array([38]),)
# (array([40]),)
# (array([41]),)
# (array([42]),)
# (array([46]),)
# (array([48]),)
# (array([50]),)
# (array([53]),)
# (array([57]),)
# (array([61]),)
# (array([62]),)
# (array([65]),)
# (array([69]),)
# (array([73]),)
# (array([76]),)
# (array([80]),)
# (array([82]),)
# (array([86]),)
# (array([91]),)
# (array([94]),)
# (array([96]),)
# (array([101]),)
# (array([102]),)
# (array([105]),)
# (array([107]),)
# (array([111]),)
# (array([112]),)
# (array([115]),)
# (array([118]),)
# (array([126]),)
# (array([129]),)
# (array([131]),)
# (array([136]),)
# (array([141]),)
# (array([132]),)
# (array([134]),)
# (array([138]),)
# (array([135]),)
# (array([137]),)
# (array([116]),)
# (array([130]),)
# (array([124]),)
# (array([123]),)
# (array([121]),)
# (array([125]),)
# (array([127]),)
# (array([117]),)
# (array([93]),)
# (array([36]),)
# (array([5]),)
# (array([3]),)
# (array([1]),)
# (array([0]),)
# (array([2]),)
# (array([4]),)
# (array([25]),)
# (array([37]),)
# (array([44]),)
# (array([42]),)
# (array([45]),)
# (array([46]),)
# (array([49]),)
# (array([48]),)
# (array([51]),)
# (array([50]),)
# (array([56]),)
# (array([54]),)
# (array([58]),)
# (array([60]),)
# (array([62]),)
# (array([61]),)
# (array([65]),)
# (array([66]),)
# (array([67]),)
# (array([68]),)
# (array([72]),)
# (array([71]),)
# (array([74]),)
# (array([73]),)
# (array([77]),)
# (array([78]),)
# (array([79]),)
# (array([80]),)
# (array([82]),)
# (array([81]),)
# (array([85]),)
# (array([84]),)
# (array([89]),)
# (array([86]),)
# (array([90]),)
# (array([87]),)
# (array([91]),)
# (array([94]),)
# (array([96]),)
# (array([92]),)
# (array([98]),)
# (array([97]),)
# (array([100]),)
# (array([103]),)
# (array([105]),)
# (array([104]),)
# (array([107]),)
# (array([109]),)
# (array([121]),)
# (array([124]),)
# (array([126]),)
# (array([129]),)
# (array([114]),)
# (array([111]),)
# (array([76]),)
# (array([55]),)
# (array([102]),)
# (array([93]),)
# (array([128]),)
# (array([130]),)
# (array([64]),)
# (array([27]),)
# (array([110]),)
# (array([116]),)
# (array([99]),)
# (array([57]),)
# (array([69]),)
# (array([53]),)
# (array([41]),)
# (array([38]),)
# (array([34]),)
# (array([31]),)
# (array([29]),)
# (array([26]),)
# (array([22]),)
# (array([21]),)
# (array([18]),)
# (array([16]),)
# (array([15]),)
# (array([11]),)
# (array([12]),)
# (array([7]),)
# (array([13]),)
# (array([10]),)
# (array([9]),)
# (array([5]),)
# (array([8]),)
# (array([6]),)
# (array([14]),)
# (array([17]),)
# (array([19]),)
# (array([20]),)
# (array([23]),)
# (array([24]),)
# (array([28]),)
# (array([30]),)
# (array([32]),)
# (array([33]),)
# (array([36]),)
# (array([39]),)
# (array([40]),)
# (array([43]),)
# (array([47]),)
# (array([52]),)
# (array([59]),)
# (array([63]),)
# (array([70]),)
# (array([75]),)
# (array([83]),)
# (array([88]),)
# (array([95]),)
# (array([101]),)
# (array([108]),)
# (array([112]),)
# (array([113]),)
# (array([115]),)
# (array([117]),)
# (array([118]),)
# (array([119]),)
# (array([120]),)
# (array([122]),)
# (array([123]),)
# (array([125]),)
# (array([127]),)
# (array([133]),)
# (array([137]),)
# (array([138]),)
# (array([142]),)
# (array([143]),)
# (array([144]),)
# (array([139]),)
# (array([141]),)
# (array([131]),)
# (array([140]),)
# (array([134]),)
# (array([135]),)
# (array([132]),)
# (array([136]),)
# (array([106]),)
# (array([35]),)
# (array([3]),)
# (array([1]),)
# (array([0]),)
# (array([2]),)
# (array([4]),)
# (array([6]),)
# (array([26]),)
# (array([42]),)
# (array([43]),)
# (array([48]),)
# (array([51]),)
# (array([52]),)
# (array([54]),)
# (array([57]),)
# (array([58]),)
# (array([60]),)
# (array([62]),)
# (array([63]),)
# (array([65]),)
# (array([68]),)
# (array([70]),)
# (array([72]),)
# (array([71]),)
# (array([76]),)
# (array([77]),)
# (array([79]),)
# (array([78]),)
# (array([82]),)
# (array([84]),)
# (array([86]),)
# (array([88]),)
# (array([91]),)
# (array([93]),)
# (array([95]),)
# (array([96]),)
# (array([98]),)
# (array([99]),)
# (array([104]),)
# (array([102]),)
# (array([108]),)
# (array([105]),)
# (array([110]),)
# (array([112]),)
# (array([116]),)
# (array([114]),)
# (array([117]),)
# (array([119]),)
# (array([121]),)
# (array([124]),)
# (array([131]),)
# (array([130]),)
# (array([111]),)
# (array([107]),)
# (array([85]),)
# (array([67]),)
# (array([100]),)
# (array([89]),)
# (array([126]),)
# (array([66]),)
# (array([31]),)
# (array([83]),)
# (array([92]),)
# (array([74]),)
# (array([49]),)
# (array([55]),)
# (array([46]),)
# (array([39]),)
# (array([37]),)
# (array([36]),)
# (array([30]),)
# (array([29]),)
# (array([25]),)
# (array([23]),)
# (array([20]),)
# (array([19]),)
# (array([11]),)
# (array([18]),)
# (array([9]),)
# (array([13]),)
# (array([10]),)
# (array([16]),)
# (array([15]),)
# (array([14]),)
# (array([7]),)
# (array([12]),)
# (array([8]),)
# (array([17]),)
# (array([21]),)
# (array([22]),)
# (array([24]),)
# (array([27]),)
# (array([28]),)
# (array([32]),)
# (array([33]),)
# (array([34]),)
# (array([38]),)
# (array([40]),)
# (array([41]),)
# (array([44]),)
# (array([45]),)
# (array([47]),)
# (array([50]),)
# (array([53]),)
# (array([56]),)
# (array([59]),)
# (array([61]),)
# (array([64]),)
# (array([69]),)
# (array([73]),)
# (array([75]),)
# (array([80]),)
# (array([81]),)
# (array([87]),)
# (array([90]),)
# (array([94]),)
# (array([97]),)
# (array([101]),)
# (array([103]),)
# (array([106]),)
# (array([109]),)
# (array([113]),)
# (array([115]),)
# (array([118]),)
# (array([120]),)
# (array([123]),)
# (array([125]),)
# (array([132]),)
# (array([137]),)
# (array([136]),)
# (array([135]),)
# (array([122]),)
# (array([134]),)
# (array([129]),)
# (array([128]),)
# (array([127]),)
# (array([133]),)
# (array([35]),)
# (array([5]),)
# (array([3]),)
# (array([1]),)
# (array([0]),)
# (array([2]),)
# (array([4]),)
# (array([31]),)
# (array([41]),)
# (array([48]),)
# (array([45]),)
# (array([53]),)
# (array([54]),)
# (array([57]),)
# (array([56]),)
# (array([60]),)
# (array([61]),)
# (array([64]),)
# (array([65]),)
# (array([67]),)
# (array([68]),)
# (array([70]),)
# (array([69]),)
# (array([73]),)
# (array([74]),)
# (array([77]),)
# (array([78]),)
# (array([84]),)
# (array([83]),)
# (array([86]),)
# (array([87]),)
# (array([88]),)
# (array([90]),)
# (array([92]),)
# (array([94]),)
# (array([96]),)
# (array([93]),)
# (array([97]),)
# (array([98]),)
# (array([102]),)
# (array([100]),)
# (array([105]),)
# (array([103]),)
# (array([106]),)
# (array([108]),)
# (array([110]),)
# (array([107]),)
# (array([112]),)
# (array([111]),)
# (array([114]),)
# (array([115]),)
# (array([118]),)
# (array([117]),)
# (array([99]),)
# (array([91]),)
# (array([63]),)
# (array([47]),)
# (array([81]),)
# (array([80]),)
# (array([113]),)
# (array([58]),)
# (array([21]),)
# (array([75]),)
# (array([82]),)
# (array([72]),)
# (array([49]),)
# (array([52]),)
# (array([43]),)
# (array([39]),)
# (array([37]),)
# (array([35]),)
# (array([32]),)
# (array([30]),)
# (array([27]),)
# (array([26]),)
# (array([23]),)
# (array([20]),)
# (array([16]),)
# (array([18]),)
# (array([12]),)
# (array([13]),)
# (array([11]),)
# (array([14]),)
# (array([15]),)
# (array([10]),)
# (array([6]),)
# (array([8]),)
# (array([7]),)
# (array([9]),)
# (array([17]),)
# (array([19]),)
# (array([22]),)
# (array([24]),)
# (array([25]),)
# (array([28]),)
# (array([29]),)
# (array([33]),)
# (array([34]),)
# (array([36]),)
# (array([38]),)
# (array([40]),)
# (array([42]),)
# (array([44]),)
# (array([46]),)
# (array([51]),)
# (array([55]),)
# (array([59]),)
# (array([62]),)
# (array([66]),)
# (array([71]),)
# (array([76]),)
# (array([79]),)
# (array([85]),)
# (array([89]),)
# (array([95]),)
# (array([101]),)
# (array([104]),)
# (array([109]),)
# (array([116]),)
# (array([119]),)
# (array([120]),)
# (array([121]),)
# (array([122]),)
# (array([123]),)
# (array([124]),)
# (array([128]),)
# (array([125]),)
# (array([131]),)
# (array([129]),)
# (array([126]),)
# (array([127]),)
# (array([130]),)
# (array([50]),)
# (array([5]),)
# (array([3]),)
# (array([1]),)
# (array([0]),)
# (array([28]),)
# (array([71]),)
# (array([91]),)
# (array([93]),)
# (array([92]),)
# (array([86]),)
# (array([87]),)
# (array([81]),)
# (array([80]),)
# (array([78]),)
# (array([77]),)
# (array([74]),)
# (array([75]),)
# (array([70]),)
# (array([72]),)
# (array([68]),)
# (array([69]),)
# (array([65]),)
# (array([67]),)
# (array([66]),)
# (array([64]),)
# (array([62]),)
# (array([61]),)
# (array([59]),)
# (array([60]),)
# (array([55]),)
# (array([58]),)
# (array([56]),)
# (array([54]),)
# (array([52]),)
# (array([53]),)
# (array([49]),)
# (array([50]),)
# (array([47]),)
# (array([51]),)
# (array([45]),)
# (array([46]),)
# (array([41]),)
# (array([43]),)
# (array([42]),)
# (array([40]),)
# (array([36]),)
# (array([39]),)
# (array([34]),)
# (array([35]),)
# (array([32]),)
# (array([33]),)
# (array([31]),)
# (array([90]),)
# (array([88]),)
# (array([85]),)
# (array([84]),)
# (array([100]),)
# (array([101]),)
# (array([105]),)
# (array([97]),)
# (array([79]),)
# (array([117]),)
# (array([116]),)
# (array([106]),)
# (array([98]),)
# (array([95]),)
# (array([76]),)
# (array([44]),)
# (array([29]),)
# (array([26]),)
# (array([23]),)
# (array([21]),)
# (array([18]),)
# (array([17]),)
# (array([14]),)
# (array([9]),)
# (array([10]),)
# (array([6]),)
# (array([5]),)
# (array([2]),)
# (array([8]),)
# (array([3]),)
# (array([11]),)
# (array([7]),)
# (array([4]),)
# (array([12]),)
# (array([13]),)
# (array([16]),)
# (array([19]),)
# (array([20]),)
# (array([22]),)
# (array([24]),)
# (array([25]),)
# (array([27]),)
# (array([30]),)
# (array([38]),)
# (array([48]),)
# (array([57]),)
# (array([63]),)
# (array([73]),)
# (array([83]),)
# (array([89]),)
# (array([94]),)
# (array([96]),)
# (array([99]),)
# (array([102]),)
# (array([103]),)
# (array([104]),)
# (array([107]),)
# (array([108]),)
# (array([109]),)
# (array([113]),)
# (array([118]),)
# (array([120]),)
# (array([121]),)
# (array([122]),)
# (array([123]),)
# (array([124]),)
# (array([125]),)
# (array([111]),)
# (array([119]),)
# (array([112]),)
# (array([114]),)
# (array([110]),)
# (array([115]),)
# (array([82]),)
# (array([37]),)
# (array([15]),)
# (array([1]),)
# (array([0]),)
# (array([2]),)
# (array([4]),)
# (array([8]),)
# (array([39]),)
# (array([47]),)
# (array([48]),)
# (array([53]),)
# (array([55]),)
# (array([57]),)
# (array([59]),)
# (array([63]),)
# (array([64]),)
# (array([68]),)
# (array([69]),)
# (array([72]),)
# (array([73]),)
# (array([76]),)
# (array([78]),)
# (array([80]),)
# (array([81]),)
# (array([86]),)
# (array([87]),)
# (array([90]),)
# (array([89]),)
# (array([93]),)
# (array([92]),)
# (array([99]),)
# (array([101]),)
# (array([104]),)
# (array([106]),)
# (array([108]),)
# (array([105]),)
# (array([109]),)
# (array([110]),)
# (array([113]),)
# (array([112]),)
# (array([115]),)
# (array([114]),)
# (array([116]),)
# (array([118]),)
# (array([119]),)
# (array([117]),)
# (array([103]),)
# (array([97]),)
# (array([74]),)
# (array([60]),)
# (array([107]),)
# (array([88]),)
# (array([111]),)
# (array([61]),)
# (array([31]),)
# (array([98]),)
# (array([83]),)
# (array([67]),)
# (array([51]),)
# (array([50]),)
# (array([44]),)
# (array([38]),)
# (array([35]),)
# (array([33]),)
# (array([29]),)
# (array([28]),)
# (array([25]),)
# (array([24]),)
# (array([20]),)
# (array([18]),)
# (array([10]),)
# (array([19]),)
# (array([11]),)
# (array([13]),)
# (array([12]),)
# (array([17]),)
# (array([16]),)
# (array([14]),)
# (array([6]),)
# (array([9]),)
# (array([7]),)
# (array([15]),)
# (array([21]),)
# (array([22]),)
# (array([23]),)
# (array([26]),)
# (array([27]),)
# (array([30]),)
# (array([32]),)
# (array([34]),)
# (array([36]),)
# (array([40]),)
# (array([41]),)
# (array([42]),)
# (array([43]),)
# (array([45]),)
# (array([46]),)
# (array([49]),)
# (array([52]),)
# (array([54]),)
# (array([56]),)
# (array([58]),)
# (array([62]),)
# (array([65]),)
# (array([66]),)
# (array([70]),)
# (array([71]),)
# (array([75]),)
# (array([77]),)
# (array([79]),)
# (array([82]),)
# (array([84]),)
# (array([85]),)
# (array([91]),)
# (array([100]),)
# (array([94]),)
# (array([95]),)
# (array([96]),)
# (array([102]),)
# (array([37]),)
# (array([5]),)
# (array([3]),)
# (array([1]),)
# (array([0]),)
# (array([2]),)
# (array([4]),)
# (array([5]),)
# (array([26]),)
# (array([40]),)
# (array([42]),)
# (array([48]),)
# (array([52]),)
# (array([54]),)
# (array([57]),)
# (array([60]),)
# (array([61]),)
# (array([64]),)
# (array([65]),)
# (array([68]),)
# (array([69]),)
# (array([71]),)
# (array([72]),)
# (array([75]),)
# (array([76]),)
# (array([80]),)
# (array([83]),)
# (array([87]),)
# (array([85]),)
# (array([91]),)
# (array([90]),)
# (array([92]),)
# (array([94]),)
# (array([99]),)
# (array([104]),)
# (array([107]),)
# (array([101]),)
# (array([110]),)
# (array([111]),)
# (array([112]),)
# (array([113]),)
# (array([97]),)
# (array([105]),)
# (array([74]),)
# (array([56]),)
# (array([96]),)
# (array([82]),)
# (array([106]),)
# (array([58]),)
# (array([7]),)
# (array([84]),)
# (array([79]),)
# (array([66]),)
# (array([49]),)
# (array([51]),)
# (array([44]),)
# (array([38]),)
# (array([36]),)
# (array([34]),)
# (array([31]),)
# (array([30]),)
# (array([27]),)
# (array([24]),)
# (array([21]),)
# (array([17]),)
# (array([9]),)
# (array([20]),)
# (array([11]),)
# (array([12]),)
# (array([14]),)
# (array([18]),)
# (array([19]),)
# (array([15]),)
# (array([8]),)
# (array([13]),)
# (array([10]),)
# (array([16]),)
# (array([22]),)
# (array([23]),)
# (array([25]),)
# (array([28]),)
# (array([29]),)
# (array([32]),)
# (array([33]),)
# (array([35]),)
# (array([37]),)
# (array([39]),)
# (array([41]),)
# (array([43]),)
# (array([45]),)
# (array([47]),)
# (array([50]),)
# (array([53]),)
# (array([55]),)
# (array([59]),)
# (array([62]),)
# (array([63]),)
# (array([67]),)
# (array([70]),)
# (array([73]),)
# (array([77]),)
# (array([78]),)
# (array([81]),)
# (array([86]),)
# (array([88]),)
# (array([89]),)
# (array([93]),)
# (array([95]),)
# (array([98]),)
# (array([108]),)
# (array([103]),)
# (array([102]),)
# (array([100]),)
# (array([109]),)
# (array([46]),)
# (array([6]),)
# (array([3]),)
# (array([1]),)
# (array([0]),)
# (array([2]),)
# (array([4]),)
# (array([24]),)
# (array([28]),)
# (array([32]),)
# (array([31]),)
# (array([35]),)
# (array([34]),)
# (array([37]),)
# (array([36]),)
# (array([40]),)
# (array([39]),)
# (array([44]),)
# (array([43]),)
# (array([47]),)
# (array([46]),)
# (array([50]),)
# (array([45]),)
# (array([51]),)
# (array([49]),)
# (array([60]),)
# (array([56]),)
# (array([61]),)
# (array([54]),)
# (array([67]),)
# (array([52]),)
# (array([63]),)
# (array([64]),)
# (array([66]),)
# (array([59]),)
# (array([69]),)
# (array([53]),)
# (array([62]),)
# (array([58]),)
# (array([65]),)
# (array([55]),)
# (array([87]),)
# (array([89]),)
# (array([80]),)
# (array([78]),)
# (array([96]),)
# (array([91]),)
# (array([98]),)
# (array([81]),)
# (array([57]),)
# (array([100]),)
# (array([94]),)
# (array([84]),)
# (array([83]),)
# (array([76]),)
# (array([72]),)
# (array([68]),)
# (array([42]),)
# (array([29]),)
# (array([26]),)
# (array([22]),)
# (array([20]),)
# (array([18]),)
# (array([16]),)
# (array([9]),)
# (array([14]),)
# (array([7]),)
# (array([6]),)
# (array([11]),)
# (array([8]),)
# (array([15]),)
# (array([10]),)
# (array([5]),)
# (array([13]),)
# (array([12]),)
# (array([17]),)
# (array([19]),)
# (array([21]),)
# (array([23]),)
# (array([25]),)
# (array([27]),)
# (array([30]),)
# (array([33]),)
# (array([41]),)
# (array([48]),)
# (array([70]),)
# (array([71]),)
# (array([73]),)
# (array([74]),)
# (array([75]),)
# (array([77]),)
# (array([79]),)
# (array([82]),)
# (array([85]),)
# (array([88]),)
# (array([90]),)
# (array([92]),)
# (array([93]),)
# (array([95]),)
# (array([97]),)
# (array([99]),)
# (array([101]),)
# (array([103]),)
# (array([107]),)
# (array([104]),)
# (array([105]),)
# (array([106]),)
# (array([102]),)
# (array([108]),)
# (array([86]),)
# (array([38]),)
# (array([3]),)
# (array([1]),)
# (array([0]),)
# (array([2]),)
# (array([4]),)
# (array([5]),)
# (array([29]),)
# (array([41]),)
# (array([43]),)
# (array([50]),)
# (array([51]),)
# (array([56]),)
# (array([57]),)
# (array([61]),)
# (array([62]),)
# (array([65]),)
# (array([66]),)
# (array([71]),)
# (array([72]),)
# (array([76]),)
# (array([75]),)
# (array([79]),)
# (array([80]),)
# (array([83]),)
# (array([84]),)
# (array([86]),)
# (array([85]),)
# (array([95]),)
# (array([94]),)
# (array([97]),)
# (array([98]),)
# (array([100]),)
# (array([101]),)
# (array([99]),)
# (array([96]),)
# (array([90]),)
# (array([70]),)
# (array([59]),)
# (array([102]),)
# (array([88]),)
# (array([103]),)
# (array([54]),)
# (array([7]),)
# (array([77]),)
# (array([68]),)
# (array([47]),)
# (array([49]),)
# (array([44]),)
# (array([38]),)
# (array([35]),)
# (array([32]),)
# (array([30]),)
# (array([27]),)
# (array([25]),)
# (array([24]),)
# (array([19]),)
# (array([20]),)
# (array([9]),)
# (array([21]),)
# (array([12]),)
# (array([13]),)
# (array([16]),)
# (array([17]),)
# (array([18]),)
# (array([14]),)
# (array([8]),)
# (array([11]),)
# (array([10]),)
# (array([15]),)
# (array([22]),)
# (array([23]),)
# (array([26]),)
# (array([28]),)
# (array([31]),)
# (array([33]),)
# (array([34]),)
# (array([36]),)
# (array([37]),)
# (array([39]),)
# (array([40]),)
# (array([42]),)
# (array([45]),)
# (array([46]),)
# (array([48]),)
# (array([53]),)
# (array([55]),)
# (array([58]),)
# (array([60]),)
# (array([63]),)
# (array([64]),)
# (array([67]),)
# (array([69]),)
# (array([74]),)
# (array([73]),)
# (array([78]),)
# (array([81]),)
# (array([82]),)
# (array([91]),)
# (array([93]),)
# (array([87]),)
# (array([89]),)
# (array([92]),)
# (array([52]),)
# (array([6]),)
# (array([3]),)
# (array([1]),)
# (array([0]),)
# (array([2]),)
# (array([3]),)
# (array([5]),)
# (array([22]),)
# (array([34]),)
# (array([35]),)
# (array([41]),)
# (array([43]),)
# (array([46]),)
# (array([47]),)
# (array([50]),)
# (array([51]),)
# (array([55]),)
# (array([54]),)
# (array([57]),)
# (array([58]),)
# (array([63]),)
# (array([61]),)
# (array([65]),)
# (array([66]),)
# (array([69]),)
# (array([70]),)
# (array([73]),)
# (array([71]),)
# (array([76]),)
# (array([74]),)
# (array([77]),)
# (array([80]),)
# (array([82]),)
# (array([81]),)
# (array([79]),)
# (array([92]),)
# (array([95]),)
# (array([84]),)
# (array([67]),)
# (array([98]),)
# (array([94]),)
# (array([97]),)
# (array([64]),)
# (array([7]),)
# (array([91]),)
# (array([86]),)
# (array([56]),)
# (array([59]),)
# (array([49]),)
# (array([42]),)
# (array([39]),)
# (array([36]),)
# (array([30]),)
# (array([29]),)
# (array([26]),)
# (array([25]),)
# (array([20]),)
# (array([19]),)
# (array([11]),)
# (array([18]),)
# (array([10]),)
# (array([15]),)
# (array([13]),)
# (array([16]),)
# (array([17]),)
# (array([12]),)
# (array([6]),)
# (array([9]),)
# (array([8]),)
# (array([14]),)
# (array([21]),)
# (array([23]),)
# (array([24]),)
# (array([27]),)
# (array([28]),)
# (array([31]),)
# (array([33]),)
# (array([37]),)
# (array([38]),)
# (array([40]),)
# (array([44]),)
# (array([45]),)
# (array([48]),)
# (array([52]),)
# (array([53]),)
# (array([60]),)
# (array([62]),)
# (array([68]),)
# (array([72]),)
# (array([78]),)
# (array([83]),)
# (array([85]),)
# (array([87]),)
# (array([89]),)
# (array([88]),)
# (array([90]),)
# (array([93]),)
# (array([96]),)
# (array([75]),)
# (array([32]),)
# (array([4]),)
# (array([1]),)
# (array([0]),)
# (array([2]),)
# (array([4]),)
# (array([5]),)
# (array([26]),)
# (array([39]),)
# (array([40]),)
# (array([46]),)
# (array([49]),)
# (array([52]),)
# (array([54]),)
# (array([56]),)
# (array([58]),)
# (array([61]),)
# (array([62]),)
# (array([65]),)
# (array([64]),)
# (array([68]),)
# (array([67]),)
# (array([71]),)
# (array([72]),)
# (array([76]),)
# (array([77]),)
# (array([82]),)
# (array([83]),)
# (array([87]),)
# (array([86]),)
# (array([89]),)
# (array([90]),)
# (array([91]),)
# (array([92]),)
# (array([93]),)
# (array([84]),)
# (array([88]),)
# (array([79]),)
# (array([59]),)
# (array([20]),)
# (array([73]),)
# (array([48]),)
# (array([53]),)
# (array([45]),)
# (array([37]),)
# (array([35]),)
# (array([34]),)
# (array([31]),)
# (array([28]),)
# (array([23]),)
# (array([22]),)
# (array([15]),)
# (array([8]),)
# (array([7]),)
# (array([13]),)
# (array([9]),)
# (array([11]),)
# (array([12]),)
# (array([16]),)
# (array([17]),)
# (array([18]),)
# (array([10]),)
# (array([19]),)
# (array([14]),)
# (array([21]),)
# (array([24]),)
# (array([25]),)
# (array([27]),)
# (array([29]),)
# (array([30]),)
# (array([32]),)
# (array([33]),)
# (array([36]),)
# (array([38]),)
# (array([41]),)
# (array([42]),)
# (array([44]),)
# (array([47]),)
# (array([50]),)
# (array([51]),)
# (array([55]),)
# (array([57]),)
# (array([60]),)
# (array([63]),)
# (array([66]),)
# (array([69]),)
# (array([70]),)
# (array([74]),)
# (array([75]),)
# (array([81]),)
# (array([78]),)
# (array([80]),)
# (array([85]),)
# (array([43]),)
# (array([6]),)
# (array([3]),)
# (array([1]),)
# (array([0]),)
# (array([1]),)
# (array([3]),)
# (array([4]),)
# (array([18]),)
# (array([35]),)
# (array([39]),)
# (array([45]),)
# (array([47]),)
# (array([50]),)
# (array([52]),)
# (array([55]),)
# (array([57]),)
# (array([61]),)
# (array([63]),)
# (array([66]),)
# (array([67]),)
# (array([71]),)
# (array([70]),)
# (array([73]),)
# (array([74]),)
# (array([76]),)
# (array([77]),)
# (array([80]),)
# (array([81]),)
# (array([85]),)
# (array([82]),)
# (array([86]),)
# (array([87]),)
# (array([88]),)
# (array([89]),)
# (array([68]),)
# (array([60]),)
# (array([41]),)
# (array([56]),)
# (array([6]),)
# (array([64]),)
# (array([42]),)
# (array([49]),)
# (array([43]),)
# (array([37]),)
# (array([33]),)
# (array([34]),)
# (array([30]),)
# (array([29]),)
# (array([26]),)
# (array([25]),)
# (array([23]),)
# (array([20]),)
# (array([17]),)
# (array([19]),)
# (array([14]),)
# (array([13]),)
# (array([11]),)
# (array([16]),)
# (array([15]),)
# (array([10]),)
# (array([7]),)
# (array([9]),)
# (array([8]),)
# (array([12]),)
# (array([21]),)
# (array([22]),)
# (array([24]),)
# (array([27]),)
# (array([28]),)
# (array([31]),)
# (array([32]),)
# (array([36]),)
# (array([38]),)
# (array([40]),)
# (array([44]),)
# (array([46]),)
# (array([48]),)
# (array([51]),)
# (array([54]),)
# (array([58]),)
# (array([59]),)
# (array([62]),)
# (array([65]),)
# (array([69]),)
# (array([72]),)
# (array([75]),)
# (array([78]),)
# (array([83]),)
# (array([84]),)
# (array([79]),)
# (array([53]),)
# (array([5]),)
# (array([2]),)
# (array([0]),)
# (array([1]),)
# (array([3]),)
# (array([6]),)
# (array([8]),)
# (array([28]),)
# (array([26]),)
# (array([33]),)
# (array([34]),)
# (array([38]),)
# (array([39]),)
# (array([42]),)
# (array([43]),)
# (array([46]),)
# (array([47]),)
# (array([50]),)
# (array([49]),)
# (array([54]),)
# (array([53]),)
# (array([58]),)
# (array([57]),)
# (array([61]),)
# (array([60]),)
# (array([63]),)
# (array([62]),)
# (array([66]),)
# (array([64]),)
# (array([65]),)
# (array([68]),)
# (array([71]),)
# (array([72]),)
# (array([67]),)
# (array([51]),)
# (array([36]),)
# (array([52]),)
# (array([5]),)
# (array([84]),)
# (array([75]),)
# (array([77]),)
# (array([70]),)
# (array([55]),)
# (array([45]),)
# (array([41]),)
# (array([35]),)
# (array([32]),)
# (array([29]),)
# (array([25]),)
# (array([22]),)
# (array([21]),)
# (array([19]),)
# (array([20]),)
# (array([14]),)
# (array([15]),)
# (array([13]),)
# (array([17]),)
# (array([16]),)
# (array([12]),)
# (array([9]),)
# (array([11]),)
# (array([10]),)
# (array([18]),)
# (array([23]),)
# (array([24]),)
# (array([27]),)
# (array([30]),)
# (array([31]),)
# (array([37]),)
# (array([40]),)
# (array([44]),)
# (array([48]),)
# (array([56]),)
# (array([59]),)
# (array([69]),)
# (array([74]),)
# (array([76]),)
# (array([78]),)
# (array([79]),)
# (array([80]),)
# (array([81]),)
# (array([82]),)
# (array([83]),)
# (array([85]),)
# (array([73]),)
# (array([7]),)
# (array([4]),)
# (array([2]),)
# (array([0]),)
# (array([2]),)
# (array([4]),)
# (array([6]),)
# (array([22]),)
# (array([40]),)
# (array([43]),)
# (array([49]),)
# (array([55]),)
# (array([60]),)
# (array([62]),)
# (array([63]),)
# (array([64]),)
# (array([65]),)
# (array([66]),)
# (array([67]),)
# (array([68]),)
# (array([71]),)
# (array([72]),)
# (array([73]),)
# (array([74]),)
# (array([77]),)
# (array([76]),)
# (array([78]),)
# (array([79]),)
# (array([81]),)
# (array([80]),)
# (array([61]),)
# (array([75]),)
# (array([70]),)
# (array([50]),)
# (array([7]),)
# (array([69]),)
# (array([53]),)
# (array([51]),)
# (array([44]),)
# (array([39]),)
# (array([35]),)
# (array([32]),)
# (array([31]),)
# (array([28]),)
# (array([26]),)
# (array([23]),)
# (array([21]),)
# (array([17]),)
# (array([16]),)
# (array([20]),)
# (array([11]),)
# (array([12]),)
# (array([13]),)
# (array([18]),)
# (array([19]),)
# (array([15]),)
# (array([8]),)
# (array([10]),)
# (array([9]),)
# (array([14]),)
# (array([25]),)
# (array([24]),)
# (array([27]),)
# (array([30]),)
# (array([29]),)
# (array([33]),)
# (array([34]),)
# (array([37]),)
# (array([38]),)
# (array([41]),)
# (array([42]),)
# (array([45]),)
# (array([46]),)
# (array([47]),)
# (array([48]),)
# (array([52]),)
# (array([54]),)
# (array([56]),)
# (array([57]),)
# (array([58]),)
# (array([59]),)
# (array([36]),)
# (array([5]),)
# (array([3]),)
# (array([1]),)
# (array([0]),)
# (array([5]),)
# (array([39]),)
# (array([48]),)
# (array([47]),)
# (array([46]),)
# (array([41]),)
# (array([42]),)
# (array([38]),)
# (array([37]),)
# (array([32]),)
# (array([30]),)
# (array([20]),)
# (array([23]),)
# (array([16]),)
# (array([17]),)
# (array([14]),)
# (array([15]),)
# (array([12]),)
# (array([13]),)
# (array([11]),)
# (array([10]),)
# (array([9]),)
# (array([8]),)
# (array([7]),)
# (array([4]),)
# (array([3]),)
# (array([34]),)
# (array([51]),)
# (array([53]),)
# (array([59]),)
# (array([50]),)
# (array([72]),)
# (array([73]),)
# (array([68]),)
# (array([64]),)
# (array([61]),)
# (array([58]),)
# (array([54]),)
# (array([49]),)
# (array([43]),)
# (array([40]),)
# (array([35]),)
# (array([25]),)
# (array([27]),)
# (array([22]),)
# (array([24]),)
# ...
# (array([44]),)
# (array([46]),)
# (array([49]),)
# (array([48]),)
# (array([51]),)
# (array([52]),)
# (array([40]),)
# (array([5]),)
# (array([50]),)
# (array([39]),)
# (array([36]),)
# (array([35]),)
# (array([30]),)
# (array([29]),)
# (array([26]),)
# (array([25]),)
# (array([22]),)
# (array([20]),)
# (array([18]),)
# (array([19]),)
# (array([14]),)
# (array([10]),)
# (array([13]),)
# (array([12]),)
# (array([15]),)
# (array([9]),)
# (array([7]),)
# (array([8]),)
# (array([11]),)
# (array([16]),)
# (array([21]),)
# (array([23]),)
# (array([24]),)
# (array([27]),)
# (array([28]),)
# (array([33]),)
# (array([34]),)
# (array([37]),)
# (array([42]),)
# (array([43]),)
# (array([45]),)
# (array([47]),)
# (array([3]),)
# (array([1]),)
# (array([0]),)
# (array([2]),)
# (array([4]),)
# (array([5]),)
# (array([9]),)
# (array([16]),)
# (array([7]),)
# (array([13]),)
# (array([6]),)
# (array([12]),)
# (array([8]),)
# (array([14]),)
# (array([10]),)
# (array([15]),)
# (array([11]),)
# (array([18]),)
# (array([17]),)
# (array([47]),)
# (array([45]),)
# (array([43]),)
# (array([40]),)
# (array([38]),)
# (array([36]),)
# (array([35]),)
# (array([32]),)
# (array([31]),)
# (array([30]),)
# (array([28]),)
# (array([24]),)
# (array([20]),)
# (array([25]),)
# (array([21]),)
# (array([26]),)
# (array([22]),)
# (array([19]),)
# (array([23]),)
# (array([27]),)
# (array([29]),)
# (array([33]),)
# (array([34]),)
# (array([37]),)
# (array([39]),)
# (array([41]),)
# (array([42]),)
# (array([44]),)
# (array([46]),)
# (array([48]),)
# (array([49]),)
# (array([50]),)
# (array([3]),)
# (array([1]),)
# (array([0]),)
# (array([1]),)
# (array([3]),)
# (array([5]),)
# (array([7]),)
# (array([38]),)
# (array([42]),)
# (array([43]),)
# (array([44]),)
# (array([45]),)
# (array([46]),)
# (array([47]),)
# (array([21]),)
# (array([6]),)
# (array([41]),)
# (array([40]),)
# (array([39]),)
# (array([37]),)
# (array([34]),)
# (array([31]),)
# (array([30]),)
# (array([27]),)
# (array([24]),)
# (array([19]),)
# (array([23]),)
# (array([14]),)
# (array([17]),)
# (array([10]),)
# (array([16]),)
# (array([15]),)
# (array([12]),)
# (array([8]),)
# (array([11]),)
# (array([9]),)
# (array([13]),)
# (array([18]),)
# (array([20]),)
# (array([22]),)
# (array([25]),)
# (array([26]),)
# (array([28]),)
# (array([29]),)
# (array([32]),)
# (array([33]),)
# (array([36]),)
# (array([35]),)
# (array([4]),)
# (array([2]),)
# (array([0]),)
# (array([14]),)
# (array([15]),)
# (array([13]),)
# (array([12]),)
# (array([11]),)
# (array([10]),)
# (array([9]),)
# (array([8]),)
# (array([7]),)
# (array([5]),)
# (array([4]),)
# (array([1]),)
# (array([6]),)
# (array([42]),)
# (array([40]),)
# (array([39]),)
# (array([36]),)
# (array([34]),)
# (array([32]),)
# (array([30]),)
# (array([29]),)
# (array([26]),)
# (array([27]),)
# (array([21]),)
# (array([19]),)
# (array([16]),)
# (array([22]),)
# (array([17]),)
# (array([25]),)
# (array([20]),)
# (array([18]),)
# (array([23]),)
# (array([24]),)
# (array([28]),)
# (array([31]),)
# (array([33]),)
# (array([35]),)
# (array([37]),)
# (array([38]),)
# (array([41]),)
# (array([43]),)
# (array([44]),)
# (array([45]),)
# (array([2]),)
# (array([3]),)
# (array([0]),)
# (array([3]),)
# (array([7]),)
# (array([15]),)
# (array([14]),)
# (array([13]),)
# (array([11]),)
# (array([12]),)
# (array([9]),)
# (array([10]),)
# (array([6]),)
# (array([8]),)
# (array([5]),)
# (array([4]),)
# (array([43]),)
# (array([41]),)
# (array([38]),)
# (array([35]),)
# (array([34]),)
# (array([32]),)
# (array([29]),)
# (array([28]),)
# (array([27]),)
# (array([25]),)
# (array([21]),)
# (array([18]),)
# (array([22]),)
# (array([16]),)
# (array([23]),)
# (array([19]),)
# (array([17]),)
# (array([20]),)
# (array([24]),)
# (array([26]),)
# (array([30]),)
# (array([31]),)
# (array([33]),)
# (array([36]),)
# (array([37]),)
# (array([39]),)
# (array([40]),)
# (array([42]),)
# (array([2]),)
# (array([1]),)
# (array([0]),)
# (array([1]),)
# (array([3]),)
# (array([5]),)
# (array([7]),)
# (array([13]),)
# (array([9]),)
# (array([12]),)
# (array([6]),)
# (array([11]),)
# (array([8]),)
# (array([10]),)
# (array([15]),)
# (array([14]),)
# (array([38]),)
# (array([37]),)
# (array([34]),)
# (array([32]),)
# (array([29]),)
# (array([27]),)
# (array([28]),)
# (array([25]),)
# (array([23]),)
# (array([18]),)
# (array([22]),)
# (array([17]),)
# (array([24]),)
# (array([19]),)
# (array([16]),)
# (array([20]),)
# (array([21]),)
# (array([26]),)
# (array([30]),)
# (array([31]),)
# (array([33]),)
# (array([35]),)
# (array([36]),)
# (array([39]),)
# (array([40]),)
# (array([41]),)
# (array([4]),)
# (array([2]),)
# (array([0]),)
# (array([11]),)
# (array([39]),)
# (array([34]),)
# (array([25]),)
# (array([10]),)
# (array([9]),)
# (array([8]),)
# (array([7]),)
# (array([6]),)
# (array([5]),)
# (array([2]),)
# (array([4]),)
# (array([28]),)
# (array([32]),)
# (array([31]),)
# (array([27]),)
# (array([26]),)
# (array([18]),)
# (array([24]),)
# (array([21]),)
# (array([15]),)
# (array([13]),)
# (array([19]),)
# (array([12]),)
# (array([23]),)
# (array([17]),)
# (array([14]),)
# (array([16]),)
# (array([20]),)
# (array([22]),)
# (array([30]),)
# (array([29]),)
# (array([33]),)
# (array([35]),)
# (array([36]),)
# (array([37]),)
# (array([38]),)
# (array([3]),)
# (array([1]),)
# (array([0]),)
# (array([12]),)
# (array([14]),)
# (array([13]),)
# (array([11]),)
# (array([10]),)
# (array([9]),)
# (array([8]),)
# (array([7]),)
# (array([6]),)
# (array([5]),)
# (array([1]),)
# (array([2]),)
# (array([32]),)
# (array([35]),)
# (array([34]),)
# (array([31]),)
# (array([28]),)
# (array([26]),)
# (array([27]),)
# (array([24]),)
# (array([23]),)
# (array([16]),)
# (array([21]),)
# (array([15]),)
# (array([25]),)
# (array([19]),)
# (array([17]),)
# (array([18]),)
# (array([20]),)
# (array([22]),)
# (array([30]),)
# (array([29]),)
# (array([33]),)
# (array([36]),)
# (array([37]),)
# (array([3]),)
# (array([4]),)
# (array([0]),)
# (array([14]),)
# (array([13]),)
# (array([12]),)
# (array([11]),)
# (array([10]),)
# (array([9]),)
# (array([8]),)
# (array([6]),)
# (array([5]),)
# (array([4]),)
# (array([1]),)
# (array([7]),)
# (array([35]),)
# (array([34]),)
# (array([33]),)
# (array([31]),)
# (array([28]),)
# (array([27]),)
# (array([26]),)
# (array([25]),)
# (array([23]),)
# (array([18]),)
# (array([22]),)
# (array([16]),)
# (array([21]),)
# (array([17]),)
# (array([15]),)
# (array([19]),)
# (array([20]),)
# (array([24]),)
# (array([30]),)
# (array([29]),)
# (array([32]),)
# (array([3]),)
# (array([2]),)
# (array([0]),)
# (array([2]),)
# (array([4]),)
# (array([27]),)
# (array([28]),)
# (array([29]),)
# (array([30]),)
# (array([31]),)
# (array([33]),)
# (array([32]),)
# (array([34]),)
# (array([26]),)
# (array([24]),)
# (array([25]),)
# (array([23]),)
# (array([21]),)
# (array([15]),)
# (array([5]),)
# (array([9]),)
# (array([16]),)
# (array([7]),)
# (array([11]),)
# (array([8]),)
# (array([12]),)
# (array([17]),)
# (array([10]),)
# (array([6]),)
# (array([13]),)
# (array([14]),)
# (array([19]),)
# (array([22]),)
# (array([20]),)
# (array([18]),)
# (array([3]),)
# (array([1]),)
# (array([0]),)
# (array([3]),)
# (array([31]),)
# (array([29]),)
# (array([32]),)
# (array([26]),)
# (array([25]),)
# (array([18]),)
# (array([16]),)
# (array([4]),)
# (array([23]),)
# (array([28]),)
# (array([30]),)
# (array([27]),)
# (array([22]),)
# (array([17]),)
# (array([19]),)
# (array([15]),)
# (array([12]),)
# (array([7]),)
# (array([8]),)
# (array([5]),)
# (array([14]),)
# (array([9]),)
# (array([6]),)
# (array([10]),)
# (array([11]),)
# (array([13]),)
# (array([24]),)
# (array([20]),)
# (array([21]),)
# (array([2]),)
# (array([1]),)
# (array([0]),)
# (array([1]),)
# (array([3]),)
# (array([4]),)
# (array([5]),)
# (array([6]),)
# (array([7]),)
# (array([9]),)
# (array([10]),)
# (array([31]),)
# (array([28]),)
# (array([30]),)
# (array([29]),)
# (array([24]),)
# (array([23]),)
# (array([20]),)
# (array([21]),)
# (array([19]),)
# (array([17]),)
# (array([14]),)
# (array([16]),)
# (array([15]),)
# (array([12]),)
# (array([11]),)
# (array([13]),)
# (array([18]),)
# (array([22]),)
# (array([27]),)
# (array([25]),)
# (array([26]),)
# (array([8]),)
# (array([2]),)
# (array([0]),)
# (array([2]),)
# (array([6]),)
# (array([11]),)
# (array([10]),)
# (array([8]),)
# (array([9]),)
# (array([7]),)
# (array([5]),)
# (array([4]),)
# (array([24]),)
# (array([28]),)
# (array([23]),)
# (array([25]),)
# (array([22]),)
# (array([21]),)
# (array([14]),)
# (array([20]),)
# (array([13]),)
# (array([18]),)
# (array([15]),)
# (array([12]),)
# (array([16]),)
# (array([17]),)
# (array([19]),)
# (array([29]),)
# (array([26]),)
# (array([27]),)
# (array([3]),)
# (array([1]),)
# (array([0]),)
# (array([1]),)
# (array([4]),)
# (array([23]),)
# (array([27]),)
# (array([15]),)
# (array([17]),)
# (array([9]),)
# (array([7]),)
# (array([2]),)
# (array([5]),)
# (array([26]),)
# (array([19]),)
# (array([28]),)
# (array([20]),)
# (array([22]),)
# (array([11]),)
# (array([21]),)
# (array([10]),)
# (array([16]),)
# (array([12]),)
# (array([8]),)
# (array([13]),)
# (array([14]),)
# (array([18]),)
# (array([25]),)
# (array([24]),)
# (array([6]),)
# (array([3]),)
# (array([0]),)
# (array([1]),)
# (array([3]),)
# (array([22]),)
# (array([23]),)
# (array([24]),)
# (array([26]),)
# (array([4]),)
# (array([5]),)
# (array([13]),)
# (array([8]),)
# (array([14]),)
# (array([19]),)
# (array([17]),)
# (array([9]),)
# (array([10]),)
# (array([15]),)
# (array([16]),)
# (array([11]),)
# (array([6]),)
# (array([12]),)
# (array([7]),)
# (array([20]),)
# (array([21]),)
# (array([18]),)
# (array([25]),)
# (array([2]),)
# (array([0]),)
# (array([1]),)
# (array([3]),)
# (array([4]),)
# (array([6]),)
# (array([5]),)
# (array([7]),)
# (array([25]),)
# (array([22]),)
# (array([20]),)
# (array([18]),)
# (array([19]),)
# (array([15]),)
# (array([12]),)
# (array([14]),)
# (array([11]),)
# (array([16]),)
# (array([9]),)
# (array([10]),)
# (array([13]),)
# (array([17]),)
# (array([21]),)
# (array([23]),)
# (array([24]),)
# (array([8]),)
# (array([2]),)
# (array([0]),)
# (array([1]),)
# (array([3]),)
# (array([4]),)
# (array([5]),)
# (array([6]),)
# (array([7]),)
# (array([21]),)
# (array([23]),)
# (array([19]),)
# (array([16]),)
# (array([22]),)
# (array([11]),)
# (array([14]),)
# (array([9]),)
# (array([17]),)
# (array([12]),)
# (array([13]),)
# (array([10]),)
# (array([15]),)
# (array([18]),)
# (array([20]),)
# (array([24]),)
# (array([8]),)
# (array([2]),)
# (array([0]),)
# (array([7]),)
# (array([8]),)
# (array([5]),)
# (array([4]),)
# (array([3]),)
# (array([2]),)
# (array([22]),)
# (array([23]),)
# (array([18]),)
# (array([21]),)
# (array([20]),)
# (array([13]),)
# (array([10]),)
# (array([12]),)
# (array([9]),)
# (array([16]),)
# (array([14]),)
# (array([11]),)
# (array([15]),)
# (array([19]),)
# (array([17]),)
# (array([6]),)
# (array([1]),)
# (array([0]),)
# (array([7]),)
# (array([6]),)
# (array([5]),)
# (array([4]),)
# (array([2]),)
# (array([1]),)
# (array([22]),)
# (array([20]),)
# (array([21]),)
# (array([19]),)
# (array([16]),)
# (array([9]),)
# (array([17]),)
# (array([10]),)
# (array([18]),)
# (array([14]),)
# (array([12]),)
# (array([13]),)
# (array([15]),)
# (array([11]),)
# (array([8]),)
# (array([3]),)
# (array([0]),)
# (array([1]),)
# (array([3]),)
# (array([4]),)
# (array([5]),)
# (array([6]),)
# (array([7]),)
# (array([17]),)
# (array([9]),)
# (array([13]),)
# (array([21]),)
# (array([11]),)
# (array([12]),)
# (array([8]),)
# (array([20]),)
# (array([15]),)
# (array([16]),)
# (array([10]),)
# (array([18]),)
# (array([14]),)
# (array([19]),)
# (array([2]),)
# (array([0]),)
# (array([0]),)
# (array([2]),)
# (array([3]),)
# (array([4]),)
# (array([5]),)
# (array([6]),)
# (array([18]),)
# (array([20]),)
# (array([17]),)
# (array([15]),)
# (array([10]),)
# (array([16]),)
# (array([11]),)
# (array([19]),)
# (array([14]),)
# (array([7]),)
# (array([13]),)
# (array([8]),)
# (array([12]),)
# (array([9]),)
# (array([1]),)
# (array([1]),)
# (array([3]),)
# (array([4]),)
# (array([6]),)
# (array([5]),)
# (array([7]),)
# (array([18]),)
# (array([19]),)
# (array([14]),)
# (array([13]),)
# (array([8]),)
# (array([17]),)
# (array([10]),)
# (array([12]),)
# (array([9]),)
# (array([15]),)
# (array([11]),)
# (array([16]),)
# (array([2]),)
# (array([0]),)
# (array([0]),)
# (array([3]),)
# (array([5]),)
# (array([7]),)
# (array([6]),)
# (array([4]),)
# (array([13]),)
# (array([16]),)
# (array([17]),)
# (array([9]),)
# (array([18]),)
# (array([10]),)
# (array([14]),)
# (array([11]),)
# (array([15]),)
# (array([12]),)
# (array([8]),)
# (array([2]),)
# (array([1]),)
# (array([1]),)
# (array([10]),)
# (array([15]),)
# (array([16]),)
# (array([17]),)
# (array([6]),)
# (array([9]),)
# (array([11]),)
# (array([4]),)
# (array([14]),)
# (array([7]),)
# (array([8]),)
# (array([3]),)
# (array([12]),)
# (array([5]),)
# (array([13]),)
# (array([2]),)
# (array([0]),)
# (array([2]),)
# (array([8]),)
# (array([13]),)
# (array([16]),)
# (array([3]),)
# (array([6]),)
# (array([11]),)
# (array([14]),)
# (array([5]),)
# (array([7]),)
# (array([12]),)
# (array([9]),)
# (array([15]),)
# (array([10]),)
# (array([4]),)
# (array([1]),)
# (array([0]),)
# (array([0]),)
# (array([2]),)
# (array([5]),)
# (array([6]),)
# (array([4]),)
# (array([13]),)
# (array([10]),)
# (array([7]),)
# (array([9]),)
# (array([12]),)
# (array([15]),)
# (array([8]),)
# (array([14]),)
# (array([11]),)
# (array([3]),)
# (array([1]),)
# (array([1]),)
# (array([12]),)
# (array([14]),)
# (array([13]),)
# (array([8]),)
# (array([9]),)
# (array([5]),)
# (array([4]),)
# (array([6]),)
# (array([11]),)
# (array([7]),)
# (array([10]),)
# (array([3]),)
# (array([2]),)
# (array([0]),)
# (array([0]),)
# (array([2]),)
# (array([4]),)
# (array([3]),)
# (array([14]),)
# (array([11]),)
# (array([10]),)
# (array([6]),)
# (array([8]),)
# (array([13]),)
# (array([7]),)
# (array([12]),)
# (array([9]),)
# (array([5]),)
# (array([1]),)
# (array([13]),)
# (array([3]),)
# (array([2]),)
# (array([12]),)
# (array([10]),)
# (array([7]),)
# (array([5]),)
# (array([4]),)
# (array([8]),)
# (array([6]),)
# (array([9]),)
# (array([11]),)
# (array([1]),)
# (array([0]),)
# (array([4]),)
# (array([1]),)
# (array([0]),)
# (array([12]),)
# (array([7]),)
# (array([5]),)
# (array([6]),)
# (array([11]),)
# (array([8]),)
# (array([10]),)
# (array([9]),)
# (array([3]),)
# (array([2]),)
# (array([0]),)
# (array([3]),)
# (array([4]),)
# (array([7]),)
# (array([6]),)
# (array([8]),)
# (array([10]),)
# (array([12]),)
# (array([5]),)
# (array([11]),)
# (array([9]),)
# (array([2]),)
# (array([1]),)
# (array([0]),)
# (array([3]),)
# (array([2]),)
# (array([8]),)
# (array([5]),)
# (array([9]),)
# (array([10]),)
# (array([6]),)
# (array([11]),)
# (array([7]),)
# (array([4]),)
# (array([1]),)
# (array([4]),)
# (array([3]),)
# (array([1]),)
# (array([8]),)
# (array([10]),)
# (array([6]),)
# (array([7]),)
# (array([5]),)
# (array([11]),)
# (array([9]),)
# (array([2]),)
# (array([0]),)
# (array([4]),)
# (array([3]),)
# (array([2]),)
# (array([8]),)
# (array([5]),)
# (array([7]),)
# (array([6]),)
# (array([9]),)
# (array([10]),)
# (array([1]),)
# (array([0]),)
# (array([2]),)
# (array([4]),)
# (array([3]),)
# (array([9]),)
# (array([5]),)
# (array([8]),)
# (array([7]),)
# (array([6]),)
# (array([10]),)
# (array([1]),)
# (array([0]),)
# (array([1]),)
# (array([9]),)
# (array([5]),)
# (array([3]),)
# (array([6]),)
# (array([7]),)
# (array([4]),)
# (array([8]),)
# (array([2]),)
# (array([0]),)
# (array([1]),)
# (array([3]),)
# (array([7]),)
# (array([4]),)
# (array([8]),)
# (array([6]),)
# (array([5]),)
# (array([9]),)
# (array([2]),)
# (array([0]),)
# (array([0]),)
# (array([3]),)
# (array([6]),)
# (array([8]),)
# (array([7]),)
# (array([4]),)
# (array([5]),)
# (array([2]),)
# (array([1]),)
# (array([1]),)
# (array([8]),)
# (array([5]),)
# (array([3]),)
# (array([7]),)
# (array([4]),)
# (array([6]),)
# (array([2]),)
# (array([0]),)
# (array([1]),)
# (array([3]),)
# (array([7]),)
# (array([4]),)
# (array([5]),)
# (array([6]),)
# (array([2]),)
# (array([0]),)
# (array([6]),)
# (array([7]),)
# (array([5]),)
# (array([4]),)
# (array([2]),)
# (array([3]),)
# (array([1]),)
# (array([0]),)
# (array([3]),)
# (array([2]),)
# (array([7]),)
# (array([6]),)
# (array([4]),)
# (array([5]),)
# (array([1]),)
# (array([0]),)
# (array([6]),)
# (array([3]),)
# (array([5]),)
# (array([2]),)
# (array([4]),)
# (array([1]),)
# (array([0]),)
# (array([0]),)
# (array([4]),)
# (array([6]),)
# (array([3]),)
# (array([5]),)
# (array([2]),)
# (array([1]),)
# (array([6]),)
# (array([3]),)
# (array([4]),)
# (array([2]),)
# (array([5]),)
# (array([1]),)
# (array([0]),)
# (array([1]),)
# (array([4]),)
# (array([3]),)
# (array([5]),)
# (array([2]),)
# (array([0]),)
# (array([1]),)
# (array([3]),)
# (array([2]),)
# (array([4]),)
# (array([5]),)
# (array([0]),)
# (array([1]),)
# (array([3]),)
# (array([2]),)
# (array([4]),)
# (array([5]),)
# (array([0]),)
# (array([1]),)
# (array([3]),)
# (array([2]),)
# (array([4]),)
# (array([0]),)
# (array([1]),)
# (array([3]),)
# (array([2]),)
# (array([4]),)
# (array([0]),)
# (array([1]),)
# (array([3]),)
# (array([2]),)
# (array([4]),)
# (array([0]),)
# (array([1]),)
# (array([3]),)
# (array([2]),)
# (array([4]),)
# (array([0]),)
# (array([1]),)
# (array([3]),)
# (array([2]),)
# (array([0]),)
# (array([3]),)
# (array([2]),)
# (array([1]),)
# (array([0]),)
# (array([3]),)
# (array([2]),)
# (array([1]),)
# (array([0]),)
# (array([3]),)
# (array([2]),)
# (array([1]),)
# (array([0]),)
# (array([3]),)
# (array([2]),)
# (array([1]),)
# (array([0]),)
# (array([3]),)
# (array([2]),)
# (array([1]),)
# (array([0]),)
# (array([2]),)
# (array([1]),)
# (array([0]),)
# (array([2]),)
# (array([1]),)
# (array([0]),)
# (array([2]),)
# (array([1]),)
# (array([0]),)
# (array([2]),)
# (array([1]),)
# (array([0]),)
# (array([2]),)
# (array([1]),)
# (array([0]),)
# (array([2]),)
# (array([1]),)
# (array([0]),)
# (array([1]),)
# (array([2]),)
# (array([0]),)
# (array([1]),)
# (array([0]),)
# (array([1]),)
# (array([0]),)
# (array([1]),)
# (array([0]),)
# (array([1]),)
# (array([0]),)
# (array([1]),)
# (array([0]),)
# 11
# VIP得分最大波段： 222
# 0.16673209274779874
