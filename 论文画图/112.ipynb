# %%
import matplotlib.pyplot as plt

# 原始数据
rms = [0.2525026684344725, 0.23126483531439976, 0.23126483531439976, 0.23126483531439976, 0.23126483531439976, 0.23126483531439976, 0.23126483531439976, 0.23126483531439976, 0.23126483531439976, 0.23126483531439976, 0.23054601978860517, 0.23054601978860517, 0.23054601978860517, 0.23054601978860517, 0.23054601978860517, 0.23054601978860517, 0.23054601978860517, 0.23054601978860517, 0.23054601978860517, 0.23054601978860517, 0.21518392786445995, 0.21518392786445995, 0.21518392786445995, 0.21518392786445995, 0.21518392786445995, 0.21518392786445995, 0.21518392786445995, 0.21518392786445995, 0.21518392786445995, 0.21518392786445995, 0.21518392786445995, 0.21518392786445995, 0.21518392786445995, 0.21172323346913619, 0.21172323346913619, 0.21172323346913619, 0.21172323346913619, 0.21172323346913619, 0.21172323346913619, 0.21172323346913619, 0.21172323346913619, 0.21172323346913619, 0.21172323346913619, 0.21172323346913619, 0.21172323346913619, 0.21172323346913619, 0.21172323346913619, 0.21172323346913619, 0.21172323346913619, 0.21172323346913619, 0.21172323346913619, 0.21172323346913619, 0.21172323346913619, 0.21172323346913619, 0.21172323346913619, 0.21172323346913619, 0.21172323346913619, 0.21172323346913619, 0.21172323346913619, 0.21172323346913619, 0.21172323346913619, 0.21172323346913619, 0.21172323346913619, 0.21172323346913619, 0.21172323346913619, 0.21172323346913619, 0.21172323346913619, 0.21172323346913619, 0.21037997552882184, 0.21037997552882184, 0.21037997552882184, 0.21037997552882184, 0.21037997552882184, 0.21037997552882184, 0.21037997552882184, 0.21037997552882184, 0.20492456280355983, 0.20492456280355983, 0.20492456280355983, 0.20492456280355983, 0.20492456280355983, 0.20492456280355983, 0.20492456280355983, 0.20492456280355983, 0.20492456280355983, 0.20492456280355983, 0.20492456280355983, 0.20492456280355983, 0.20492456280355983, 0.20492456280355983, 0.20280668758814438, 0.20280668758814438, 0.20280668758814438, 0.20280668758814438, 0.20280668758814438, 0.20280668758814438, 0.20280668758814438, 0.20280668758814438]

# %%
with plt.style.context(('seaborn-whitegrid')):
    # 创建折线图
    plt.figure(figsize=(8, 6))
    plt.plot(range(len(rms)), rms, marker='o', linestyle='-')  # 绘制所有数据点
    
    # 添加标题和标签
    # plt.title('RMSECV vs Simulated Annealing Iteration', fontsize=18)
    plt.xlabel('Simulated Annealing Iteration', fontsize=18)
    plt.ylabel('RMSECV', fontsize=18)
    
    # 设置横坐标刻度
    plt.xticks(range(0, len(rms), 10), fontsize=16)
    plt.yticks(fontsize=16)
    # 显示图形
    plt.grid(False)
    plt.show()

# %%
# 创建折线图
plt.figure(figsize=(8, 6))
plt.plot(range(len(rms)), rms, marker='o', linestyle='-', color='b')  # 绘制所有数据点

# 添加标题和标签
plt.title('RMSECV vs Simulated Annealing Iteration', fontsize=18)
plt.xlabel('Simulated Annealing Iteration', fontsize=18)
plt.ylabel('RMSECV', fontsize=18)

# 设置横坐标刻度
plt.xticks(range(0, len(rms), 10), fontsize=18)

# 显示图形
plt.grid(False)
plt.show()
